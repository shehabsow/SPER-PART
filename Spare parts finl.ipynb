# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_excel('Engineering Spare parts WH (Recovered).xlsx')
df
# Out:
#                            Item description  Qty.           Part #  \
# 0     YOKE TYPE TRACK ROLLERS, 12X32X11.8MM   1.0            STO12
# 1                         WIPER , 20/30*4*7   1.0      1-999-04634
# 2         WHITE SMALL Circle PLASTIC GASKET   4.0        BTHL30013
# 3                     WHITE PTFE GASKET SET   1.0  13-GPT*12T*0002
# 4                     WHITE PTFE GASKET SET   1.0  12-GPT*12T*0005
# ..                                      ...   ...              ...
# 743  1 EPDM GASKET + STOPPER + CABLE GASKET   1.0           551775
# 744     RELAY 24VDC, 5A, 14 PINS - MY4 DC24   1.0          6402031
# 745           WATER HEATER 27KW, 400V, IP25   1.0         DEX Next
# 746                     Plate Heater 230 V    1.0            1000W
# 747                 Seat Valve, 3/4",16 Bar   1.0        J4SSG16U5
#
#     Manufacturer  Supplier Machine location     Comments  \
# 0            INA       NaN     NaN   M-12-2      BEARING
# 1          GLATT    GLATT      NaN   B-02-2       GASKET
# 2            IMA       IMA     NaN   B-03-2       GASKET
# 3            NaN  STILLMAS     NaN   L-12-3       GASKET
# 4            NaN  STILLMAS     NaN   L-12-3       GASKET
# ..           ...       ...     ...      ...          ...
# 743          NaN   BURKERT     NaN   B-02-2       GASKET
# 744        OMRON       IMA     NaN   E-05-2       RELAY
# 745        CLAGE       NaN     NaN   M-11-1       HEATER
# 746         Horn       NaN     NaN   D-03-2       HEATER
# 747         Omal       NaN     NaN   D-07-2  Water VALVE
#
#                           Item description3
# 0     YOKE TYPE TRACK ROLLERS, 12X32X11.8MM
# 1                         WIPER , 20/30*4*7
# 2         WHITE SMALL Circle PLASTIC GASKET
# 3                     WHITE PTFE GASKET SET
# 4                     WHITE PTFE GASKET SET
# ..                                      ...
# 743  1 EPDM GASKET + STOPPER + CABLE GASKET
# 744     RELAY 24VDC, 5A, 14 PINS - MY4 DC24
# 745                                     NaN
# 746                                     NaN
# 747                                     NaN
#
# [748 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Item description       1
# Qty.                   2
# Part #                31
# Manufacturer          43
# Supplier             536
# Machine              699
# location               8
# Comments               9
# Item description3      4
# dtype: int64

# %%
df['Comments'].isnull().sum()
# Out:
# 9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Item description   747 non-null    object
#  1   Qty.               746 non-null    float64
#  2   Part #             717 non-null    object
#  3   Manufacturer       705 non-null    object
#  4   Supplier           212 non-null    object
#  5   Machine            49 non-null     object
#  6   location           740 non-null    object
#  7   Comments           739 non-null    object
#  8   Item description3  744 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 52.7+ KB

# %%
df.columns = df.columns.str.capitalize()
df.columns
# Out:
# Index(['Item description', 'Qty.', 'Part #', 'Manufacturer', 'Supplier',
#        'Machine', 'Location', 'Comments', 'Item description3'],
#       dtype='object')

# %%
df['Comments'] = df['Comments'].str.capitalize()
df['Comments']
# Out:
# 0          Bearing
# 1           Gasket
# 2           Gasket
# 3           Gasket
# 4           Gasket
#           ...
# 743         Gasket
# 744         Relay
# 745         Heater
# 746         Heater
# 747    Water valve
# Name: Comments, Length: 748, dtype: object

# %%
df_f = df.drop(['Machine','Supplier','Item description3'], axis=1)
df_f.to_csv('Eng Spare parts.csv', index=False)
df_f
# Out:
#                            Item description  Qty.           Part #  \
# 0     YOKE TYPE TRACK ROLLERS, 12X32X11.8MM   1.0            STO12
# 1                         WIPER , 20/30*4*7   1.0      1-999-04634
# 2         WHITE SMALL Circle PLASTIC GASKET   4.0        BTHL30013
# 3                     WHITE PTFE GASKET SET   1.0  13-GPT*12T*0002
# 4                     WHITE PTFE GASKET SET   1.0  12-GPT*12T*0005
# ..                                      ...   ...              ...
# 743  1 EPDM GASKET + STOPPER + CABLE GASKET   1.0           551775
# 744     RELAY 24VDC, 5A, 14 PINS - MY4 DC24   1.0          6402031
# 745           WATER HEATER 27KW, 400V, IP25   1.0         DEX Next
# 746                     Plate Heater 230 V    1.0            1000W
# 747                 Seat Valve, 3/4",16 Bar   1.0        J4SSG16U5
#
#     Manufacturer Location     Comments
# 0            INA   M-12-2      Bearing
# 1          GLATT   B-02-2       Gasket
# 2            IMA   B-03-2       Gasket
# 3            NaN   L-12-3       Gasket
# 4            NaN   L-12-3       Gasket
# ..           ...      ...          ...
# 743          NaN   B-02-2       Gasket
# 744        OMRON   E-05-2       Relay
# 745        CLAGE   M-11-1       Heater
# 746         Horn   D-03-2       Heater
# 747         Omal   D-07-2  Water valve
#
# [748 rows x 6 columns]

# %%
categorical = df_f.select_dtypes(include='O').columns

for cat in categorical:
    print(f"{cat} column has number of uniques : {df_f[cat].nunique()}")
    print(f"{cat} column has uniques : {df_f[cat].unique()}")
    print(f'\n{"-"*50}\n')
    print(f"{cat} column each unique repeated by:")
    print(df_f[cat].value_counts())
    print(f'\n{"-"*50}\n')
# Out:
# Item description column has number of uniques : 680
# Item description column has uniques : ['YOKE TYPE TRACK ROLLERS, 12X32X11.8MM' 'WIPER , 20/30*4*7'
#  'WHITE SMALL Circle PLASTIC GASKET' 'WHITE PTFE GASKET SET'
#  'WHITE LIGHT PROBE WM 03 PCT 2' 'Wheel BT 156259'
#  'WEAR RING 100X114X10 BZ' 'WATER TOTAL HARDNESS COLORIMETRIC REAGENTS'
#  'WATER TANK TRANSPERANT 60L, PE, WITH DOSING PUMP'
#  'WATER PROOF ELECTRIC BOX 10X10, IP55'
#  'WATER LOW RANGE HARDNESS INDICATOR REAGENT A'
#  'WATER JET PUMP, 1130W, 230V, IP44' 'WATER HEATER 27KW, 400V, IP25'
#  'WATER HARDNESS INDICATOR REAGENT' 'WATER FREE CHLORINE REAGENT '
#  'WASHING NOZZLE TYPE A05, D=28MM' 'WAER RING 90X104X10 BZ '
#  'V-SEAL-RING, D=500MM' 'VISOLUX PHOTOELECTRIC SENSOR 24VDC'
#  'VIRTICAL MULTISTAGE CENTERFUGAL PUMP 0.75KW, 1.8M3/H'
#  'VIPRONIC POINT LEVEL SWITCH, IP66, 8.2VDC'
#  'ventilation FAN 220-240 V 35W , 1850rpm'
#  'VENTELATION AXIAL FAN, 220V, 0.4A, 80W'
#  'VENTELATION AXIAL FAN, 220V, 0.22A, 38W'
#  'VARIABLE SPEED GEARED MOTOR, 44W, 0.16A, 3Ø'
#  "VALVE, PN16, BRASS WITH ACTUATOR, 230V 7W, 16BAR,1/2''"
#  'VACUUM PUMP WITH MOTOR 3 PHASE 3-3.6AMP 1.25 KW 1420 RPM'
#  'VACCUM PUMP 1Ø, 90M3/H, 0.37KW, 1.2A, 2820RPM'
#  'VACCUM DIAL GAUGE, -1 TO 1 BAR' "UV LAMP SLEEVE , 35''L"
#  "UV LAMP 40W , 33.19''L" 'USB SERVER INDUSTRY ISOCHRON EATHERNET'
#  'UPS, I/P=24VDC, O/P=24VDC/10A' 'UPS BATTERY BANK 24V 1.3AH/15A MAX'
#  'UPS 24VDC, 20A' 'UPPER SEALING ROLLER '
#  'Universal Temperature Converter KFD2-UT2-Ex1'
#  'TUBE AXIAL FAN 220AC/240V - 46/40W' 'TRAP BUILT SPA, 12.7*10, LP3350'
#  "TRACK & TRACE TOUCH SCREEN, 15'', IN S.S HOUSING" 'TOUTH BELTS KIT'
#  'TOUCH SCREEN DISPLAY , XP ANALYTICAL' 'TOTAL HARDNESS PHOTOMETER'
#  'TIMING BILT W=12, 103 TETH' 'TIMING BELT, L=2550, STEP=150, T10-2550'
#  'TIMING BELT, L=2250, 225 TEETH' "TIMING BELT, L=15'',W=3/8'',75 TEETH"
#  'TIMING BELT, 960*30*8MM, 120 TEETH' 'TIMING BELT- 330 teeth'
#  'TIMING BELT ; T10-2250' 'Timing Belt ,L=1840 , W=75 mm'
#  'THYRISTOR CONTROL UNIT, 230V-50/60Hz-4A'
#  'THERMOSTATE 230V,2A, IP54, 150-7C' 'THERMOMETER, FLAT, PT100, M44X1.5'
#  'THERMOCOUPLE , TYPE J, TMAX=270C - 74315-01/27'
#  'THERMAL TRANSFER DESKTOP PRINTER'
#  'THERMAL INKJET PRENTER+ SMART JET DUE PRO'
#  'TERMINAL JUMPER, 800V, INSULATED, GRAY' 'TERMINAL JUMPER, 800V'
#  'TERMINAL BLOCK, 2 CONDUCTOR, 6MM2, GRAY'
#  'TERMINAL BLOCK, 2 CONDUCTOR, 2.5MM2, GRAY'
#  'TERMINAL BLOCK, 2 CONDUCTOR, 16MM2, GRAY'
#  'TERMINAL BLOCK, 2 CONDUCTOR GROUND,1 6MM2, GREEN-YELLOW'
#  'TERMINAL BLOCK, 2 CONDUCTOR GROUND, 6MM2, GREEN-YELLOW'
#  'TERMINAL BLOCK, 2 CONDUCTOR GROUND, 2.5MM2, GREEN-YELLOW'
#  'TENSION SPRING, 1.4X10X35.3' 'TENSION SPRING, 1.2X9X82' 'TENSION SPRING'
#  'TEMPERATURE SENSOR, PT100, CLASS A'
#  'TEMPERATURE SENSOR PT1000,WITH DISPLAY, M18 '
#  'TEMPERATURE SENSOR ,PT100, 200C, IP65' 'TEMPERATURE MODULE, 8 INPUT'
#  'TEMPERATURE CONVETOR KFD2-UT2-1'
#  'TEMPERATURE CONTROLLER, 240VAC, WITH DISPLAY'
#  'TEMPERATURE AND HUMIDITY DATA LOGGER' 'TEMPERATURE / HUMIDITY SENSOR '
#  'TEMP PROBE PT100 -70-260C' 'Temp Control Unit GWK'
#  "TC GASKET 6'', 40MP-X, SILICONE"
#  'SWIVEL CASTOR, D200, WITH SPRING SYSTEM' 'SWITCH WITH 14 PIN'
#  'SWITCH FOR FORKLIFT' 'Switch Amplifier KFD2-ST2-Ex1.LB'
#  'Switch Amplifier KFD2-SR2-Ex2.W' 'Switch Amplifier KFD2-SR2-Ex1.W.LB'
#  'Switch Amplifier KFD2-SR2-Ex1.W' 'Switch Amplifier KFD2-SH-Ex1'
#  'SUPER LINEAR BUSHING, ID=20MM, 5M/S' nan
#  'SUCTION CUP FOR BUNCH STATION BLISTERING MACHINE '
#  'STRIPPER 1 COMPL.P 2100, S.S' 'STERLIZING GRADE AIR AND GAS FILTER'
#  'STEPPING MOTOR DRIVING CARD I/P 4-90VAC'
#  'SPRINGS FOR LEAFLET COMPNSIATION ARM ' 'SPRING PRESSURE PIECE'
#  'SPRAY NOZZLE, 100VG, SIZE 3,'
#  'SPEED CONTROLLER I/P 1Ø,O/P1  0-180DC, 4A, O/P2  210VDC 0.6A '
#  'SPARE PART KIT' 'SONPROG PC INTERFACE FOR SONAR-BERO'
#  'SOLINOID VALVE WITH ACTUATOR 2.5A, 220V, 10BAR WITH SOCKET'
#  'SOLID STATE RELAY ,90A,24-600VAC '
#  'SOLID STATE RELAY ,25A,CONTROL V 4-32VDC '
#  'SOLID STATE RELAY ,100A,CONTROL V 4-32VDC '
#  'SOLENOID VALVE PNEUMATIC , 10BAR, 3/2  '
#  'SOLENOID VALVE PENUMATIC, 16BAR, 3/2, 24VDC'
#  'SOLENOID VALVE PENUMATIC, 16BAR'
#  'SOLENOID VALVE PENUMATIC, 10BAR, 3/2, 24VDC'
#  'SOFT PVC HOSE ARMORED , FOOD CONTACT'
#  'SOCKET ON DIN RAIL, 16A,250V, 2P+E'
#  'SMART Transmitter Power Supply KFD2-STC4-Ex1'
#  'Size 220mm/50mm Alumnum Dorval leaflet rooler '
#  'Size 220mm/15mm Alumnum Dorval leaflet roller '
#  'SINGLE SOLENOID PILOT ACTUATED 5/2-VALVE, 24VDC'
#  'SINGLE SOLENOID PILOT ACTUATED 4/2-VALVE, 24VDC'
#  'SIMATIC S7 CENTRAL PROCESSING UNIT' 'SILICON O RING 295X4MM'
#  'SIGNAL FILAMENT LAMP, 28V' 'Short Manual Leaflet real shaft '
#  'SHIM PS 15X22X1' 'SHAFT SEAL KIT BAQE D28MM'
#  'SERVO MOTOR, 3Ø, 1.3KW,5.4A, 1500RPM'
#  'SERVO MOTOR 2.9KW, 11.9A, 1500RPM,18.6NM'
#  'SERVO DRIVER I/P 3~,1.2A,O/P 3~ ,0-480V, 0-3000HZ, 1.9A,0.5KW'
#  'SERVO DRIVER I/P 3~, 3.7A,O/P 3~, 0-480V, 0-300HZ, 5.4A, 1.5KW'
#  'SERVO DRIVER I/P 3~, 2.5A,O/P 3~, 0-480V, 0-300HZ, 3.5A, 1KW'
#  'SERVO DRIVE 1.5KW, 0-400HZ' 'SERVICE SET'
#  'SENSOR MAGN.FINEC.:SMC D-H7CN'
#  'SENSOR FOR LIQUID ANALYSIS, CONDUCTIVITY'
#  'SENSOR FIBER OPTIC , RANGE 0- 0.15M'
#  'SELF ALLIGNING BALL BEARING, DOUBLE ROW, 20X47X18MM'
#  'SELF ALLIGNING BALL BEARING, DOUBLE ROW, 20X47X14MM'
#  'SELF ALLIGNING BALL BEARING, DOUBLE ROW, 12X32X14MM'
#  'SELECTOR SWITCH WITH KNOB 2 POSITION '
#  'SELECTIVITY MODULE, 4 CHANNEL,I/P 24VDC, 40A, O/P 4X10A'
#  'SEARCH LIGHT 127 CM ' "SEALING RING , 1/4''"
#  'SEALING PROFILE ,L= 845MM, GLUED, SILICONE'
#  'SCALE 104 923 WITH STANDARD PARTS' 'SAFETY SWITCH MAGNITIC, NC+NO, 4A'
#  'SAFETY RELAY PNOZ m1p 24V DC 28W' 'SAFETY RELAY 2SAFETY CONTACT, 3.5W'
#  'Safety relay 2NO , 24VDC, 2.5W' 'SAFETY RELAY '
#  'SAFETY CONTACT EXPANTION'
#  'S.S PUMP WATER PUMP 3~, 1.1KW, 2.5A, 1.8M3/H '
#  "S.S FILTER HOUSING , V=3.3L, L=20''"
#  'S.S CASTOR WITH PU WHEELS , HEAVEY DUTY'
#  'RUBBER BOOT FOR FILL -O - MATIC' 'ROTARY LOBE PUMP,S.S, 7 BAR, 150C'
#  'RODLESS PENUMATIC CYLINDER , 8 BAR MAX'
#  'ROD END BEARING FEMALE, 12MM, M12X1.75'
#  'ROD END BEARING FEMALE, 10MM, M10X1.5'
#  'RJ45 PANEL CONNECTOR WITH M22 THREAD FOR FRONT INSTALLATION'
#  'RETRO REFLECTIVE SENSOR HEAD, IP67, MAX DESTANCE =5M (Laser)'
#  'REPL..IND.POSIZ . BAND ROLLER ALVE' 'RELAY, 8 PIN,24VDC,5A'
#  'RELAY, 24VDC,10A - 2228H1'
#  'REED PROXIMITY SWITCH, FOR CQ2/NCQ2 CYLINDERS - SMC D-A73CN'
#  'REED PROXIMITY SWITCH, 2 WIRE, DIRECT MOUNTING - SMC D-Z73L'
#  'RED SQUARE COVER' 'RECHAGEBLE  BATTERY 12V 2AH/20HR'
#  'RADIAL INSERT BALL BEARING, 50X90X43.7MM'
#  'RADIAL INSERT BALL BEARING, 20X47X43.7MM'
#  'PVC TRANSPERANT HOSE 38*5,FOOD GRADE WITH END COUPLINGS, SPIRED WIRE'
#  'PVC 30*25MM AIR HOSE , FOOD GRADE, W.P 10 BAR , SPIRED WIRE'
#  'PUSH BUTTON, WHITE'
#  'PROX.IND.: PEPPERL + F. 3RG4210 - 7AG00 - PF - 90248010'
#  'PROPYLENE GLYCOL PREMIXED coolant 5GAL 20L'
#  'PROGRAMABLE CONTROLLER CPU UNIT, 16 POINT' 'PROGRAMABLE CONTROLLER'
#  'PROCESSOR MODULE ' 'PRINT CONTROLLER ' 'PRESSURE SPRING, 2X12X44'
#  'PRESSURE SPRING, 1X17X30' 'PRESSURE SPRING SET'
#  'PRESSURE SENSOR, RANGE -0.2TO 0.2BAR,IP66'
#  "PRESSURE RGULAUR PENUMATIC, 8BAR, RELEAVING +GAUGE, 1/4''"
#  "PRESSURE RELIEF SAFETY VALVE PN10,1/2''/3/4''"
#  'Pressure Regulator ,Harris Inlet 200 Bar , ArCo2'
#  'PREPHERAL WHEEL PUMP, 1.5KW, 3.3A, 400V, IP54, 80L/M '
#  'PRE-FILTER PLEATED (2-LINE)WASHABLE 496X496X47MM'
#  'PRE-FILTER (Z LINE),ALUMINIUM FRAME 491*762*22MM'
#  'PRE-FILTER (CLASS G4),ALUMINIUM FRAME 491*762*22MM'
#  'PREASURE TRANSMITTER WITH SENSOR FOR LEVEL, 3WIRE, 0-400MBAR,IP66'
#  'POWER SUPPLY,SITOP MODULAR ,I/P 3Ø, O/P 24VDC, 20A'
#  'POWER SUPPLY UNIT, 240VAC, 5VDC, 3.6A'
#  'POWER SUPPLY I/P 240VAC, O/P 24VDC, 3A, 75W'
#  'POWER SUPPLY I/P 240VAC, 6A , O/P 24VDC, 20A, 480W'
#  'POWER RELAY, DPDT, 24VDC, 8A' 'POWER MODULE, 240VAC, 100W'
#  'POWER LINE FILTER, 3X520/300V, 64A, 3X4.4µF'
#  'Power Feed Module KFD2-EB2'
#  'POWER CONTACTOR 3Ø, 7.5KW, 2NC,2NO, CONTROL 24VDC'
#  'POWER 2 LINE FILTER, 3A, 250VA, 2×0,47 μF (X2)+2×4700 pF (Y2)'
#  'POTENTIOMETER,  CPL FOR FORKLIFT' 'POTENTIOMETER,  AUX R/L'
#  'POSITION SWITCH, 1NO/NC' 'PNEUMATIC CYLINDER'
#  'PNEUM CYLINDER TBC 32x80 ' 'PNEUM CYLINDER Parker 32x80 '
#  'PLUG FOR SENSOR WITH CABLE, 5 POLE, M12,F.90 ANGELED'
#  "PLATE HEAT EXCHANGER 4*1'', 9M3/H, 289*289MM, S.S"
#  'PIN 094054 WITH STANADARD PARTS' 'PIN 052397 WITH STANADARD PARTS'
#  'PILE CARBET PA 50X50CM , 5M2, 20 PIECES'
#  'PHOTRONIK CONTROLLER 230VAC 50HZ 0.9A ' 'PHOTOSENSOR 3WIRE'
#  'PHOTOELECTRIC SENSOR, PNP, NO/NC' 'PHOTOELECTRIC SENSOR, 250V'
#  'PHOTOELECTRIC SENSOR TANSMETTER+RECIEVER, SENSEING DESTANCE=5M'
#  'PHOTOELECTRIC SENSOR TANSMETTER, M8., 4PIN'
#  'PHOTOELECTRIC SENSOR RECIEVER,PNP/NPN, NO/NC'
#  'PHOTOELECTRIC SENSOR FOR ADAPTION OF FIBER-OPTIC CABLES '
#  'PHOTOELECTRIC RETRO-REFLECTIVE SWITCH, RANGE 6M'
#  'PHOTOELECTRIC RETRO REFLECTIVE SENSOR,RANGE=0.1 TO 0.6M'
#  'PHOTOELECTRIC RETRO REFLECTIVE SENSOR, NPN'
#  'PHOTOELECTRIC RETRO REFLECTIVE SENSOR, NO'
#  'PHOTOELECTRIC RETRO REFLECTIVE SENSOR, M18,NO,RANGE=0.1 TO 0.3M '
#  'PHOTOELECTRIC RETRO REFLECTIVE SENSOR, 0 TO 0.3M'
#  'PHOTOELECTRIC HEAD TRANSMITTER' 'PHOTOELECTRIC HEAD RECIEVER'
#  'PHOTOELEC REFLEX SENSOR, NC+N0, RANGE=3M'
#  'PHOTOELEC REFLEX SENSOR, NC+N0, RANGE=2M' 'PHASE SHIFT CONTROL DEVICE '
#  'PENUMATICE HOSE POLYURTHAN 8X5,150PSI, 15M'
#  'PENUMATICE HOSE POLYURTHAN 6X4,150PSI'
#  'PENUMATICE HOSE POLYURTHAN 12X8,150PSI'
#  'PENUMATIC/ SPRING, BUTTERFLY VALVE , NC, S.S'
#  'PENUMATIC SINGLE SOLENOID, 2 POSITION  , 24VDC'
#  'PENUMATIC FILTER WITH REGULATOR, 5µM, 0 TO 10 BAR'
#  'PENUMATIC CYLINDER SET' 'OVERLOAD RELAY, 42 TO 55A'
#  'OUTPUT UNIT 16 POINT, TRANSISTOR PNP' 'OUTPUT MODULE DIGITAL'
#  'OUTER TRIANGLE OF CLOTHING STATION '
#  'OPTO-COUPLER MODULE, I/P 53VDC, O/P53VDC, 4 A'
#  'OPTO-COUPLER 6.2MM, 24VDC, 2 A' 'OPERATOR KEYPAD MODULE, 8 BUTTONS'
#  'OPERATION PANEL FOR SIMATIC S7' 'OPERATION PANEL FOR PESTER PAC'
#  'OILSEAL BROWN, ISP1D, 60*80*7/7.9' 'OILSEAL BLACK 170X200X15'
#  "OILSEAL 8'', 217.5*197*2, SILICONE " 'OILSEAL , 40*55*10' 'OILSEAL'
#  'OIL SEAL, 30*42*9,BUTADIENE-NITRILE RUBBER' 'OIL SEAL SET'
#  'OIL SEAL 19*27*4, POLYAMAIDE AND PU' 'OIL SEAL ,60*80*8, NBR'
#  'OIL SEAL , 60*80*7, ' 'OIL SAE 15W40 API CJ-4C1-4/SM'
#  'OIL MOLY ULTRA RED GREASE NO.2' 'OIL FOR VACUME PUMP'
#  "OIL FILTER, 3/4'', FOR FORKLIFT" "OIL FILTER, 3/4''" 'O RING, 80*3MM'
#  'O RING, 6*1MM, EPDM' 'O RING, 12.3X2.4' 'O RING T=1.78, NBR'
#  'O RING SILICONE STRING Ø6MM, L=1436MM, GLUED' 'O RING SET FOR FORKLEFT'
#  'O RING SEAL HEATING TANK POS7' 'O RING 85*3MM ' 'O RING 6*0.78, EPDM'
#  'O RING 3*1MM, L=925MM' 'O RING 189.87*5.33MM' 'O RING 14*1.5MM, EPDM'
#  'O RING 12*3MM, SILICON, RED' 'O RING 11.1*1.78, EPDM'
#  'O RING , DN15*4.5, DIN11851' 'O RING ' 'O RING'
#  'NON TOXIC  AL LUBRICANT'
#  "NON RETURN VALVE WITH CLAMP, 1/2 X 1/2'', 12 BAR"
#  "NON RETURN VALVE WITH CLAMP, 1 1/2'',S.S"
#  'NON CONTACT MAGNITIC SAFETY SWITCH, 1NO+1NC'
#  'NETWORK CABLE RJ45/IP20 - 85445190' "NEEDLE VALVE , 3/4,'' S.S"
#  'NEEDLE ROLLER BEARING, 20X35X17MM' 'NEEDLE ROLLER BEARING, 12x24x14MM'
#  'NEEDLE ROLLER /ANGULAR CONTACT BALL BEARING, 15X28X20MM'
#  'MULTIFUNCTION CONTROL RELAY, 3Ø, 183 TO 528VAC, 5A'
#  'MOTOR, 3Ø, 0.75KW, 2A, IP55' 'MOTOR FEEDBACK ,7-12VDC, '
#  'MOTOR CONTROLLER, DC PWM,U1=28V, U2=0 TO 24V '
#  'MOTOR CONTROLLER SINGLE DRIVE, I/P MAX 700VDC, 24A, O/P 3Ø, 9A, 0-599HZ'
#  'MOTOR 6A, 8.5NM' 'MOTION CONTROLLER 8AXIS , 8DISCRETE I/P, 24VDC'
#  'MINIATURE PHOTOELECTRIC , PNP, M8 CONNECTION, SENSING >10M - 84879059'
#  'MINI RELAY 6A, 24VDC - 84229090' 'MINI RELAY 6A, 24VDC'
#  'MINI ISO CYLINDER, BORE =25MM, 25MM STROKE'
#  'MINI ISO CYLINDER, BORE =20MM, 80MM STROKE'
#  'MINI ISO CYLINDER, BORE =20MM, 300MM STROKE' 'MICRO SWITCH, NO+NC, 15A'
#  'MICRO SWITCH PS 1041 303 PHM' 'MICRO SWITCH FOR FORKLEFT, 10A, 250VAC'
#  'MICRO MOTOR CONTROL BOX I/P 1~30VA,O/P 3-30VDC,0.3A'
#  'METAL KNEES 083081' 'MEMBRANE ELEMENT FOR RO UNIT'
#  'MECHANICAL SEAL FOR CH 6247 PUMP' 'MARK II MANOMETER 250 Pa'
#  'MANUAL MOTOR STARTER, 10 TO 16A' 'MANUAL MOTOR STARTER, 0.9 TO 1.25A'
#  'MANUAL MOTOR CONTROL,3P,  9 TO 14A'
#  'MANUAL MOTOR CONTROL,3P,  1.6 TO 2.5A'
#  'MANUAL MOTOR CONTROL , 2.5-4A, 400V, 1.5KW'
#  'MANUAL MOTOR CONTROL , 1-1.6A, 400V,0.55KW'
#  'MANOMETER WITH ANALOG INDICATOR , 0 TO 10BAR'
#  'main real Clutch KEP 09P1300011724VDC' 'main index shaft '
#  'MAGNITIC SAFETY SENSOR, 1NO,1NC, 24VDC,1W, 100MA'
#  'MAGNITIC DOOR CONTACT SWITCH  WITH MAGNET, S.S,76*13*25MM, SPDT'
#  'Magnetic Reed switch ,2 wire, 24VAC/DC, 0.5m'
#  'MAGNETEC FLOAT SWITCH, IP65, 230VAC/DC'
#  'MAGNEHELIC PRESSURE GAUGE 60 Pa' 'MAGNEHELIC PRESSURE GAUGE 500 Pa'
#  'MAGNEHELIC PRESSURE GAUGE 250 Pa'
#  'M12 CONNECTOR 4 PIN FEMALE WITH CABLE LED 10M , 24VDC/4A'
#  'M12 CONNECTOR 4 PIN FEMALE' 'LUBRICATING OIL FOR PAPER SHREDERS'
#  'LUBRICATING FLUID FOR KEMET PRODUCTS TYPE OS' 'LOTOTO CARDS'
#  'Long Manual Leaflet real shaft ' 'LOCKOUT STATION - LOTOTO'
#  'LOCKOUT - TAGOUT SAFETY KIT - LOTOTO' 'LOCK AND KEY - LOTOTO'
#  'LOAD CELL, S.S 22KG' 'LITHIUM PLC BATTERY, 1.7AH'
#  'LITHIUM BATTERY, 3V, 950MAH' 'LINEAR BUSHING, 16X26X36M'
#  'LINEAR BUSHING, 12X22X32M' 'LINEAR BUSHING BALL BEARING, DI=20MM'
#  'LINEAR BUSHING BALL BEARING, DI=16MM'
#  'LINEAR BUSHING BALL BEARING, 30X47X68MM'
#  'LINEAR BUSHING BALL BEARING, 25X35X40MM'
#  'LINEAR BUSHING BALL BEARING, 16X26X36MM'
#  'LINEAR BUSHING BALL BEARING, 12X22X32MM'
#  'LINEAR BUSHING BALL BEARING, 10X19X29MM' "LINEAR ARRAY, 4'',RED, 24VDC"
#  'LIMIT SWITCH, NO/NC, 5A, 250VAC' 'LIMIT SWITCH, NO/NC, 5A, 230VAC'
#  'LIMIT SWITCH MECHANICAL, IP54, 15A@250VAC, 2N0+2NC'
#  'LIMIT SWITCH , IP65, 220V,3A, N0/NC' 'LIMIT SWITCH , 220V, 2A, N0/NC'
#  'LIGHT TOUCH CONTACT ELEMENT'
#  'LEVEL INSTRUMENT CAPACITIVE , HYDROSTATIC, SILOMETER'
#  'LENS 12.5MM, F/1.4 VGA'
#  'LED T8-120 CM - 18W - COOL DAY LIGHT - G13 - (1 PACK = 25 LED)'
#  'LED LAMP 9W 6500K / 60CM' 'LED LAMP 9W  6500K / 60CM'
#  'LED LAMP 5W  6500K / SPOT' 'LED LAMP  8.8W 6500K E27'
#  'LED FLOOD LIGHT 200W  2400 LUMEN'
#  'LATHE 1/4HP, 1Ø, 1.6A, 2 SPEED , 2 SHAFTS' 'LAMP, 3W, 130V' 'KEY SET'
#  'KEY OPERATION SWITCH ' 'KEY FOR LIMIT SWITCH'
#  'Inverter, I/P 1~,3.7A,O/P 3~,2.4A,0.95KVA, 0-400HZ'
#  'Inverter, 3Ø, 0.75KW' 'Inverter, 0.75KW, 240V,4A'
#  'Inverter MICROMASTER 440 WITHOUT FILTER, 3Ø,  0.75KW'
#  'Inverter L100 Series' 'Inverter  SJ100 SERIES'
#  'Intermediate Piece 16 Bar , DIN50 , PN40' 'INTER PHONE '
#  'INPUT MODULE 3DI476.6 16E'
#  'INFLATABLE GASKET , UNFOLDING U-SHAPED, SILICONE'
#  'INFLATABLE GASKET , UNFOLDING U-SHAPED , SILICONE, 35X32MM'
#  'INDUSTRIAL CONNECTOR, 6PIN, 16A, M+F' 'INDUSTRIAL 3D VISUALIZATION UNIT'
#  'INDUCTIVE PROXIMITY SWITCH, PNP, NO'
#  'INDUCTIVE PROXIMITY SWITCH, PNP, NC'
#  'INDUCTIVE PROXIMITY SWITCH, NPN, NO'
#  'INDUCTIVE PROXIMITY SWITCH, NPN, NC'
#  'INDUCTIVE PROXIMITY SWITCH, NON FERROUS TARGET, NO'
#  'INDUCTIVE PROXIMITY SWITCH, NC, M8'
#  'INDUCTIVE PROXIMITY SWITCH, NC, M18'
#  'INDUCTIVE PROXIMITY SWITCH, NC, M12'
#  'INDUCTIVE PROXIMITY SWITCH, M8, PNP, NO'
#  'INDUCTIVE PROXIMITY SWITCH, M12, PNP, NO/NC'
#  'INDUCTIVE PROXIMITY SWITCH, M12, PNP, NO'
#  'INDUCTIVE PROXIMITY SWITCH, M12, NPN, NO'
#  'INDUCTIVE PROXIMITY SWITCH, M12, NAMUR, NC'
#  'INDUCTIVE PROXIMITY SWITCH , PNP, NO/NC'
#  'INDUCTIVE PROXIMITY SWITCH - M8 - 3RG4011-0AG05-PF'
#  'INDUCTIVE PROXIMITY SWITCH '
#  'INDUCTIVE PROXIMITY  SENSOR M12,PNP,NO - 90318034'
#  'INDUCTIVE PROXIMITY  SENSOR M12,PNP,NO - 84229090'
#  'INCLINED TUBE MANOMETER ' 'IMPELLER 40-200/210 CI'
#  'IMAGE BASED ID READER' 'IMA GREEN BELT' 'HYDRAULIC OIL H-1 ISO-150'
#  'HYDRAULIC DOOR CLOSSER'
#  'HOSE, SILICONE, WITH TEXTILE REINFORCEMENT, WHITE PLATINUME CURED'
#  'HOSE WITH FABRIC LINING L=2.7, 19*4MM FOOD GRADE +NIPPLES+COUPLING'
#  'HOSE 3/4 W.P=30BAR ' 'HIGHBAY LED 160W 220V 20000 LUMINE '
#  'HIGH TEMPERATURE FILTER UPTO 120C, 592*592*292MM, 4250M3/H '
#  'HEPA FILTER, 610*1220*69, 0.3µM,0.4M/S' 'HEPA EXUAUST FILTER, H13'
#  'HELICAL POTENTIOMETER 10KOHM'
#  'HEATTING ELEMENT 9KW, 400V, 13A, L=335, WITH 2.2M CABLE'
#  'HEATING ELEMENT, 750W, 230V, S.S' 'HEATER 3~,9000W, 13A, IP50'
#  'HEATER 3~,8000W' 'HEATER , 2 WIRE' 'Hand Pallets Wheels  (Rubber Cover)'
#  'Hand Pallets Load Rollers 167607' 'GROUP MARKER CARRIER, '
#  'GROUP LOCK HASPS - LOTOTO' 'GROUP LOCK BOX - LOTOTO'
#  'GROUNDING CABLE, 1.3MM, WITH MOUNTING SET' 'GREASE NLG1 NO.2'
#  'GLASS FIBER OPTIC CABLE, THROUGH BEAM MODEL'
#  'GEARED MOTOR, 24VDC, 25.1W' 'GEARED MOTOR 3Ø, 2.2KW, 4.7A, 1410/64 RPM'
#  'GEARBOX , WITH S.S SHAFTS' 'GEARBOX , RATIO 1/7'
#  'GEAR OIL  H-1 FOOD GRADE ISO 320'
#  'Gear Lubricant ISO-220 , API GL-5 MT-1 PG-2'
#  'GEAR LUB OIL ISO 460 , API GL5 MT-1 PG-2' 'GEAR BOX IMA GIANT 1'
#  'GASKET, DN300, U PROFILE, 5/9*10 ' 'GASKET RING Ø125XØ107X1MM, SILICONE'
#  'GASKET RING FILTER DN400 WITH INLAY '
#  'GASKET Ø14MM, FABRIC FILTER, SILICONE' 'GASKET KIT'
#  'GASKET DN100, SILICONE' 'GASKET DISCHARGE ' 'GASKET'
#  'FUSE 1A, 6.3X32MM, CRAMIC' 'FUSE 1A, 5X20MM, GLASS'
#  'FUNCTION MODULE, 13 PIN' 'FRONT CONNECTROR FOR S7-300, 40 POLE'
#  'Frequency Converter with Trip Values KFD2-UFC-Ex1.D'
#  'FORK PHOYOCELL, 10-30VDC, PNP/NPN - WF2-40B416'
#  'FLUORESCENTS TUBES T8-150 CM F58W/35'
#  'FLOWMETER OF BATCH CONTROLLER, 4-20MA,12-36VDC'
#  'FLOW MONITOR SENSOR , M18, IP67'
#  'FLOW ELECTRONIC MODULE , PNP, 12-36VDC, 0.7A, 0.3-10M/S'
#  'FLOW  ASSEMBLY FOR PH/ORP SENSORS' 'FLOROCENT 60CM 20W'
#  'FLOOD LIGHT 150W' "FLEXIBLE HOSE 1'', GRAY, 3M, FOR VACUUM CLEANER"
#  'FLASH BOX FOR CAMERA SYSTEM' 'FLANGE GASKET , GCM I, EXHAUST SHOE'
#  'FLANGE 061 216 WITH STANDARD PARTS'
#  'FIXED CASTOR D200, WITH SPRING SYSTEM '
#  "FIRE ANGLE HOSE VALVE 2  1/2''  618R" 'FIRE ALARM WATER FLOW DETECTOR'
#  "FILTER CARTAGE,20'', 5µ, POLYPROPYLENE"
#  'FILTER CARTAGE, PAPER, 64X38X70MM'
#  'FIELD METROLOGY WELL CALIBRATION 200C TO 962C' 'FIBER-OPT NPN/PNP'
#  'FIBER OPTIC AMPILIFIER,NPN, M12, NC+NO, M12'
#  'FIBER OPTIC AMPILIFIER, NPN, WITH TIMER, INCLUDING SIDE PLATE'
#  'FELT PADS FOR PUNCH HEADS, 19MM' 'FAN MOTOR 220-240VAC - 0.09A'
#  'FAN MOTOR 220-240V - 0.08A' 'F INSERT CRIMP, FEMALE, 40PIN'
#  'ETHERNET SWITCH , 8XRJ45' 'ENERGETIC DIFFUSE SENSOR, PNP'
#  'END AND INTERMEDIATE PLATE' 'ENCODER, STEPS=8192' 'ENCODER, STEPS=360'
#  'ENCODER, STEPS=256' 'ENCODER TYPE D, RS422'
#  'ENCODER SINGLE TURN, 13BIT, FLAGE SOCKET'
#  'ENCODER ,STEPS=32768 - CEV582S-90041' 'ENCODER , LIKA '
#  'EMERGENCY STOP RELLAY CONTROLLER, 24VDC' 'ELECTRONIC POSITION INDICATOR'
#  'ELECTRONIC CARD KRINT V5.1 GWK' 'ELECTRONIC CARD KRANL V2.0'
#  'ELECTRONIC CARD KRADC V1.1' 'ELECTRONIC CARD'
#  'Electronic Board for VFD ' 'ELECTROMAGNITIC PANEL BUZZER, 24VDC'
#  'ELECTROMAGNETIC MOTOR BRAKE 24V, 38W'
#  'ELECTRIC SOLENOID ACTUATOR, 24VDC, 1A, '
#  'ELECTRIC PLASTIC HOSE WITH END GLANDS M20X1.5'
#  'Electric Contact Gauge,WITH HIGH/LOW SWITCH' 'Electric Contact Gauge,'
#  'EARTH STRAP WITH END TERMINALS, 30CM' 'DOUBLE SIEVE INSERT'
#  'DOUBLE DRIVE CONNECTOR AND SERCOS CABLE'
#  'DOUBLE ACTING CYLINDER, PISTON DIA25MM' 'DOOR LOCK WITHOUT KEY'
#  'DOOR LEVER HANDLE ' 'DOOR CLOSER SLIDE ARM&CHANNEL'
#  'DOOR CLOSER CAM ACTION' 'DISTRIBUTION BOX IN WALL, 2-4 GANG, PLASTIC'
#  'DISTRIBUTION BOX  165*220*108 ,IP20'
#  'DISPLACEMENT LINEAR POSITION TRANSDUCER '
#  "DISC ASEPTIC DIAPHRAM VALVE . S.S, 3/4''" 'DIODES MODULE, 10 DIODES'
#  'DIGITAL TEMPERATURE SWITCH PROBE, PTC, -50 TO 105 C'
#  'DIGITAL PRECISION SETTING KNOB' 'DIGITAL INPUT/OUTPUT MODULE FOR S7-200'
#  'DIGITAL INPUT MODULE '
#  'Differential Pressure Gauge for Filter, Max 16 Bar'
#  'DIAPHRAGM, DN50, EPDM' 'DIAPHRAGM, DN25, EPDM' 'DIAPHRAGM, DN20, EPDM'
#  'DIAPHRAGM, DN15, EPDM'
#  'DEVICE SOCKET 2+PE FOR PENUMATIC VALVE , 10A, 250VAC, LED'
#  'DEVICE SOCKET 2+PE FOR PENUMATIC VALVE , 10A, 250VAC'
#  'DESK TOP SCREEN  THINKVISION'
#  'DEFFERENTIAL PRESSURE RANGE -3000TO3000 PA'
#  'DEEP GROVE BALL BEARING, 60X110X22' 'DEEP GROOVE BALL BEARING,15X24X5MM'
#  'DEEP GROOVE BALL BEARING, 8X22X7MM' 'DEEP GROOVE BALL BEARING, 6X19X6MM'
#  'DEEP GROOVE BALL BEARING, 5X16X5MM'
#  'DEEP GROOVE BALL BEARING, 45X100X25MM'
#  'DEEP GROOVE BALL BEARING, 40X80X18MM'
#  'DEEP GROOVE BALL BEARING, 35X80X21MM'
#  'DEEP GROOVE BALL BEARING, 35X72X17MM'
#  'DEEP GROOVE BALL BEARING, 30X62X16MM'
#  'DEEP GROOVE BALL BEARING, 30X55X13MM'
#  'DEEP GROOVE BALL BEARING, 30X42X7MM'
#  'DEEP GROOVE BALL BEARING, 25X62X17MM'
#  'DEEP GROOVE BALL BEARING, 25X47X12MM'
#  'DEEP GROOVE BALL BEARING, 20X52X21MM'
#  'DEEP GROOVE BALL BEARING, 20X52X15MM'
#  'DEEP GROOVE BALL BEARING, 20X47X14MM'
#  'DEEP GROOVE BALL BEARING, 20X42X12MM'
#  'DEEP GROOVE BALL BEARING, 17X47X14MM, S.S'
#  'DEEP GROOVE BALL BEARING, 17X35X4MM'
#  'DEEP GROOVE BALL BEARING, 17X35X10MM'
#  'DEEP GROOVE BALL BEARING, 15X42X13MM'
#  'DEEP GROOVE BALL BEARING, 15X35X11MM'
#  'DEEP GROOVE BALL BEARING, 15X32X9MM'
#  'DEEP GROOVE BALL BEARING, 12X32X10MM'
#  'DEEP GROOVE BALL BEARING, 12X28X8MM'
#  'DEEP GROOVE BALL BEARING, 10X30X9MM'
#  'DEEP GROOVE BALL BEARING, 10X26X8MM'
#  'DEEP GROOVE BALL BEARING, 10X19X5MM'
#  'DC BRUSHERLESS FAN MOTOR 24VDC 0.36AMP' 'DATA CABLE'
#  'Current value transformer KFD2-CD-1.32' 'CUPPER CURVES AND DEVICE'
#  'CUPPER BAR FOR STRIPPER , P2000/2100' 'CROSS CLAMP WITH LEVER 25X25MM'
#  'CPU MODULE FOR S7-200' 'CPU CARD' 'CPU + SOFTWARE FOR ECOGRAPH T RSG35'
#  'COVER FOR 60*60 LED PANEL UNIT' 'COUPLING SOCKET, 6+PE,  10A, 250V'
#  'CONVEYOR BELT GG 40 U' 'CONVENTIONAL DOOR CLOSER, MAX 60KG'
#  'CONTROL BOX WITH SCREEN' 'CONTROL BOARD'
#  'CONTACTOR, 3Ø, 90KW, 400V,2C+2N0' 'CONTACTOR, 3Ø, 75KW, 400V,AC'
#  'CONTACTOR, 24VDC, 3Ø,  4KW, 1NO' 'CONTACTOR, 24VAC, 3Ø, 7.5KW, 400V,1NC'
#  'CONTACTOR, 24VAC, 3Ø, 4KW, 400V,1NC'
#  'CONTACTOR COMBINATION FOR SAFETY CIRCUITS,24VDC'
#  'CONTACTOR , FOR FORKLIFT, 24V, WITH TERMINALS'
#  'CONTACTOR , 4KW, 400VAC, 9A' 'CONTACTOR , 400VAC, 3Ø, 7.5KW, 1NO '
#  'CONTACTOR , 230VAC, 3Ø, 30KW, 1NO+1NC'
#  'CONTACT BLOCK, 250VAC, 6A, 8 PIN' 'CONTACT BLOCK, 250V, 1.5W'
#  'CONTACT BLOCK REED, 1NO' 'CONNECTOR, 230-363A' 'CONNECTOR >PC-GF20<'
#  'CONNECTION FOR VALVE CABLE 3MT'
#  'CONNECTING CABLE  5M.FOR SOLENOID VALVE VIA M2 ,IP65, W/ LED'
#  'CONDUCTIVITY TRANSMITTER/Liquisys M +PT100'
#  'CONCAVE DIAPHRAGM, DN32-40, EPDM' 'CONCAVE DIAPHRAGM, DN15-25, EPDM'
#  'CONCAVE DIAPHRAGM, DN12, EPDM' 'COMPLETE UNIT LEAFLET FEEDER'
#  'COMPLETE CLUTCH UNIT' 'COMPACT PLC CPU, 8DI, 6DO, 2AI , FOR S7- 1200'
#  'COLOR SENSOR , PNP,5 PIN,  M12 - CS81-P1112'
#  'CLEAN ROOM HEPA AIR FILTER 610X610X69 0.3µm'
#  'CLEAN ROOM AIR FILTER 610X1220X69 0.3µm' 'CLAMPING MODULE, P MAX=8BAR'
#  'CLAMP TERMINAL SOCKET, 10A' 'Circuit-breaker, 3p, 200A'
#  'Circuit-breaker, 3p, 160A' 'Circuit-breaker, 3p, 160'
#  'CHLORINE FREE AND TOTAL HR REAGENTS SET'
#  'CERCLE ILLUMINATION 126X126X13 FOR TELECAMERA'
#  'CAT6 CABLE COMMUNICATION CABLE, AWG23'
#  'CAT6 CABLE COMMUNICATION CABLE, 24AWG.75C'
#  'CARTON METAL FINGERS OF CARTON CHAIN ' 'CARBON PUMP VANES, 95X43X4 MM'
#  'CARBON BRUSH SET 10X25X20' 'CARBON BRUSH FOR FORKLIFT'
#  'CAPACITIVE PROXIMITY SWITCH , PNP, NO' 'Camozzi Filter regulator 16 Bar'
#  'CAMERA, 0.8 MP, GIGABIT EATHERNET , RJ45' 'CAMERA LENS 50MM, F/1.4 USM'
#  'CAMERA LENS 40MM, F/2.8 STM' 'CAM SWITCH MODULE '
#  'CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIAL GUIDANCE, 6X16X11MM'
#  'CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIAL GUIDANCE, 12X30X40MM'
#  'CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIAL GUIDANCE, 12X30X14MM'
#  'CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIAL GUIDANCE, 10X22X12MM'
#  'CAM FOLLOWER, 8X19X11MM' 'CAM FOLLOWER, 6X16X28MM'
#  'CAM FOLLOWER, 6.35X15.875MM' 'CAM FOLLOWER, 22X10X36.2MM'
#  'CAM FOLLOWER, 12X30XM12X1.5' 'CAM FOLLOWER, 12X26XM10X1.25MM'
#  'CABLE 20 X0,5MMQ - LAPP UNITRONIC LIYY - 84229090'
#  'CABINET SCHUKO SOCKET ON OMEGA BAR 16A,250V'
#  'BUTTERFLY VALVE , DN 25 PS 12, 0-90C'
#  'BUTTERFLY VALVE , DN ,PS 12, 0-90C' 'BUSH 050 427 WITH STANDARD PARTS'
#  'BRUSHLESS MOTOR 0.3KW ,400V,1.3A' 'BRECOFLEX Timing Belt 16T10/2400'
#  'BREAK SHOE FOR FORKLIFT' 'BOEX COUPLING'
#  'Black rubber roller for leaflet 315 mm 220mm L'
#  'Black rubber roller for leaflet 210mm 22mm L'
#  "BLACK NYLON HOSE 1/2'' FOR HIGH PRESSURE "
#  'BEVEL GEARBOX SIZE 11O, RATIO 1/1, Ø26H7' 'BEVEL GEARBOX ,GWP'
#  'BELT KIT , FLAT SUPER POWER; 610 x25MM' 'BATTERY MODULE'
#  'BATTERY CHARGER FOR ADFLO/JUPITER,O/P 3-9VDC, 1.5A, 3-pin'
#  'BALL BUSH B-0672-116-40' 'AZ 15/16-B2-1747 RETROFIT KIT '
#  'AXIAL VENTELATION FAN, 8X8CM, 240VAC,0.07A '
#  'AUXILIARY SWITCH BLOCK, 1N+2NC' 'AUTOMATION PC 910'
#  'AUTO REED SWITCH ,SOLID STATE ,PNP'
#  'ASSEMBLY MODULE ,MP6, MOUNTING RAIL SCREW TYPE'
#  'ANGULAR CONTACT BALL BEARING, 12X37X12MM'
#  'ANGULAR CONTACT BALL BEARING DOUBLE ROW, 17X40X17.5MM'
#  'ANALOG ORB SENSOR ELECTROD PLATIN' 'Aluminium product Loader '
#  'AIR FILTER, IFI 596*287*22, G3 (PreFilter)'
#  "AIR FILTER CARTAGE , HIGHFLOW TETPOR H.T 0.2µm,20''"
#  "AIR FILTER , DEMI CARTAGE, 2.5'', 0.2µm "
#  'AIR FILTER , 600X600X125 -Ø250 (PACK OF 3)' 'AIR FILTER'
#  'AIR FILTER for Vaccum pump' 'AILR FILTER ,EMFLON FILTER 0.2µm, 87mmL'
#  'AILR FILTER ,EMFLON FILTER 0.2µm, 20"'
#  'AILR FILTER ,EMFLON FILTER 0.2µm ' 'AILR FILTER ,EMFLON FILTER 0.2µm'
#  'ADJUSTABLE SPEED DRIVE , 1.3KVA,1Ø, 3.3A'
#  'ADAPTER SCREW IN FOR PROCESS SENSOR, M18X1.5/G1/2'
#  'AC SERVOMOTOR 3~AC,94V,1.5A,0.2KW,250HZ,3000RPM'
#  'AC SERVOMOTOR 3~AC,220V,0.89A,100W,3000RPM'
#  'AC SERVOMOTOR 3~AC,114V,2.4A,0.4KW,250HZ,3000RPM'
#  'AC SERVO MOTOR, 3Ø, 120V, 4.1A, 0.75KW, IP67'
#  'AC SERVO MOTOR 400V,250HZ,2.2A,650W,3000RPM'
#  'AC SERVO MOTOR 3~, 78V,250HZ,1.1A,0.1KW,3000RPM'
#  'AC SERVO DRIVER, I/P 1Ø, 4.1A, O/P 3Ø, 400W, 2.6A'
#  'AC SERVO DRIVER, I/P 1Ø, 2.4A, O/P 3Ø, 200W, 1.6A'
#  'AC SERVO DRIVER, I/P 1~,6.6A,O/P 3~, 0-240V, 4.1A, 750W'
#  'AC SERVO DRIVER, I/P 1~,1.6A,O/P 3~, 0-240V, 1.2A'
#  'AC SERVO DRIVE I/P 3~,400V,2.5A,O/P 3~,0-480V,3.5A,1KW'
#  'AC SERVO DRIVE I/P 1~,230V,2A,O/P 3~,90.3V,1.6A,200W'
#  'AC DRIVE, I/P 1~,5A,O/P 3~2.4A,0.37KW, 0-650HZ'
#  'AC DRIVE, 1.1KW, I/P 1Ø, 9.2A, O/P 3Ø, 0-400HZ, 5A'
#  'AC DRIVE ,7.5KW, 17A,3Ø, 0-500HZ, IP21'
#  'AC DRIVE ,11KW, 25A, 3Ø, 0-500HZ, IP21'
#  'AC DRIVE , 15 KW, 32A,3Ø, 0-500HZ, IP21'
#  'ABSOULUTE ENCODER , 360X1 STEPS, 10-32VDC - AG600-460027000000'
#  'ABSOLUTE ENCODER, 24VDC, 360*1 STEPS' '3 POSITION SELECTOR'
#  '240V, 0.75KW, BELT/ WHEEL SIZE 125MM' "2 WAY VALVE , 1/4'', M/F, S.S"
#  '134a REFREGERANT 13.6KG' '1060T10 COVER-GRID ASSY (SPRING COUPLING)'
#  '1 EPDM GASKET + STOPPER + CABLE GASKET'
#  ' RELAY 24VDC, 5A, 14 PINS - MY4 DC24' 'Plate Heater 230 V '
#  'Seat Valve, 3/4",16 Bar']
#
# --------------------------------------------------
#
# Item description column each unique repeated by:
# INDUCTIVE PROXIMITY SWITCH, PNP, NO                 8
# DEEP GROOVE BALL BEARING, 20X42X12MM                6
# DEEP GROOVE BALL BEARING, 6X19X6MM                  5
# INFLATABLE GASKET , UNFOLDING U-SHAPED, SILICONE    4
# LINEAR BUSHING BALL BEARING, 16X26X36MM             4
#                                                    ..
# OVERLOAD RELAY, 42 TO 55A                           1
# OUTPUT MODULE DIGITAL                               1
# OUTER TRIANGLE OF CLOTHING STATION                  1
# OPTO-COUPLER MODULE, I/P 53VDC, O/P53VDC, 4 A       1
# Seat Valve, 3/4",16 Bar                             1
# Name: Item description, Length: 680, dtype: int64
#
# --------------------------------------------------
#
# Part # column has number of uniques : 702
# Part # column has uniques : ['STO12' '1-999-04634' 'BTHL30013' '13-GPT*12T*0002' '12-GPT*12T*0005'
#  '14-GPT*12T*0001' 919202 156259 96457868 'HI-93735-0' 98148805 15
#  'HI93735A-LR' 'JP 4-54 - 99458768' 'DEX Next' 'HI93735IND-0' 'HI93701-0'
#  '1-999-04156' 96457867 '30C1400527 EH' 'LS-1S-GA-1297/7B/46'
#  'CRN 1-13 EY-CX-T-E-HUUE' '943492-9000' 'CC12038S220M' '220ZY-2E'
#  'FB-108 EX-S1-S' '\xa00,047D2MRV-4' 8240200.9101 'SV1040 C000' 'TSC.80'
#  'WSG' 'QS-012' 'S36RL' 53642 'QUNIT-UPS/24DC/24DC/10' 6182118
#  'QUINT4-UPS/24DC/24DC/20' nan 116917 'FP-108-C' 5084177 'TM 15 2.0'
#  'PAT/04' 'HI97735' '12T10_1030' 'L1H002010' 'T10-2250' '150XL037-CR'
#  '960-8M-30' 'T2.5-330' 'TSG 4-V.05' 'ATH-70' '29-999-16650' 'IMA00034'
#  'ZD22042-T0EG00EZ' 'SMART JET ONE' '282-402' '280-402' '282-101'
#  '280-901' 'TOP JOB S' '282-107' '280-907' 904511 136088 'B402997'
#  'TSRT-6702UAB' 'TN7530' 902820.7012 '2AT300.6' 191884 'TCN4H-24R'
#  'TGU-4500' 'THC-P' 'CH-8712 Stafa' 9070766 '1-997-00681' '1-113-00289B'
#  6150096 156281 180997 132960 132959 132958 46903 'R073002000' '67/241-T'
#  3500414 'ZEMTB-020TT-AN3' 6042501 '132L 27MM DI 3MM THICKNESS ' 2149276
#  '20.1533-49' 'EVD533-E' '05.0730-02' '05.0732-02' '3RX4001' 9360151
#  'SO967960' 'RA 2425 -D 06 ' 'RM1A48D100' 'MCH-3-1/4' 'L78EM45GGS00061'
#  'L88EM44GGS00061' 'L22BA452BG00061' 'LV5EM41' 'ARMORVIN' 'USA-2P' 122580
#  '220x50mm almunum Roller ' '220mm/15mm ' '181BA400A0B1661'
#  '181BA400A000061' '031SA4004012B61' '6ES7317-2AJ10-0AB0' '1997-01945'
#  'OR388' '350mm L 690mm Di ' 904594 96488302 'SGMGV-13DDA6H'
#  'SGMGV-30DDA6H' 'SGDV-1R9D11A' 'SGDV-5R4D11A' 'SGDV-3R5D11A'
#  'VF1404MC9PT1BR1_1' 'SCQ2S16-D' 5810218 'CLS21-C1N2D' 'LL3-DB01'
#  '2204 2RS' 2204 '1204 ETN9' '2201-2RS-TVH#E' 'P9MSMD0N' '6EP1961-2BA00'
#  'DIN 7603C' '1-997-05836' 70001643 101152094 773100 475695 751103
#  101120594 774580 92733558 'IDL 12GB16C2J' 'S 31 07-07' 3105241
#  'TopWing TW1/00082 25/02-W12-GW11-EFEF' 'ORIGA SYSTEM PLUS' 'SFG 12'
#  'KI 10 D' 'JAF10' 492075 'LV-H62F' '919BH166700' 'G2R-2' 'G2R-1' 5810539
#  5810117 6152521900 'UL 7.2-12' 'YET 210' 'NA204G' 'IH35641038/50' '30X25'
#  912313 6020075 '013-03344-000' 'CQM1H-CPU51' 'PLS 511 S' '2CP100.60-1'
#  'M600 OEM' 56557 136118 755954 'BR64.CKLC3MHVMXX' 'P31RA12BNTP' 253046
#  801 5055169 'DB50L-EB00BB13CG30' '6EP1436-3BA00' 'CQM1-PA203'
#  'TIS 75-124' 'BED-48024' '40.52.9.024.0000' '2PS740.9' 'FN256-64-52-H'
#  189783 '3RT10251BB44' 'B84114-D-B30' 231232 '9600-601-4' 'LS-11' 909003
#  'TBC 32x80' 'B32-7112B-80' '7000-12411-2341000' "B10THX30/1P-SC-S 4X1''"
#  70000296 'Alpha 823' 'PS364-2' 'DL Z-S30-PN' 'FAI7/BP-1A' 'S41-2-C-P'
#  'CAR-30X' 'PE-T5D' 'S3Z-PR-5-M01-PL' 'S3Z-PR-5-FG01-PL' 'FMS 18-34 U'
#  50022680 'WL170-N420' 'FPDK 10N5101' 'MVC/A0-0A' 'E3F-DS30Y1' 'CR-30X'
#  'RK 18/4 G,4000' 'PS-52T' 'PS-52R' 'UF87PA3' 'HN22PA3' '33 43303B00' 805
#  604 '6X4' 1280 102.095 'B5E6ACA49C' 'LFR-M2-G3/8-C10S' 900279 'RT2G'
#  'CQM1-OD214' '2DO428.6' '150MM L' 50044 526059 'E82ZBC'
#  '6AV3617-1JC20-0AX1' 'PCS095 M PLUS' '60*80*7/7.9' 'A170X200X15'
#  '102093-010' 9200055835 102091.0004 'UP 30 42 9' 243927 'SD 19X27X4 B'
#  'BAU4SLX2' 'TPYDCB2355' '700 CJ SUPEREME 7000' 229 '520-509/01' 531000001
#  531000002 '1-977-00447' '1-999-10976' 903130 'M08010103' '1-997-05838'
#  230275 3250098 '1-997-00447' '1-997-00425' 40989 '1-997-03778'
#  '1-999-10757' '1-999-08222' '1-999-01859' '1-999-14861' '1-997-00644'
#  9520 'B596218' '620-50-P5' 11691 '048Z60150PT121' 1059411 6053787
#  '049Z60075PT121' 'NAO 20X35X17' '4901-2RS' 'NKIB5902' 'RM17-TE00'
#  'LSMV80LT' 'SFS60-HRATZS01' 'BV3.815K3' 'BV3.815K2' 'LXM62DD27C21020'
#  'ML34FN47060M8L4' 'LMC201C' 6002803 6400117 'P1A-S025MS-0025'
#  'P1A-S020DS-0080' 'P1A-S020DS-0100' 'P1A-S020DS-0300' 'P1A-S020DS-0160'
#  'BZ-2RW84-A2' 903931 156278 'UC503C' 83081 'FILMTEC BW30-4040 DRY'
#  '3A2-001-19KIEC1' '3A3-001-28KKE01' '40-250Pa' 'SFK0K' '3RV2011-0KA10'
#  'GV2ME16' 'PKZM0-2,5' 'PKZM0-4' 'PKZM0-1,6' ' KEP 09P1300011724VDC'
#  '335mm L x 20mm ' 101120670 '2507A-L' 'ELS-AA 9010038' '2000-60Pa'
#  '12-340001-00' '71-340001-0 ' '7000-12291-2341000' 'M12' '1.235.997.401'
#  301103 '475mm L 750mm Di' 'EP-B101' 'AG01743' '3G2A9-BAT08' 'CR2477N'
#  'LME162636\xa0' 'LME122232' 'KB20GUU' 'KB16GUU' 'KB3068-PP' 'KH25-B'
#  'KB 16 G' 'LME 16 UU' 'LME162636 NUU' 'LBE16' 'LME 122232 N'
#  'LME122232 UU' 'LM101929 UU' 'AL4424' 'ME-8104' 151155769 '055.000.5'
#  'L5K13MEM123' 'WLCA12-2' 912321 'Silometer FMC671Z' 'FL-BC1214D-VG'
#  'ELED8651318' 'T8' 'MR16' 'E27' 'Floodlight 200W' '26 ESK' 'BA9S T10'
#  909761 'QRJSSA12E' 'XCKY02' 'LSLV0004M100-1EOFNS' '195N1015'
#  'E82EV751K2C' '6SE6440-2UD17-5AA1' 'L100-004NFE' 'SJ100-004NFE' 'CF8M'
#  'TP-1L' 913335 '04-0070-08' '1-952-20190-0' '1-999-10335' '04-0079-26'
#  '1-105-00459D' '6M' 'HRC_S24' 'IBCT-1214' 'NBB4-12GM50-E2-5M'
#  'NBB2-12GM40-E2-V1' '18GM50-E2-V1' 'IF5345' 'IN5370' 'HYP-12R 4PA'
#  'DW-AS-503-M30-002' 'ILCT1215' 'ILLI1214' 'ILCT 1213' 'NJ3-18GK-S1N'
#  'NJ1,5-8GM-N-5M' 'NCB5-18GM40-N0' 'NCN4-12GM35-N0' 'AE1-AP-2A'
#  'BES 516-113-BO-C-03' 'BES 516-113-S4-C' 'XS212BLPAM12' 'AM1/AN-1A'
#  'NCB2-12GM35-N0-V1' 'IN5028\xa0/ IN-3004-FPKG' 6022432 '3RG4210-7AG00'
#  33877 6003098 6022113 6552001000 96039185 'MATRIX 210 212-110 SB4494'
#  'B472476' '0269150 - 005' 'D720' 'GSI 65NT-FDA' 'OCO601716EH' '160W'
#  'COMATEX FP-F61592-HT' 'M575-233-008' 21738000 908661 9050262 'E112303'
#  '9050262\xa0' 202430 281920 8619 '249-119' '1-105-00215'
#  '229 ULTRA RED SUPEREME' 'SLK2226' 912694 'R57DV100M4/BMG/HR/TF'
#  'NRVS016163' 276 '268 moly ss' '286 MOLY SS ' '1-997-01944' '1-997-04183'
#  '1-997-01427' '1-997-01946' '139034 BT' 'PB 139032' '1-997-00198'
#  '028 15296 000' 3230175 3230171 'T1A' '50F F1AL' 'E82ZAFSC100'
#  '6ES7922-3BD20-5AC0' 188370 6028450 '29575/37627' 'SE35/8035' 'SI1000'
#  'SE32/8032' 'CPA250-A00' 'FL20T9/19' '1INCH HOSE' 'B1450' '3-740-01430A'
#  70000810 '1-113-00289A' 'A56\xa0' 'WFD30' 'RM2F050H21' 90950500000 9171
#  'S5-5-E1-30' 'UM55PA2' 'FS-M1' 3100493 '2082HSL' 'FD1238A2HSL'
#  'HAN 40D-F' 1240900000 'RK 72/4-200' 'RK 93/4-20 S,6000' '280-312'
#  '2016-1291' 282 6362018 'ARS60-G4Z0-S02' 'AS508/GY-6-Z/S412'
#  'DIG 58D-2500-AB-105-SC8-D78' '6FX2001-5QS12' 6362135
#  'AS58S12/GS-10-R/S625' '18813647\xa0' 'AP05' 9071114 9070459 9070880
#  'CQM1-ME08K' 9070747 'HRB-PS30' '6/500.100' '70-134' 'AISI316'
#  'EARTH-STRAP' 3450050 'VW3E6002' 2469 '72X60' 'DDTH002' 64010001 42020101
#  '2-4 GANG' 'BR 806' 'JX-EP-60-70282' '061A60075PT70' 36649 'TS-51' 912690
#  '6ES7223-1BH22-0XA0' '3DI476.6' 'PD120' 'DD20-ITFM' 'DD10-ITFM'
#  'DD07-ITFM' 'DD05-ITFM' 2004087 1258133 '9227-AG1' 'Delta bar PMD75'
#  '6212-2NSE' '6802 ZZ' '608-2RSH' '608-2Z' '626-2Z/C3' '626-2RSH'
#  '626-2RS1' '626-2RSH/C3' '626-Z' '625-2Z/C3' '6309-2RS1/C3' '6208-2Z/C3'
#  '6208-2RS1/C3' '6307-2Z/C3' '6207-2RS1/C3' '6206-2RS1' '6006-2RS1'
#  '61806-2RS1' '6305-RS1' '6005-2RSH/C3' '62304.2RSR' '6304-RS1' '6204D'
#  '6004-2RSH/C3' '6004LLU/5K' '6004LU' '6004-C3' '6004D' '6004.2ZR.C3'
#  '6303-2z-v14-17' '63003-2RS' '6003-2RSH/C3' '6003-2Z/C3' '6302-2Z/C3'
#  '6202-2RSH/C3' '6002-2RSH/C3' '6201-2RSH/C3' '6001-2Z/C3' '6001-2RS1'
#  '6200.EE' '6200-2RSH' '6000-2RSH/C3' '6000-2Z/C3\xa0' '6800 RS'
#  '61800-2Z' 'FP-108/DC' 9180192 104218 3500408 3100411 'WLK610401'
#  '6ES7216-2AD23-0XB0' 'B12' 'XPR0008-1009/0' 'T3104 001' 70166 60150
#  109836013 'QK-CE220' 'DILM185-S/22' 'DILM150(RAC240)' '3RT1016-1BB41'
#  '3RT1025-1AC20' '3RT2016-1AB02' '3TK2804-0BB4' 135654 'XTMC9A10'
#  'CL02A310TU' 'CL07A311MN' 'AT2' 'AL5' 'P9B10FH' 909948 '7202001-01'
#  6600174 8047680 'CLM223' 'Diaphragm code 13' '6ES7212-1AE40-0XB0' 1028224
#  'M575-233-005' 'AV-35-2-SA' 95.05 '95.85.3' 'NZMB2-A200' 'NZMB2-A160'
#  'NZMN2-A160 ' 'HI93734-01' '7965E.K1305' 'NK6' 'SET OF CHAIN '
#  90135200007 7509136 161611 128636 'BCS030PS1CS4' 'MC202-D10' 'TXG08C'
#  'EF 50mm f/1.4 USM' 'EF 40mm f/2.8 STM' '2DS100.60-1 ' 'KR16-NMT'
#  'KR16-PP-A' 'KR 30' 'KR30-PP-A' 'KR30-PP' 'KR 22' 'KR19-PP-A-NMT' 'CF8'
#  'CF6' 'CR10' 'KR22 PP' 'CF12' 'CF10' 6011492 680572 'VSM0073049'
#  'VSM0073052' 70002956 'SGMEV-03DDA61' 70207 174967 3700955
#  '220mm 315mm dimater ' '220mm 210mm dimater ' 'DASH 10' 'RS00110 '
#  'GWP 14W' '610x25' '6EP1935/6ME21' '003-00-58PEU' 901958 101096089
#  'PA80S-220' '3RH1911-1HA12' '5PC910.SX02-00' 'D-F7P' 62001 '7301B'
#  '3203-2RS-C3' 'CPS12-0PA2GSA' 97695 9026756 'ZCHT/2C-N' 'ZHFT/BT'
#  'HTH-H14-AL-600X600X125-FC2/1PM' '102094-ET' 'AVF021V002PVJ'
#  'AB2PFR7PVH4' 'C3PFRP1' 'AVF021V002PVH4' 'VFS11S-2004PL-WP' 'E40096'
#  'MSME022G1U' 'SGMEV-01ADA61' 'MSME042G1U' 'MSME082G1U' 'SGMEV-07DDA61'
#  'MSME012G1U' 'MBDKT2510' 'MADHT1507' 'MCDHT3520' 'MADHT1505' 'MADDT1207'
#  'E82EV371K2C200' 'N 0002 2S XBK2' 'ACS580_01-018A-4+J400'
#  'ACS580_01-026A-4+J400' 'ACS580-01-033A-4+J400' 1033274 1034599
#  6152520900 'OUNB C24050' '4-CAACCFILT*009' '134a' '23012060-GRD' 551775
#  6402031 '1000W' 'J4SSG16U5']
#
# --------------------------------------------------
#
# Part # column each unique repeated by:
# T8                   3
# Diaphragm code 13    3
# CQM1-OD214           2
# M575-233-008         2
# DEX Next             2
#                     ..
# PCS095 M PLUS        1
# 60*80*7/7.9          1
# A170X200X15          1
# 102093-010           1
# J4SSG16U5            1
# Name: Part #, Length: 702, dtype: int64
#
# --------------------------------------------------
#
# Manufacturer column has number of uniques : 263
# Manufacturer column has uniques : ['INA' 'GLATT' 'IMA' nan 'UHLMANN' 'GRUNDFOS' 'HANNA' 'THECNO TUBE'
#  'CLAGE' 'PEPPERL+FUCHS' 'ENDRESS+HAUSER' 'GOLDENSUN' 'TIDAR' 'COMOBREATH'
#  'PLANETROIL' 'IMI BUSCHJOST' 'BUSCH/ATB' 'DVP' 'SOLO' 'STERILIGHT-VIQUA'
#  'W&T' 'PHOENIX  CONTACT' 'COMMONWEALTH' 'METTLER TOLEDO' 'BRECO'
#  'OPTIBELT' 'WALTHER FLENDER' 'POGGI' 'Local' 'UHLMANN ' 'JUMO' 'TERMICS'
#  'ZEBRA' 'MCC' 'WAGO' 'IFM' 'B&R AUTOMATION' 'AUTONICS' 'TINY TAG'
#  'LOVE CONTROLS' 'GWK' 'BT' 'REXROTH' 'FETTE' 'PARKER' 'EVER ELECTRONICS '
#  'FUTUER ' 'LENZE' 'SIEMENS' 'CELDUC' 'CARLO GAVAZZI' 'FESTO' 'NUMATICS'
#  'ARMORVIN ' 'VIMAR' 'Local ' 'Oregnal ' 'MG' 'YASKAWA' 'LUST' 'SMC'
#  'SICK' 'KSM' 'HIC' 'SKF' 'FAG' 'GENERAL ELECTRIC' 'ELSWEDY' 'SCHMERSAL'
#  'PILZ' 'PALL' 'GN' 'SPX' 'UNIBAL' 'ASKUBAL' 'ASAHI' 'LUTZE' 'KEYENCE'
#  'SIKO' 'OMRON' 'ULTRA CELL ' 'FBJ' 'AMA' 'YORK' 'EBERLE' 'WOLKE' 'VEGA'
#  'CALEFFI SOLAR' 'Harris' 'FCV' 'ATECO GROUP' 'TRACO POWER' 'BICKER'
#  'FINDER' 'SCHAFFNER' 'EPCOS' 'CROWN' 'MOELLER' 'E.MC' 'MURR' 'SWEP'
#  'ALPHA' 'TAKENAKA' 'MICRO DETECTORS' 'DATALOGIC' 'MAG' 'HANYOUNG'
#  'SENSOPART' 'LEUZE' 'BAUMER' 'OMCH' 'WENGLOR' 'BINDER' 'ggi' 'SAZN' 'ABA'
#  'AWH' 'ROGATTI' 'ELEKTRONIK SYSTEME LAUER' 'CHR' 'A+P' 'AS' 'CFW'
#  "Schaeffer's" 'RAYMOND' 'BUSCH' 'BEL RAY' 'RATTTINOX' 'SCHNEIDER'
#  'LEROY SOMER' 'LUTRONIK' 'UHLMANN BLISTER' 'EVER MOTOR' 'MICRO' 'KUMATSO'
#  'URAWA' 'DOW' 'HILGE' 'DWYER INSTRUMENTS' 'EATON' 'KEP' 'uhlmann '
#  'SENTROL' 'KSR KUEBLER' 'AIXONTEC' 'HSM PRESSEN' 'KEMET' 'PRINZING'
#  'RICE LAKE' 'RENATA' 'IKO' 'NB' 'KOLMB' 'HFB' 'ADVANCED ILLUMINATION'
#  'MOUJEN' 'MAYR' 'EMAS' 'MMR' 'RICOH' 'ELIOS' 'CNYON' 'VENUS' 'RED WING'
#  'KEI LAMP' 'SCHLEGEL' 'Lsis' 'DANFOSS' 'HITACHI' 'LOCAL' 'COMMAX'
#  'HARTING' 'SCHONBUCH' 'CONTRINEX' 'BALLUFF' 'TELEMECANIQUE' 'BULLUFF'
#  'HYUNDAE' 'GECITECH' 'AIR HOSE' 'OPPLE' 'VOKES' 'AAF' 'NILFISK' 'RICA'
#  'GRASEBY' 'STILL ' 'GEFEG-NECKAR' 'SEW' 'COLOBO FILIPPETTI' 'SNT' 'OMEGA'
#  'GE' 'BURKERT' 'TORNADO' 'IMAGO TECHNOLOGIES' 'GIACOMINI' 'system sensor'
#  'BECKER' 'FLUKE' 'LINDA' 'KINGSKY' 'WEIDMULLER' 'TR ELECTRONIC' 'LIKA'
#  'SCHLEICHER' 'FIKE' 'TEAFLEX' 'BADOTHERM' 'E.ma' 'AMIRCO' 'WELDER'
#  'DORMA' 'KENWELL' 'BORSAN' 'UNIMEASURE ' 'LEGRAND' 'ATLAS COPCO'
#  'DIAPHRAGM DIRECT' 'NORGEN' 'LENOVO' 'NACHI' 'KG' 'GF' 'KBC' 'NTN' 'SNR'
#  'GWC' '3 BROTHERS' 'AMPHENOL-TUCHEL' 'CISA' 'ARGUS' 'QUIKO' 'GEMU' 'AFF'
#  'METTLER TOLEDO-PCE' 'BELDEN' 'PANDUIT' 'Camozzi' 'CANON' 'JNS' 'LAPP'
#  'LUETZE' 'SVS' 'MASTER PLUS' 'UNIMEC' 'GWP' 'HABASIT' 'SEIMENS' '3M'
#  'TURBO' 'B&R' 'AIR FLOW' 'ULPATEK' 'TOSHIBA' 'PANASONIC' 'SINUS' 'ABB'
#  'SICK STEGMANN' 'MORRISFLEX' 'TIBA' 'FALK' 'Horn' 'Omal']
#
# --------------------------------------------------
#
# Manufacturer column each unique repeated by:
# SKF              38
# GLATT            33
# UHLMANN          28
# PEPPERL+FUCHS    24
# SIEMENS          19
#                  ..
# CFW               1
# RAYMOND           1
# BEL RAY           1
# LEROY SOMER       1
# Omal              1
# Name: Manufacturer, Length: 263, dtype: int64
#
# --------------------------------------------------
#
# Location column has number of uniques : 127
# Location column has uniques : ['M-12-2' 'B-02-2' 'B-03-2' 'L-12-3' 'N-08-3' nan 'L-13-3' 'D-05-2'
#  'N-11-4' 'K-10-3' 'L-10-1' 'M-11-1' 'J-11-3' 'E-06-2' 'E-06-1' 'E-05-3'
#  'L-13-2' 'L-10-2' 'B-10-3' 'K-101' 'L-12-1' 'D-06-2' 'K13-4' 'F-05-2'
#  'E-05-2' 'N-08-1' 'A-05-3' 'E-02-1' 'L-12-2' 'J-08-2' 'K-13-2' 'K-09-2'
#  'M-13-4' 'M-13-3' 'I-10-3' 'I-10-2' 'I-09-2' 'N-08-2' 'M-10-3' 'B-10-2'
#  'K-09-1' 'N-10-3' 'A2-4' 'L-08-2' 'M-11-2' 'M-10-2' 'L-10-4' 'L-08-3'
#  'E-01-2' 'M-12-1' 'D-04-3' 'A-09-2' 'F-01-1' 'M-11-3' 'A-08-3' 'C-02-1'
#  'N-09-3' 'L-11-1' 'N-10-2' 'F-01-4' 'K-10-1' 'K-11-4' 'A-08-2' 'C-07-2'
#  'L-12-4' 'F-06-2' 'A-03-1' 'M-13-2' 'L-09-2' 'K-08-1' 'K-10-2' 'I-08-2'
#  'E-05-4' 'E-07-3' 'D-02-2' 'J-12-3' 'J-11-2' 'A2-3' 'B-01-2' 'TBC'
#  'M-12-4' 'C-06-1' 'L-10-3' 'M-08-2' 'N-09-1' 'C-01-3' 'F-02-2' 'K-08-4'
#  'M-08-3' 'C-01-1' 'C-01-2' 'I-09-3' 'C-04-3' 'C-01-4' 'J-10-2' 'L-11-3'
#  'M-09-1' 'M-08-1' 'L-13-4' 'D-03-2' 'A-05-4' 'L-13-1' 'N--09-1' 'M-10-1'
#  'D-07-2' 'C-06-2' 'F-01-2' 'A-05-2' 'D-04-2' 'E-08-3' 'M-09-3' 'K-12-4'
#  'J-09-2' 'F-04-4' 'A-03-3' 'TBD' 'A-02-3' 'te' 'E-03-1' 'K12-3' 'K12-2'
#  'K-13-3' 'K13-3' 'F-02-1' 'F-03-4' 'J-11-1' 'L-08-1' 'A-02-4']
#
# --------------------------------------------------
#
# Location column each unique repeated by:
# A-08-3     47
# K-13-2     40
# M-12-2     33
# E-06-2     30
# E-05-2     28
#            ..
# I-10-2      1
# L-13-1      1
# N--09-1     1
# M-10-1      1
# A-02-4      1
# Name: Location, Length: 127, dtype: int64
#
# --------------------------------------------------
#
# Comments column has number of uniques : 140
# Comments column has uniques : ['Bearing' 'Gasket' 'Light' 'Forklift wheel' 'Oil seal' 'Water test '
#  'Water pump' 'Water heater' 'Glatt nozzle' 'Sensor  photoelectric'
#  'Glatt  switch' 'Fan' 'Motor' 'Glatt valve' 'Vacuum pump' 'Gauge'
#  'Water uv' 'Ups' 'Heater' 'Converter' 'Belts' 'T & t' 'Control'
#  'Thermostate' 'Thermocouple' 'Prenter' 'Jumper' 'Conductor' 'Spring'
#  'Stilmas sensor' 'Module' 'Data logger' 'Sensor' 'Panel' 'Swivel castor'
#  'Switch' 'Forklift switch' 'Amplifier' nan 'Suction cup' 'Fette'
#  'Filters cartage' 'Servo motor' 'Solenoid valve' 'Relay' 'Neumatic hose'
#  'Socket' 'Power supply' 'Leaflet rooler' 'Shaft' 'Servo driver'
#  'Water conductivity' 'Water filter' 'Pump' 'Cylinder' 'Electricity'
#  'Proximity' 'Battery' 'Button' 'Forklift coolant' 'Module ' 'Pre-filter'
#  'Water valve' 'Controller' 'Plug' 'Plate' 'Electricity pin' 'Clothing'
#  'Oil _ grease' 'Oil _ filter' 'Cable' 'Feedback' 'Mechanics l1'
#  'Water ro' 'Clutch' 'Lototo' 'Load cell' 'Led' 'Inverter'
#  'Water intermediate' 'Electricity light' 'High filter' 'Hepa filter'
#  'Electricity helical' 'Hand pallets' 'Gearbox' 'Fuse'
#  'Flowmeter controller' 'Flow monitor sensor' 'Flow module'
#  'Flange gasket' 'Fire valve' 'Fire detector' 'Water filter cartage'
#  'Calibration' 'Fiber sensor' 'Enconders' 'Emergency'
#  'Electronic  position indicator' 'Electronic board' 'Electronic buzzer'
#  'Electric gauge' 'Electric earth' 'Sieve glatt' 'Connector cable' 'Door'
#  'Diodes module' 'Digital precision' 'Differential pressure gauge'
#  'Diaphragm' 'Solenoid coil' 'Screen desk' 'Value transformer' 'Clamp'
#  'Contactor' 'Forklift control' 'Conductivity transmitter'
#  'Electricity complete' 'Plc cpu' 'Water test' 'Chain' 'Forklift carbon'
#  'Regulator' 'Cam' 'Power strip' 'Valve ahu' 'Bush' 'Forklift break'
#  'Couplin' 'Bearing bush' 'Actuator az ' 'Analog sensor' 'Packfilter'
#  'Pump filter' 'Emflon filter' 'Speed drive' 'Process senso' 'Selector'
#  'Electricity 2 way' 'Freon gas r134a' 'Relay ']
#
# --------------------------------------------------
#
# Comments column each unique repeated by:
# Bearing              75
# Oil seal             38
# Proximity            32
# Sensor               27
# Control              23
#                      ..
# Electronic buzzer     1
# Electric earth        1
# Sieve glatt           1
# Connector cable       1
# Relay                 1
# Name: Comments, Length: 140, dtype: int64
#
# --------------------------------------------------

# %%
df_f['Comments'].values
# Out:
# array(['Bearing', 'Gasket', 'Gasket', 'Gasket', 'Gasket', 'Gasket',
#        'Light', 'Forklift wheel', 'Oil seal', 'Water test ', 'Water pump',
#        'Water pump', 'Water test ', 'Water pump', 'Water heater',
#        'Water test ', 'Water test ', 'Glatt nozzle', 'Oil seal',
#        'Oil seal', 'Sensor  photoelectric', 'Water pump', 'Glatt  switch',
#        'Fan', 'Fan', 'Fan', 'Motor', 'Glatt valve', 'Vacuum pump',
#        'Vacuum pump', 'Gauge', 'Water uv', 'Water uv', 'Ups', 'Ups',
#        'Ups', 'Ups', 'Heater', 'Converter', 'Fan', 'Belts', 'T & t',
#        'Belts', 'T & t', 'Water test ', 'Belts', 'Belts', 'Belts',
#        'Belts', 'Belts', 'Belts', 'Belts', 'Belts', 'Control',
#        'Thermostate', 'Thermostate', 'Thermocouple', 'Prenter', 'Prenter',
#        'Jumper', 'Jumper', 'Conductor', 'Conductor', 'Conductor',
#        'Conductor', 'Conductor', 'Conductor', 'Spring', 'Spring',
#        'Spring', 'Stilmas sensor', 'Stilmas sensor', 'Stilmas sensor',
#        'Module', 'Control', 'Control', 'Data logger', 'Data logger',
#        'Sensor', 'Panel', 'Oil seal', 'Swivel castor', 'Switch',
#        'Forklift switch', 'Amplifier', 'Amplifier', 'Amplifier',
#        'Amplifier', 'Amplifier', 'Bearing', nan, 'Suction cup', 'Fette',
#        'Filters cartage', 'Servo motor', 'Spring', 'Spring',
#        'Glatt nozzle', 'Control', nan, nan, 'Control', 'Solenoid valve',
#        'Relay', 'Relay', 'Relay', 'Solenoid valve', 'Solenoid valve',
#        'Solenoid valve', 'Solenoid valve', 'Solenoid valve',
#        'Neumatic hose', 'Socket', 'Power supply', 'Leaflet rooler',
#        'Leaflet rooler', 'Solenoid valve', 'Solenoid valve',
#        'Solenoid valve', 'Control', 'Oil seal', 'Light', 'Leaflet rooler',
#        'Leaflet rooler', 'Shaft', 'Servo motor', 'Servo motor',
#        'Servo driver', 'Servo driver', 'Servo driver', 'Servo driver',
#        nan, 'Sensor', 'Water conductivity', 'Sensor', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Switch', 'Module', 'Light',
#        'Oil seal', 'Oil seal', nan, 'Relay', 'Relay', 'Relay', 'Relay',
#        'Relay', 'Relay', 'Water pump', 'Water filter', 'Swivel castor',
#        'Fette', 'Pump', 'Cylinder', 'Bearing', 'Bearing', 'Bearing',
#        'Electricity', 'Sensor', 'Solenoid valve', 'Relay', 'Relay',
#        'Proximity', 'Proximity', nan, 'Battery', 'Bearing', 'Bearing',
#        'Neumatic hose', 'Neumatic hose', 'Button', 'Proximity',
#        'Forklift coolant', 'Control', 'Control', 'Module ', 'Control',
#        'Spring', 'Spring', 'Spring', 'Solenoid valve', 'Solenoid valve',
#        'Solenoid valve', 'Solenoid valve', 'Pump', 'Pre-filter',
#        'Pre-filter', 'Pre-filter', 'Water valve', 'Power supply',
#        'Power supply', 'Power supply', 'Power supply', 'Power supply',
#        'Module ', 'Power supply', 'Module ', 'Controller', 'Controller',
#        'Forklift switch', 'Forklift switch', 'Forklift switch',
#        'Cylinder', 'Cylinder', 'Cylinder', 'Plug', 'Plate',
#        'Electricity pin', 'Electricity pin', 'Pump', 'Control', 'Sensor',
#        'Sensor', 'Sensor', 'Sensor', 'Sensor', 'Sensor', 'Sensor',
#        'Sensor', 'Sensor', 'Sensor', 'Sensor', 'Sensor', 'Sensor',
#        'Sensor', 'Sensor', 'Sensor', 'Sensor', 'Sensor', 'Sensor',
#        'Control', 'Neumatic hose', 'Neumatic hose', 'Neumatic hose',
#        'Neumatic hose', 'Solenoid valve', 'Solenoid valve',
#        'Solenoid valve', 'Cylinder', 'Relay', 'Module', 'Module',
#        'Module', 'Clothing', 'Module', 'Module', 'Module', 'Panel',
#        'Panel', 'Oil seal', 'Oil seal', 'Oil seal', 'Oil seal',
#        'Oil seal', 'Oil seal', 'Oil seal', 'Oil seal', 'Oil seal',
#        'Oil seal', 'Oil seal', 'Oil _ grease', 'Oil _ grease',
#        'Oil _ filter', 'Oil _ filter', 'Oil _ filter', 'Oil seal',
#        'Oil seal', 'Oil seal', 'Oil seal', 'Oil seal', 'Oil seal',
#        'Oil seal', 'Oil seal', 'Oil seal', 'Oil seal', 'Oil seal',
#        'Oil seal', 'Oil seal', 'Oil seal', 'Oil seal', 'Oil seal',
#        'Oil seal', 'Oil seal', nan, 'Solenoid valve', 'Solenoid valve',
#        'Switch', 'Cable', 'Bearing', 'Bearing', 'Bearing', 'Bearing',
#        'Control', 'Motor', 'Feedback', 'Controller', 'Controller',
#        'Controller', 'Motor', 'Controller', 'Control', 'Relay', 'Relay',
#        'Cylinder', 'Cylinder', 'Cylinder', 'Cylinder', 'Cylinder',
#        'Switch', 'Switch', 'Switch', 'Control', 'Mechanics l1',
#        'Water ro', 'Oil seal', 'Oil seal', 'Gauge', 'Motor', 'Motor',
#        'Motor', 'Control', 'Control', 'Control', 'Gauge', 'Clutch',
#        'Shaft', 'Relay', 'Switch', 'Switch', 'Switch', 'Gauge', 'Gauge',
#        'Gauge', 'Control', 'Control', 'Oil _ grease', 'Oil _ grease',
#        'Lototo', 'Leaflet rooler', 'Lototo', 'Lototo', 'Lototo',
#        'Load cell', 'Battery', 'Battery', 'Bearing', 'Bearing', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Switch', 'Switch',
#        'Switch', 'Switch', 'Switch', 'Switch', 'Light', 'Control',
#        'T & t', 'Led', 'Light', 'Light', 'Light', 'Light', 'Light',
#        'Light', 'Light', 'Light', 'Switch', 'Switch', 'Switch',
#        'Inverter', 'Inverter', 'Inverter', 'Inverter', 'Inverter',
#        'Inverter', 'Water intermediate', nan, 'Module', 'Gasket',
#        'Gasket', 'Gasket', 'Gasket', 'Gasket', 'Control', 'T & t',
#        'Proximity', 'Proximity', 'Proximity', 'Proximity', 'Proximity',
#        'Proximity', 'Proximity', 'Proximity', 'Proximity', 'Proximity',
#        'Proximity', 'Proximity', 'Proximity', 'Proximity', 'Proximity',
#        'Proximity', 'Proximity', 'Proximity', 'Proximity', 'Proximity',
#        'Proximity', 'Proximity', 'Proximity', 'Proximity', 'Proximity',
#        'Proximity', 'Proximity', 'Gauge', 'Amplifier', 'Amplifier',
#        'Belts', 'Oil _ grease', 'Oil _ grease', 'Neumatic hose',
#        'Neumatic hose', 'Neumatic hose', 'Electricity light',
#        'Electricity light', 'High filter', 'Hepa filter', 'Hepa filter',
#        'Electricity helical', 'Heater', 'Heater', 'Heater', 'Heater',
#        'Heater', 'Heater', 'Hand pallets', 'Hand pallets', 'Electricity',
#        'Lototo', 'Lototo', 'Cable', 'Oil _ grease', 'Cable', 'Motor',
#        'Motor', 'Motor', 'Gearbox', 'Oil _ grease', 'Oil _ grease',
#        'Oil _ grease', 'Gearbox', 'Gasket', 'Gasket', 'Gasket', 'Gasket',
#        'Gasket', 'Gasket', 'Gasket', 'Gasket', 'Gasket', 'Gasket', 'Fuse',
#        'Fuse', 'Module', nan, 'Converter', 'Sensor', 'Light',
#        'Flowmeter controller', 'Flow monitor sensor', 'Flow module',
#        'Flow monitor sensor', 'Light', 'Light', 'Neumatic hose', 'T & t',
#        'Flange gasket', 'Flange gasket', 'Swivel castor', 'Fire valve',
#        'Fire detector', 'Water filter cartage', 'Water filter cartage',
#        'Calibration', 'Fiber sensor', 'Fiber sensor', 'Fiber sensor',
#        'Electricity', 'Fan', 'Fan', 'Electricity', 'Switch', 'Sensor',
#        'Sensor', 'Electricity', 'Electricity', 'Electricity', 'Enconders',
#        'Enconders', 'Enconders', 'Enconders', 'Enconders', 'Enconders',
#        'Enconders', 'Emergency', 'Electronic  position indicator',
#        'Electronic board', 'Electronic board', 'Electronic board',
#        'Electronic board', 'Electronic board', 'Electronic buzzer',
#        'Clutch', 'Solenoid valve', 'Neumatic hose', 'Electric gauge',
#        'Electric gauge', 'Electric earth', 'Sieve glatt',
#        'Connector cable', 'Cylinder', 'Door', 'Door', 'Door', 'Door',
#        'Electricity', 'Electricity', 'Cylinder', 'Solenoid valve',
#        'Diodes module', 'Switch', 'Digital precision', 'Module', 'Module',
#        'Differential pressure gauge', 'Diaphragm', 'Diaphragm',
#        'Diaphragm', 'Diaphragm', 'Solenoid coil', 'Solenoid coil',
#        'Screen desk', 'Differential pressure gauge', 'Bearing', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing',
#        'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing', 'Bearing',
#        'Bearing', 'Fan', 'Cable', 'Value transformer', 'Fette', 'Fette',
#        'Clamp', 'Module', 'Module', 'Module', 'Light', 'Socket', 'Belts',
#        'Door', 'Control', 'Control', 'Contactor', 'Contactor',
#        'Contactor', 'Contactor', 'Contactor', 'Contactor',
#        'Forklift control', 'Contactor', 'Contactor', 'Contactor',
#        'Contactor', 'Contactor', 'Contactor', 'Contactor', 'Contactor',
#        'Cable', 'Cable', 'Conductivity transmitter', 'Diaphragm',
#        'Diaphragm', 'Diaphragm', 'Electricity complete', 'Clutch',
#        'Plc cpu', 'Sensor', 'Hepa filter', 'Hepa filter', 'Hepa filter',
#        'Clamp', 'Clamp', 'Contactor', 'Contactor', 'Contactor',
#        'Water test', 'Led', 'Cable', 'Cable', 'Chain', 'Mechanics l1',
#        'Forklift carbon', 'Forklift carbon', 'Proximity', 'Proximity',
#        'Regulator', 'T & t', 'T & t', 'T & t', 'Module', 'Cam', 'Cam',
#        'Cam', 'Cam', 'Cam', 'Cam', 'Cam', 'Cam', 'Cam', 'Cam', 'Cam',
#        'Cam', 'Cam', 'Cam', 'Cable', 'Power strip', 'Valve ahu',
#        'Valve ahu', 'Bush', 'Servo driver', 'Belts', 'Forklift break',
#        'Couplin', 'Leaflet rooler', 'Leaflet rooler', 'Neumatic hose',
#        'Gearbox', 'Gearbox', 'Belts', 'Battery', 'Battery',
#        'Bearing bush', 'Actuator az ', 'Fan', 'Switch', 'T & t', 'T & t',
#        'Switch', 'Module', 'Bearing', 'Bearing', 'Analog sensor',
#        'Mechanics l1', 'Pre-filter', 'Filters cartage', 'Filters cartage',
#        'Packfilter', 'Packfilter', 'Packfilter', 'Pump filter',
#        'Emflon filter', 'Emflon filter', 'Emflon filter', 'Emflon filter',
#        'Speed drive', 'Process senso', 'Servo motor', 'Servo motor',
#        'Servo motor', 'Servo motor', 'Servo motor', 'Servo motor',
#        'Servo driver', 'Servo driver', 'Servo driver', 'Servo driver',
#        'Servo driver', 'Servo driver', 'Servo driver', 'Servo driver',
#        'Servo driver', 'Servo driver', 'Servo driver', 'Enconders',
#        'Enconders', 'Selector', 'Selector', 'Swivel castor',
#        'Electricity 2 way', 'Freon gas r134a', 'Couplin', 'Gasket',
#        'Relay ', 'Heater', 'Heater', 'Water valve'], dtype=object)

# %%
peraing = df_f[df_f['Comments'] == 'Bearing'].sort_values(by='Comments')
peraing
# Out:
#                                       Item description  Qty.        Part #  \
# 0                YOKE TYPE TRACK ROLLERS, 12X32X11.8MM   1.0         STO12
# 579               DEEP GROOVE BALL BEARING, 20X42X12MM   1.0        6004LU
# 578               DEEP GROOVE BALL BEARING, 20X42X12MM   1.0    6004LLU/5K
# 577               DEEP GROOVE BALL BEARING, 20X42X12MM   2.0  6004-2RSH/C3
# 576               DEEP GROOVE BALL BEARING, 20X47X14MM   3.0         6204D
# ..                                                 ...   ...           ...
# 355            LINEAR BUSHING BALL BEARING, 16X26X36MM   1.0     LME 16 UU
# 354            LINEAR BUSHING BALL BEARING, 16X26X36MM   2.0       KB 16 G
# 353            LINEAR BUSHING BALL BEARING, 25X35X40MM   4.0        KH25-B
# 351               LINEAR BUSHING BALL BEARING, DI=16MM   8.0       KB16GUU
# 702  ANGULAR CONTACT BALL BEARING DOUBLE ROW, 17X40...   1.0   3203-2RS-C3
#
#     Manufacturer Location Comments
# 0            INA   M-12-2  Bearing
# 579          NTN   A-08-3  Bearing
# 578          NTN   A-08-3  Bearing
# 577          SKF   A-08-3  Bearing
# 576          KBC   A-08-3  Bearing
# ..           ...      ...      ...
# 355        KOLMB   A-08-3  Bearing
# 354           NB   A-08-3  Bearing
# 353          INA   A-08-3  Bearing
# 351           NB   A-08-3  Bearing
# 702          INA   A-08-3  Bearing
#
# [75 rows x 6 columns]

# %%
OIL_SEAL = df_f[df_f['Comments'] == 'Oil seal'].sort_values(by='Comments')
OIL_SEAL
# Out:
#                                  Item description   Qty.  \
# 8                         WEAR RING 100X114X10 BZ    1.0
# 271                            O RING T=1.78, NBR    1.0
# 272  O RING SILICONE STRING Ø6MM, L=1436MM, GLUED    1.0
# 273                       O RING SET FOR FORKLEFT    1.0
# 274                 O RING SEAL HEATING TANK POS7    1.0
# 275                                O RING 85*3MM     2.0
# 276                                O RING 85*3MM     2.0
# 277                           O RING 6*0.78, EPDM  150.0
# 278                         O RING 3*1MM, L=925MM    1.0
# 279                          O RING 189.87*5.33MM    2.0
# 280                         O RING 14*1.5MM, EPDM   11.0
# 281                   O RING 12*3MM, SILICON, RED    9.0
# 282                        O RING 11.1*1.78, EPDM    6.0
# 283                   O RING , DN15*4.5, DIN11851    2.0
# 284                                       O RING     1.0
# 285                                        O RING    4.0
# 270                              O RING, 12.3X2.4    8.0
# 269                           O RING, 6*1MM, EPDM    6.0
# 268                                O RING, 80*3MM    1.0
# 262                 OIL SAE 15W40 API CJ-4C1-4/SM    1.0
# 18                        WAER RING 90X104X10 BZ     1.0
# 19                           V-SEAL-RING, D=500MM    1.0
# 80                TC GASKET 6'', 40MP-X, SILICONE    1.0
# 120                        SILICON O RING 295X4MM    2.0
# 142                          SEALING RING , 1/4''    1.0
# 143    SEALING PROFILE ,L= 845MM, GLUED, SILICONE    1.0
# 252             OILSEAL BROWN, ISP1D, 60*80*7/7.9    5.0
# 317              MECHANICAL SEAL FOR CH 6247 PUMP    1.0
# 253                      OILSEAL BLACK 170X200X15    2.0
# 255                            OILSEAL , 40*55*10    1.0
# 256                                       OILSEAL    2.0
# 257    OIL SEAL, 30*42*9,BUTADIENE-NITRILE RUBBER    9.0
# 258                                  OIL SEAL SET    2.0
# 259           OIL SEAL 19*27*4, POLYAMAIDE AND PU  159.0
# 260                        OIL SEAL ,60*80*8, NBR   14.0
# 261                          OIL SEAL , 60*80*7,    11.0
# 254           OILSEAL 8'', 217.5*197*2, SILICONE     1.0
# 318              MECHANICAL SEAL FOR CH 6247 PUMP    1.0
#
#                    Part # Manufacturer Location  Comments
# 8                96457868     GRUNDFOS   L-13-3  Oil seal
# 271             M08010103          IMA   B-02-2  Oil seal
# 272           1-997-05838        GLATT   B-02-2  Oil seal
# 273                230275           BT   B-10-2  Oil seal
# 274               3250098          NaN   B-03-2  Oil seal
# 275           1-997-00447        GLATT   B-02-2  Oil seal
# 276           1-997-00425        GLATT   B-02-2  Oil seal
# 277                 40989          NaN   B-02-2  Oil seal
# 278           1-997-03778        GLATT   B-02-2  Oil seal
# 279           1-999-10757        GLATT   B-02-2  Oil seal
# 280           1-999-08222        GLATT   B-02-2  Oil seal
# 281           1-999-01859        GLATT   B-02-2  Oil seal
# 282           1-999-14861          NaN   B-02-2  Oil seal
# 283           1-997-00644        GLATT   B-02-2  Oil seal
# 284                  9520          NaN   B-02-2  Oil seal
# 285               B596218          IMA   B-02-2  Oil seal
# 270                903130      UHLMANN   B-02-2  Oil seal
# 269           1-999-10976        GLATT   B-02-2  Oil seal
# 268           1-977-00447        GLATT   B-02-2  Oil seal
# 262  700 CJ SUPEREME 7000  Schaeffer's      TBC  Oil seal
# 18               96457867     GRUNDFOS   L-13-3  Oil seal
# 19          30C1400527 EH          NaN   B-03-2  Oil seal
# 80            1-997-00681        GLATT   B-03-2  Oil seal
# 120            1997-01945          NaN   B-03-2  Oil seal
# 142             DIN 7603C          NaN   N-09-3  Oil seal
# 143           1-997-05836        GLATT   B-03-2  Oil seal
# 252           60*80*7/7.9          CHR   B-01-2  Oil seal
# 317       3A2-001-19KIEC1        HILGE   L-13-3  Oil seal
# 253           A170X200X15          A+P   B-01-2  Oil seal
# 255            9200055835        GLATT   B-01-2  Oil seal
# 256           102091.0004        GLATT   B-03-2  Oil seal
# 257            UP 30 42 9           AS   B-01-2  Oil seal
# 258                243927          NaN   B-01-2  Oil seal
# 259          SD 19X27X4 B          INA   B-01-2  Oil seal
# 260              BAU4SLX2          CFW   B-01-2  Oil seal
# 261            TPYDCB2355        GLATT   B-01-2  Oil seal
# 254            102093-010          NaN   B-03-2  Oil seal
# 318       3A3-001-28KKE01        HILGE   L-13-3  Oil seal

# %%
ELECTRICITY_PROXIMITY = df_f[df_f['Comments'] == 'Proximity'].sort_values(by='Comments')
ELECTRICITY_PROXIMITY
# Out:
#                                       Item description  Qty.  \
# 165  REED PROXIMITY SWITCH, FOR CQ2/NCQ2 CYLINDERS ...   1.0
# 424  INDUCTIVE PROXIMITY  SENSOR M12,PNP,NO - 84229090   1.0
# 423  INDUCTIVE PROXIMITY  SENSOR M12,PNP,NO - 90318034   1.0
# 422                        INDUCTIVE PROXIMITY SWITCH    1.0
# 421                        INDUCTIVE PROXIMITY SWITCH    1.0
# 420  INDUCTIVE PROXIMITY SWITCH - M8 - 3RG4011-0AG0...   1.0
# 419            INDUCTIVE PROXIMITY SWITCH , PNP, NO/NC   4.0
# 418         INDUCTIVE PROXIMITY SWITCH, M12, NAMUR, NC   1.0
# 417           INDUCTIVE PROXIMITY SWITCH, M12, NPN, NO   1.0
# 416           INDUCTIVE PROXIMITY SWITCH, M12, PNP, NO   1.0
# 415        INDUCTIVE PROXIMITY SWITCH, M12, PNP, NO/NC   1.0
# 414        INDUCTIVE PROXIMITY SWITCH, M12, PNP, NO/NC   1.0
# 413            INDUCTIVE PROXIMITY SWITCH, M8, PNP, NO   1.0
# 412                INDUCTIVE PROXIMITY SWITCH, NC, M12   3.0
# 411                INDUCTIVE PROXIMITY SWITCH, NC, M18   1.0
# 410                 INDUCTIVE PROXIMITY SWITCH, NC, M8   1.0
# 409  INDUCTIVE PROXIMITY SWITCH, NON FERROUS TARGET...   1.0
# 408                INDUCTIVE PROXIMITY SWITCH, NPN, NC   3.0
# 407                INDUCTIVE PROXIMITY SWITCH, NPN, NO   1.0
# 406                INDUCTIVE PROXIMITY SWITCH, PNP, NC   2.0
# 405                INDUCTIVE PROXIMITY SWITCH, PNP, NO   1.0
# 404                INDUCTIVE PROXIMITY SWITCH, PNP, NO   1.0
# 403                INDUCTIVE PROXIMITY SWITCH, PNP, NO   4.0
# 402                INDUCTIVE PROXIMITY SWITCH, PNP, NO   1.0
# 401                INDUCTIVE PROXIMITY SWITCH, PNP, NO   1.0
# 400                INDUCTIVE PROXIMITY SWITCH, PNP, NO   1.0
# 399                INDUCTIVE PROXIMITY SWITCH, PNP, NO   1.0
# 398                INDUCTIVE PROXIMITY SWITCH, PNP, NO   1.0
# 174  PROX.IND.: PEPPERL + F. 3RG4210 - 7AG00 - PF -...   1.0
# 166  REED PROXIMITY SWITCH, 2 WIRE, DIRECT MOUNTING...   1.0
# 655              CAPACITIVE PROXIMITY SWITCH , PNP, NO   1.0
# 656              CAPACITIVE PROXIMITY SWITCH , PNP, NO   1.0
#
#                     Part #     Manufacturer Location   Comments
# 165                5810539              SMC   E-05-2  Proximity
# 424                6022113          BULLUFF   E-05-2  Proximity
# 423                6003098          BALLUFF   E-05-2  Proximity
# 422                  33877    PEPPERL+FUCHS   I-08-2  Proximity
# 421          3RG4210-7AG00    PEPPERL+FUCHS   K-10-2  Proximity
# 420                6022432    PEPPERL+FUCHS   E-05-2  Proximity
# 419  IN5028 / IN-3004-FPKG              IFM   I-09-2  Proximity
# 418      NCB2-12GM35-N0-V1    PEPPERL+FUCHS   I-09-2  Proximity
# 417              AM1/AN-1A  MICRO DETECTORS   I-08-2  Proximity
# 416           XS212BLPAM12    TELEMECANIQUE   E-06-2  Proximity
# 415       BES 516-113-S4-C          BALLUFF   I-09-2  Proximity
# 414    BES 516-113-BO-C-03          BALLUFF   E-06-2  Proximity
# 413              AE1-AP-2A  MICRO DETECTORS   I-09-2  Proximity
# 412         NCN4-12GM35-N0    PEPPERL+FUCHS   I-08-2  Proximity
# 411         NCB5-18GM40-N0    PEPPERL+FUCHS   I-08-2  Proximity
# 410         NJ1,5-8GM-N-5M    PEPPERL+FUCHS   I-08-2  Proximity
# 409           NJ3-18GK-S1N    PEPPERL+FUCHS   I-08-2  Proximity
# 408              ILCT 1213        SCHONBUCH   I-08-2  Proximity
# 407               ILLI1214        SCHONBUCH   I-08-2  Proximity
# 406               ILCT1215        SCHONBUCH   I-08-2  Proximity
# 405      DW-AS-503-M30-002        CONTRINEX   I-08-2  Proximity
# 404            HYP-12R 4PA         HANYOUNG   I-08-2  Proximity
# 403                 IN5370              IFM   E-06-2  Proximity
# 402                 IF5345              IFM   E-06-2  Proximity
# 401           18GM50-E2-V1    PEPPERL+FUCHS   I-08-2  Proximity
# 400      NBB2-12GM40-E2-V1    PEPPERL+FUCHS   I-08-2  Proximity
# 399      NBB4-12GM50-E2-5M    PEPPERL+FUCHS   I-08-2  Proximity
# 398              IBCT-1214        SCHONBUCH   I-08-2  Proximity
# 174                6020075              IMA   E-05-2  Proximity
# 166                5810117              SMC   E-05-2  Proximity
# 655                 128636    PEPPERL+FUCHS   I-08-2  Proximity
# 656           BCS030PS1CS4          BALLUFF   E-06-2  Proximity

# %%
ELECTRICITY_SENSOR = df_f[df_f['Comments'] == 'Sensor'].sort_values(by='Comments')
ELECTRICITY_SENSOR
# Out:
#                                       Item description  Qty.  \
# 78                           TEMP PROBE PT100 -70-260C   2.0
# 503                      ENERGETIC DIFFUSE SENSOR, PNP   1.0
# 477     FORK PHOYOCELL, 10-30VDC, PNP/NPN - WF2-40B416   1.0
# 232           PHOTOELEC REFLEX SENSOR, NC+N0, RANGE=2M   1.0
# 231           PHOTOELEC REFLEX SENSOR, NC+N0, RANGE=3M   2.0
# 230                        PHOTOELECTRIC HEAD RECIEVER   1.0
# 229                     PHOTOELECTRIC HEAD TRANSMITTER   1.0
# 228   PHOTOELECTRIC RETRO REFLECTIVE SENSOR, 0 TO 0.3M   2.0
# 227  PHOTOELECTRIC RETRO REFLECTIVE SENSOR, M18,NO,...   1.0
# 226  PHOTOELECTRIC RETRO REFLECTIVE SENSOR, M18,NO,...   2.0
# 225          PHOTOELECTRIC RETRO REFLECTIVE SENSOR, NO   1.0
# 224         PHOTOELECTRIC RETRO REFLECTIVE SENSOR, NPN   0.0
# 504                      ENERGETIC DIFFUSE SENSOR, PNP   1.0
# 223  PHOTOELECTRIC RETRO REFLECTIVE SENSOR,RANGE=0....   1.0
# 221  PHOTOELECTRIC SENSOR FOR ADAPTION OF FIBER-OPT...   1.0
# 220       PHOTOELECTRIC SENSOR RECIEVER,PNP/NPN, NO/NC   1.0
# 219         PHOTOELECTRIC SENSOR TANSMETTER, M8., 4PIN   2.0
# 218  PHOTOELECTRIC SENSOR TANSMETTER+RECIEVER, SENS...   2.0
# 217                         PHOTOELECTRIC SENSOR, 250V   1.0
# 216                   PHOTOELECTRIC SENSOR, PNP, NO/NC   1.0
# 215                   PHOTOELECTRIC SENSOR, PNP, NO/NC   1.0
# 214                                  PHOTOSENSOR 3WIRE   1.0
# 161  RETRO REFLECTIVE SENSOR HEAD, IP67, MAX DESTAN...   1.0
# 134                SENSOR FIBER OPTIC , RANGE 0- 0.15M   1.0
# 132                      SENSOR MAGN.FINEC.:SMC D-H7CN   1.0
# 222    PHOTOELECTRIC RETRO-REFLECTIVE SWITCH, RANGE 6M   1.0
# 638        COLOR SENSOR , PNP,5 PIN,  M12 - CS81-P1112   1.0
#
#                 Part #     Manufacturer Location Comments
# 78       CH-8712 Stafa             JUMO   E-06-2   Sensor
# 503        RK 72/4-200            LEUZE   I-08-2   Sensor
# 477            6028450             SICK   E-05-4   Sensor
# 232            HN22PA3          WENGLOR   E-07-3   Sensor
# 231            UF87PA3          WENGLOR   E-06-2   Sensor
# 230             PS-52R          KEYENCE   E-05-4   Sensor
# 229             PS-52T          KEYENCE   E-05-4   Sensor
# 228     RK 18/4 G,4000            LEUZE   I-08-2   Sensor
# 227             CR-30X              MAG   I-09-2   Sensor
# 226         E3F-DS30Y1             OMCH   I-09-2   Sensor
# 225          MVC/A0-0A  MICRO DETECTORS   I-08-2   Sensor
# 224       FPDK 10N5101           BAUMER   I-08-2   Sensor
# 504  RK 93/4-20 S,6000            LEUZE   E-06-2   Sensor
# 223         WL170-N420             SICK   E-06-2   Sensor
# 221        FMS 18-34 U        SENSOPART   E-06-2   Sensor
# 220   S3Z-PR-5-FG01-PL        DATALOGIC   E-05-4   Sensor
# 219    S3Z-PR-5-M01-PL        DATALOGIC   I-08-2   Sensor
# 218             PE-T5D         HANYOUNG   I-08-2   Sensor
# 217            CAR-30X              MAG   I-08-2   Sensor
# 216          S41-2-C-P        DATALOGIC   I-08-2   Sensor
# 215         FAI7/BP-1A  MICRO DETECTORS   I-08-2   Sensor
# 214        DL Z-S30-PN         TAKENAKA   K-10-2   Sensor
# 161            LV-H62F          KEYENCE   M-10-3   Sensor
# 134           LL3-DB01             SICK   M-10-3   Sensor
# 132            5810218              SMC   E-05-2   Sensor
# 222           50022680            LEUZE   E-06-2   Sensor
# 638            1028224             SICK   E-05-4   Sensor

# %%
GASKET = df_f[df_f['Comments'] == 'Gasket'].sort_values(by='Comments')
GASKET
# Out:
#                                       Item description  Qty.           Part #  \
# 1                                    WIPER , 20/30*4*7   1.0      1-999-04634
# 470                                             GASKET   1.0          3230175
# 469                                  GASKET DISCHARGE    2.0    028 15296 000
# 468                             GASKET DN100, SILICONE   2.0      1-997-00198
# 467                                         GASKET KIT   4.0        PB 139032
# 466                                         GASKET KIT   5.0        139034 BT
# 465              GASKET Ø14MM, FABRIC FILTER, SILICONE   1.0      1-997-01946
# 464               GASKET RING FILTER DN400 WITH INLAY    3.0      1-997-01427
# 463                GASKET RING Ø125XØ107X1MM, SILICONE   1.0      1-997-04183
# 471                                             GASKET   1.0          3230171
# 462                  GASKET, DN300, U PROFILE, 5/9*10    2.0      1-997-01944
# 394   INFLATABLE GASKET , UNFOLDING U-SHAPED, SILICONE   1.0       04-0079-26
# 393   INFLATABLE GASKET , UNFOLDING U-SHAPED, SILICONE   1.0      1-999-10335
# 392   INFLATABLE GASKET , UNFOLDING U-SHAPED, SILICONE   1.0    1-952-20190-0
# 391   INFLATABLE GASKET , UNFOLDING U-SHAPED, SILICONE   1.0       04-0070-08
# 5                                WHITE PTFE GASKET SET   1.0  14-GPT*12T*0001
# 4                                WHITE PTFE GASKET SET   1.0  12-GPT*12T*0005
# 3                                WHITE PTFE GASKET SET   1.0  13-GPT*12T*0002
# 2                    WHITE SMALL Circle PLASTIC GASKET   4.0        BTHL30013
# 395  INFLATABLE GASKET , UNFOLDING U-SHAPED , SILIC...   1.0     1-105-00459D
# 743             1 EPDM GASKET + STOPPER + CABLE GASKET   1.0           551775
#
#     Manufacturer Location Comments
# 1          GLATT   B-02-2   Gasket
# 470          NaN   N-09-3   Gasket
# 469          NaN   B-03-2   Gasket
# 468        GLATT   B-03-2   Gasket
# 467          NaN   B-01-2   Gasket
# 466          NaN   B-01-2   Gasket
# 465        GLATT   B-03-2   Gasket
# 464        GLATT   B-03-2   Gasket
# 463        GLATT   B-03-2   Gasket
# 471          NaN   N-09-3   Gasket
# 462        GLATT   B-02-2   Gasket
# 394        GLATT   J-10-2   Gasket
# 393        GLATT   J-10-2   Gasket
# 392        GLATT   J-10-2   Gasket
# 391        GLATT   J-10-2   Gasket
# 5            NaN   L-12-3   Gasket
# 4            NaN   L-12-3   Gasket
# 3            NaN   L-12-3   Gasket
# 2            IMA   B-03-2   Gasket
# 395        GLATT   J-10-2   Gasket
# 743          NaN   B-02-2   Gasket

# %%
Fire_fighting = df_f[df_f['Comments'] == 'Fire detector'].sort_values(by='Comments')
Fire_fighting
# Out:
#                    Item description  Qty. Part #   Manufacturer Location  \
# 491  FIRE ALARM WATER FLOW DETECTOR   1.0  WFD30  system sensor   K-13-2
#
#           Comments
# 491  Fire detector

# %%
Fire_fighting_VALVE = df_f[df_f['Comments'] == 'Fire valve'].sort_values(by='Comments')
Fire_fighting_VALVE
# Out:
#                          Item description  Qty. Part # Manufacturer Location  \
# 490  FIRE ANGLE HOSE VALVE 2  1/2''  618R   1.0   A56     GIACOMINI   D-07-2
#
#        Comments
# 490  Fire valve

# %%
Wheel_CASTOR = df_f[df_f['Comments'] == 'Swivel castor'].sort_values(by='Comments')
Wheel_CASTOR
# Out:
#                             Item description  Qty.        Part # Manufacturer  \
# 81   SWIVEL CASTOR, D200, WITH SPRING SYSTEM   2.0  1-113-00289B        GLATT
# 153  S.S CASTOR WITH PU WHEELS , HEAVEY DUTY   4.0    S 31 07-07           GN
# 489   FIXED CASTOR D200, WITH SPRING SYSTEM    2.0  1-113-00289A        GLATT
# 739     240V, 0.75KW, BELT/ WHEEL SIZE 125MM   1.0   OUNB C24050   MORRISFLEX
#
#     Location       Comments
# 81    N-08-2  Swivel castor
# 153   N-08-2  Swivel castor
# 489   N-08-2  Swivel castor
# 739   J-11-1  Swivel castor

# %%
Water_Valve = df_f[df_f['Comments'] == 'Water valve'].sort_values(by='Comments')
Water_Valve
# Out:
#                                       Item description  Qty.  \
# 191  PREASURE TRANSMITTER WITH SENSOR FOR LEVEL, 3W...   1.0
# 747                            Seat Valve, 3/4",16 Bar   1.0
#
#                  Part #    Manufacturer Location     Comments
# 191  DB50L-EB00BB13CG30  ENDRESS+HAUSER   A-08-2  Water valve
# 747           J4SSG16U5            Omal   D-07-2  Water valve

# %%
FLOWMETER_CONTROLLER = df_f[df_f['Comments'] == 'Flowmeter controller'].sort_values(by='Comments')
FLOWMETER_CONTROLLER
# Out:
#                                    Item description  Qty.     Part #  \
# 479  FLOWMETER OF BATCH CONTROLLER, 4-20MA,12-36VDC   1.0  SE35/8035
#
#     Manufacturer Location              Comments
# 479      BURKERT   A-08-2  Flowmeter controller

# %%
FLOW_MODULE = df_f[df_f['Comments'] == 'Flow module'].sort_values(by='Comments')
FLOW_MODULE
# Out:
#                                       Item description  Qty.     Part #  \
# 481  FLOW ELECTRONIC MODULE , PNP, 12-36VDC, 0.7A, ...   1.0  SE32/8032
#
#     Manufacturer Location     Comments
# 481      BURKERT   A-08-2  Flow module

# %%
FORKLIFT_Wheel = df_f[df_f['Comments'] == 'Forklift wheel'].sort_values(by='Comments')
FORKLIFT_Wheel
# Out:
#   Item description  Qty.  Part # Manufacturer Location        Comments
# 7  Wheel BT 156259   1.0  156259          NaN      NaN  Forklift wheel

# %%
LIGHT = df_f[df_f['Comments'] == 'Light'].sort_values(by='Comments')
LIGHT
# Out:
#                               Item description   Qty.           Part #  \
# 6                WHITE LIGHT PROBE WM 03 PCT 2    1.0           919202
# 121                  SIGNAL FILAMENT LAMP, 28V    1.0            OR388
# 141                       SEARCH LIGHT 127 CM     1.0              NaN
# 367                LIGHT TOUCH CONTACT ELEMENT    1.0           912321
# 371                   LED LAMP 9W 6500K / 60CM   61.0               T8
# 372                  LED LAMP 9W  6500K / 60CM   62.0               T8
# 373                  LED LAMP 9W  6500K / 60CM   35.0               T8
# 374                  LED LAMP 5W  6500K / SPOT   20.0             MR16
# 375                   LED LAMP  8.8W 6500K E27   18.0              E27
# 376           LED FLOOD LIGHT 200W  2400 LUMEN    1.0  Floodlight 200W
# 377  LATHE 1/4HP, 1Ø, 1.6A, 2 SPEED , 2 SHAFTS    1.0           26 ESK
# 378                             LAMP, 3W, 130V  100.0         BA9S T10
# 478       FLUORESCENTS TUBES T8-150 CM F58W/35    8.0      29575/37627
# 483                         FLOROCENT 60CM 20W   25.0        FL20T9/19
# 484                           FLOOD LIGHT 150W    2.0              NaN
# 608             COVER FOR 60*60 LED PANEL UNIT    3.0              NaN
#
#     Manufacturer Location Comments
# 6        UHLMANN   N-08-3    Light
# 121           MG   K-13-2    Light
# 141      ELSWEDY   C-02-1    Light
# 367      UHLMANN   K-13-2    Light
# 371        CNYON   C-01-1    Light
# 372        VENUS   C-01-2    Light
# 373        ELIOS   C-01-1    Light
# 374        ELIOS   C-01-2    Light
# 375        VENUS   K-10-3    Light
# 376        ELIOS   C-01-2    Light
# 377     RED WING   L-12-1    Light
# 378     KEI LAMP   M-08-2    Light
# 478           GE   C-02-1    Light
# 483      TORNADO   C-01-2    Light
# 484          NaN   M-10-1    Light
# 608   3 BROTHERS   K-12-4    Light

# %%
Water_Test = df_f[df_f['Comments'] == 'Water test '].sort_values(by='Comments')
Water_Test
# Out:
#                                 Item description  Qty.        Part #  \
# 9     WATER TOTAL HARDNESS COLORIMETRIC REAGENTS   1.0    HI-93735-0
# 12  WATER LOW RANGE HARDNESS INDICATOR REAGENT A   2.0   HI93735A-LR
# 15              WATER HARDNESS INDICATOR REAGENT   2.0  HI93735IND-0
# 16                  WATER FREE CHLORINE REAGENT    1.0     HI93701-0
# 44                     TOTAL HARDNESS PHOTOMETER   1.0       HI97735
#
#    Manufacturer Location     Comments
# 9         HANNA   D-05-2  Water test
# 12        HANNA   L-12-3  Water test
# 15        HANNA   L-12-3  Water test
# 16        HANNA   D-05-2  Water test
# 44        HANNA   D-05-2  Water test

# %%
Water_station = df_f[df_f['Comments'] == 'Water pump'].sort_values(by='Comments')
Water_station
# Out:
#                                       Item description  Qty.  \
# 10    WATER TANK TRANSPERANT 60L, PE, WITH DOSING PUMP   1.0
# 11                WATER PROOF ELECTRIC BOX 10X10, IP55   1.0
# 13                   WATER JET PUMP, 1130W, 230V, IP44   1.0
# 21   VIRTICAL MULTISTAGE CENTERFUGAL PUMP 0.75KW, 1...   1.0
# 151      S.S PUMP WATER PUMP 3~, 1.1KW, 2.5A, 1.8M3/H    1.0
#
#                       Part # Manufacturer Location    Comments
# 10                  98148805     GRUNDFOS   N-11-4  Water pump
# 11                        15  THECNO TUBE   K-10-3  Water pump
# 13        JP 4-54 - 99458768     GRUNDFOS   L-10-1  Water pump
# 21   CRN 1-13 EY-CX-T-E-HUUE     GRUNDFOS   L-10-1  Water pump
# 151                 92733558     GRUNDFOS   L-11-1  Water pump

# %%
Water_HEATER = df_f[df_f['Comments'] == 'Water heater'].sort_values(by='Comments')
Water_HEATER
# Out:
#                  Item description  Qty.    Part # Manufacturer Location  \
# 14  WATER HEATER 27KW, 400V, IP25   1.0  DEX Next        CLAGE   M-11-1
#
#         Comments
# 14  Water heater

# %%
GLATT_NOZZLE = df_f[df_f['Comments'] == 'Glatt nozzle'].sort_values(by='Comments')
GLATT_NOZZLE
# Out:
#                    Item description  Qty.       Part # Manufacturer Location  \
# 17  WASHING NOZZLE TYPE A05, D=28MM   1.0  1-999-04156        GLATT   J-11-3
# 97     SPRAY NOZZLE, 100VG, SIZE 3,   1.0   20.1533-49          NaN   L-08-2
#
#         Comments
# 17  Glatt nozzle
# 97  Glatt nozzle

# %%
GLATT_SWITCH = df_f[df_f['Comments'] == 'Glatt  switch'].sort_values(by='Comments')
GLATT_SWITCH
# Out:
#                              Item description  Qty.       Part #  \
# 22  VIPRONIC POINT LEVEL SWITCH, IP66, 8.2VDC   1.0  943492-9000
#
#       Manufacturer Location       Comments
# 22  ENDRESS+HAUSER   E-06-1  Glatt  switch

# %%
FAN = df_f[df_f['Comments'] == 'Fan'].sort_values(by='Comments')
FAN
# Out:
#                                 Item description  Qty.          Part #  \
# 23       ventilation FAN 220-240 V 35W , 1850rpm  29.0    CC12038S220M
# 24        VENTELATION AXIAL FAN, 220V, 0.4A, 80W   1.0        220ZY-2E
# 25       VENTELATION AXIAL FAN, 220V, 0.22A, 38W   1.0  FB-108 EX-S1-S
# 39            TUBE AXIAL FAN 220AC/240V - 46/40W   1.0        FP-108-C
# 499                 FAN MOTOR 220-240VAC - 0.09A   2.0         2082HSL
# 500                   FAN MOTOR 220-240V - 0.08A   1.0     FD1238A2HSL
# 599       DC BRUSHERLESS FAN MOTOR 24VDC 0.36AMP   9.0       FP-108/DC
# 695  AXIAL VENTELATION FAN, 8X8CM, 240VAC,0.07A    1.0       PA80S-220
#
#      Manufacturer Location Comments
# 23      GOLDENSUN   E-05-3      Fan
# 24          TIDAR   L-13-2      Fan
# 25     COMOBREATH   L-13-2      Fan
# 39   COMMONWEALTH   E-05-3      Fan
# 499         LINDA   E-05-3      Fan
# 500       KINGSKY   E-05-3      Fan
# 599  COMMONWEALTH   E-05-3      Fan
# 695         TURBO   E-05-3      Fan

# %%
MOTOR = df_f[df_f['Comments'] == 'Motor'].sort_values(by='Comments')
MOTOR
# Out:
#                                 Item description  Qty.                Part #  \
# 26   VARIABLE SPEED GEARED MOTOR, 44W, 0.16A, 3Ø   1.0          0,047D2MRV-4
# 296                  MOTOR, 3Ø, 0.75KW, 2A, IP55   1.0              LSMV80LT
# 301                              MOTOR 6A, 8.5NM   1.0       ML34FN47060M8L4
# 320              MANUAL MOTOR STARTER, 10 TO 16A   1.0                 SFK0K
# 321           MANUAL MOTOR STARTER, 0.9 TO 1.25A   1.0         3RV2011-0KA10
# 322           MANUAL MOTOR CONTROL,3P,  9 TO 14A   1.0               GV2ME16
# 454                   GEARED MOTOR, 24VDC, 25.1W   1.0                912694
# 455    GEARED MOTOR 3Ø, 2.2KW, 4.7A, 1410/64 RPM   1.0  R57DV100M4/BMG/HR/TF
# 456                    GEARBOX , WITH S.S SHAFTS   1.0                   NaN
#
#           Manufacturer Location Comments
# 26          PLANETROIL   L-10-2    Motor
# 296        LEROY SOMER   L-13-2    Motor
# 301         EVER MOTOR   E-05-2    Motor
# 320   GENERAL ELECTRIC   M-10-2    Motor
# 321            SIEMENS   M-10-2    Motor
# 322          SCHNEIDER   M-10-2    Motor
# 454       GEFEG-NECKAR   L-13-2    Motor
# 455                SEW   L-13-1    Motor
# 456  COLOBO FILIPPETTI  N--09-1    Motor

# %%
GLATT_VALVE = df_f[df_f['Comments'] == 'Glatt valve'].sort_values(by='Comments')
GLATT_VALVE
# Out:
#                                      Item description  Qty.        Part #  \
# 27  VALVE, PN16, BRASS WITH ACTUATOR, 230V 7W, 16B...   1.0  8240200.9101
#
#      Manufacturer Location     Comments
# 27  IMI BUSCHJOST   B-10-3  Glatt valve

# %%
VACUUM_PUMP = df_f[df_f['Comments'] == 'Vacuum pump'].sort_values(by='Comments')
VACUUM_PUMP
# Out:
#                                      Item description  Qty.       Part #  \
# 28  VACUUM PUMP WITH MOTOR 3 PHASE 3-3.6AMP 1.25 K...   1.0  SV1040 C000
# 29      VACCUM PUMP 1Ø, 90M3/H, 0.37KW, 1.2A, 2820RPM   1.0       TSC.80
#
#    Manufacturer Location     Comments
# 28    BUSCH/ATB    K-101  Vacuum pump
# 29          DVP   L-12-1  Vacuum pump

# %%
GAUGE = df_f[df_f['Comments'] == 'Gauge'].sort_values(by='Comments')
GAUGE
# Out:
#                                  Item description  Qty.        Part #  \
# 30                 VACCUM DIAL GAUGE, -1 TO 1 BAR   6.0           WSG
# 319                      MARK II MANOMETER 250 Pa   1.0      40-250Pa
# 326  MANOMETER WITH ANALOG INDICATOR , 0 TO 10BAR   1.0           NaN
# 333               MAGNEHELIC PRESSURE GAUGE 60 Pa   1.0     2000-60Pa
# 334              MAGNEHELIC PRESSURE GAUGE 500 Pa   2.0  12-340001-00
# 335              MAGNEHELIC PRESSURE GAUGE 250 Pa   2.0  71-340001-0
# 425                      INCLINED TUBE MANOMETER    2.0    6552001000
#
#           Manufacturer Location Comments
# 30                SOLO   D-06-2    Gauge
# 319  DWYER INSTRUMENTS   D-06-2    Gauge
# 326            UHLMANN   L-10-3    Gauge
# 333                NaN      NaN    Gauge
# 334  DWYER INSTRUMENTS   D-06-2    Gauge
# 335  DWYER INSTRUMENTS   D-06-2    Gauge
# 425          SCHNEIDER   D-06-2    Gauge

# %%
Water_UV = df_f[df_f['Comments'] == 'Water uv'].sort_values(by='Comments')
Water_UV
# Out:
#           Item description  Qty.  Part #      Manufacturer Location  Comments
# 31  UV LAMP SLEEVE , 35''L   4.0  QS-012  STERILIGHT-VIQUA    K13-4  Water uv
# 32  UV LAMP 40W , 33.19''L   4.0   S36RL  STERILIGHT-VIQUA    K13-4  Water uv

# %%
UPS = df_f[df_f['Comments'] == 'Ups'].sort_values(by='Comments')
UPS
# Out:
#                           Item description  Qty.                   Part #  \
# 33  USB SERVER INDUSTRY ISOCHRON EATHERNET   1.0                    53642
# 34           UPS, I/P=24VDC, O/P=24VDC/10A   2.0   QUNIT-UPS/24DC/24DC/10
# 35      UPS BATTERY BANK 24V 1.3AH/15A MAX   1.0                  6182118
# 36                          UPS 24VDC, 20A   1.0  QUINT4-UPS/24DC/24DC/20
#
#         Manufacturer Location Comments
# 33               W&T   E-06-2      Ups
# 34  PHOENIX  CONTACT   F-05-2      Ups
# 35  PHOENIX  CONTACT   E-05-2      Ups
# 36  PHOENIX  CONTACT   F-05-2      Ups

# %%
HEATER = df_f[df_f['Comments'] == 'Heater'].sort_values(by='Comments')
HEATER
# Out:
#                                       Item description  Qty.    Part #  \
# 37                               UPPER SEALING ROLLER    1.0       NaN
# 440  HEATTING ELEMENT 9KW, 400V, 13A, L=335, WITH 2...   1.0   9050262
# 441                   HEATING ELEMENT, 750W, 230V, S.S   1.0   E112303
# 442                         HEATER 3~,9000W, 13A, IP50   1.0  9050262
# 443                                    HEATER 3~,8000W   1.0    202430
# 444                                    HEATER 3~,8000W   1.0    281920
# 445                                    HEATER , 2 WIRE   1.0      8619
# 745                      WATER HEATER 27KW, 400V, IP25   1.0  DEX Next
# 746                                Plate Heater 230 V    1.0     1000W
#
#     Manufacturer Location Comments
# 37           NaN   N-08-1   Heater
# 440          GWK   D-03-2   Heater
# 441         RICA   N-09-3   Heater
# 442          GWK   L-10-4   Heater
# 443         RICA   L-10-4   Heater
# 444         RICA   L-10-4   Heater
# 445      GRASEBY   L-10-4   Heater
# 745        CLAGE   M-11-1   Heater
# 746         Horn   D-03-2   Heater

# %%
Converter = df_f[df_f['Comments'] == 'Converter'].sort_values(by='Comments')
Converter
# Out:
#                                       Item description  Qty.  Part #  \
# 38        Universal Temperature Converter KFD2-UT2-Ex1   1.0  116917
# 476  Frequency Converter with Trip Values KFD2-UFC-...   1.0  188370
#
#       Manufacturer Location   Comments
# 38   PEPPERL+FUCHS   E-05-3  Converter
# 476  PEPPERL+FUCHS   E-05-3  Converter

# %%
BELTS = df_f[df_f['Comments'] == 'Belts'].sort_values(by='Comments')
BELTS
# Out:
#                             Item description  Qty.       Part #  \
# 40           TRAP BUILT SPA, 12.7*10, LP3350   2.0      5084177
# 42                           TOUTH BELTS KIT   7.0          NaN
# 45                TIMING BILT W=12, 103 TETH   2.0   12T10_1030
# 46   TIMING BELT, L=2550, STEP=150, T10-2550   4.0    L1H002010
# 47            TIMING BELT, L=2250, 225 TEETH   2.0     T10-2250
# 48      TIMING BELT, L=15'',W=3/8'',75 TEETH   1.0  150XL037-CR
# 49        TIMING BELT, 960*30*8MM, 120 TEETH   2.0    960-8M-30
# 50                    TIMING BELT- 330 teeth   1.0     T2.5-330
# 51                    TIMING BELT ; T10-2250   2.0     T10-2250
# 52             Timing Belt ,L=1840 , W=75 mm   5.0          NaN
# 428                           IMA GREEN BELT   1.0      B472476
# 610                    CONVEYOR BELT GG 40 U   1.0        70166
# 682         BRECOFLEX Timing Belt 16T10/2400   4.0        70207
# 690   BELT KIT , FLAT SUPER POWER; 610 x25MM   2.0       610x25
#
#         Manufacturer Location Comments
# 40               IMA   A-05-3    Belts
# 42               NaN   L-12-2    Belts
# 45             BRECO   J-08-2    Belts
# 46               IMA   A-05-3    Belts
# 47          OPTIBELT   J-08-2    Belts
# 48               NaN   A-05-3    Belts
# 49          OPTIBELT   A-05-3    Belts
# 50   WALTHER FLENDER   A-05-3    Belts
# 51             POGGI   A-05-3    Belts
# 52             Local   A-05-3    Belts
# 428              IMA   A-05-3    Belts
# 610          UHLMANN   J-09-2    Belts
# 682            BRECO   A-05-3    Belts
# 690          HABASIT      NaN    Belts

# %%
T_T = df_f[df_f['Comments'] == 'T & t'].sort_values(by='Comments')
T_T
# Out:
#                                      Item description  Qty.  \
# 41   TRACK & TRACE TOUCH SCREEN, 15'', IN S.S HOUSING   1.0
# 43               TOUCH SCREEN DISPLAY , XP ANALYTICAL   1.0
# 369                            LENS 12.5MM, F/1.4 VGA   1.0
# 397                  INDUSTRIAL 3D VISUALIZATION UNIT   1.0
# 486                       FLASH BOX FOR CAMERA SYSTEM   1.0
# 658          CAMERA, 0.8 MP, GIGABIT EATHERNET , RJ45   1.0
# 659                       CAMERA LENS 50MM, F/1.4 USM   1.0
# 660                       CAMERA LENS 40MM, F/2.8 STM   1.0
# 697                                 AUTOMATION PC 910   3.0
# 698                                 AUTOMATION PC 910   1.0
#
#                 Part #        Manufacturer Location Comments
# 41           TM 15 2.0      METTLER TOLEDO   E-02-1    T & t
# 43              PAT/04      METTLER TOLEDO   E-02-1    T & t
# 369      FL-BC1214D-VG               RICOH   M-08-3    T & t
# 397            HRC_S24      METTLER TOLEDO   M-08-3    T & t
# 486              B1450  IMAGO TECHNOLOGIES   E-05-2    T & t
# 658             TXG08C              BAUMER   M-08-3    T & t
# 659  EF 50mm f/1.4 USM               CANON   M-08-3    T & t
# 660  EF 40mm f/2.8 STM               CANON   M-08-3    T & t
# 697     5PC910.SX02-00                 B&R   E-03-1    T & t
# 698                NaN                 B&R   E-03-1    T & t

# %%
CONTROL = df_f[df_f['Comments'] == 'Control'].sort_values(by='Comments')
CONTROL
# Out:
#                                       Item description  Qty.  \
# 53             THYRISTOR CONTROL UNIT, 230V-50/60Hz-4A   2.0
# 396               INDUSTRIAL CONNECTOR, 6PIN, 16A, M+F   1.0
# 368  LEVEL INSTRUMENT CAPACITIVE , HYDROSTATIC, SIL...   1.0
# 337                         M12 CONNECTOR 4 PIN FEMALE   1.0
# 336  M12 CONNECTOR 4 PIN FEMALE WITH CABLE LED 10M ...   1.0
# 325         MANUAL MOTOR CONTROL , 1-1.6A, 400V,0.55KW   1.0
# 324         MANUAL MOTOR CONTROL , 2.5-4A, 400V, 1.5KW   1.0
# 323              MANUAL MOTOR CONTROL,3P,  1.6 TO 2.5A   1.0
# 314  MICRO MOTOR CONTROL BOX I/P 1~30VA,O/P 3-30VDC...   1.0
# 303  MINIATURE PHOTOELECTRIC , PNP, M8 CONNECTION, ...   1.0
# 612                            CONTROL BOX WITH SCREEN   1.0
# 295  MULTIFUNCTION CONTROL RELAY, 3Ø, 183 TO 528VAC...   1.0
# 213             PHOTRONIK CONTROLLER 230VAC 50HZ 0.9A    2.0
# 179                                  PRINT CONTROLLER    1.0
# 177                             PROGRAMABLE CONTROLLER   1.0
# 176          PROGRAMABLE CONTROLLER CPU UNIT, 16 POINT   1.0
# 119                 SIMATIC S7 CENTRAL PROCESSING UNIT   3.0
# 101                SONPROG PC INTERFACE FOR SONAR-BERO   1.0
# 98   SPEED CONTROLLER I/P 1Ø,O/P1  0-180DC, 4A, O/P...   1.0
# 75        TEMPERATURE CONTROLLER, 240VAC, WITH DISPLAY   1.0
# 74                     TEMPERATURE CONVETOR KFD2-UT2-1   1.0
# 233                        PHASE SHIFT CONTROL DEVICE    1.0
# 613                                      CONTROL BOARD   1.0
#
#                  Part #    Manufacturer Location Comments
# 53           TSG 4-V.05        UHLMANN    K-13-2  Control
# 396                  6M         HARTING   K-13-2  Control
# 368   Silometer FMC671Z  ENDRESS+HAUSER   F-01-1  Control
# 337                 M12        AIXONTEC   K-10-2  Control
# 336  7000-12291-2341000            MURR   M-10-3  Control
# 325           PKZM0-1,6           EATON   M-10-2  Control
# 324             PKZM0-4           EATON   M-10-2  Control
# 323           PKZM0-2,5         MOELLER   M-10-2  Control
# 314              UC503C           URAWA   F-01-1  Control
# 303             6002803       DATALOGIC   E-05-2  Control
# 612           109836013           ARGUS   F-01-4  Control
# 295           RM17-TE00       SCHNEIDER   M-10-2  Control
# 213             PS364-2            SICK   K-08-1  Control
# 179            M600 OEM           WOLKE   E-05-2  Control
# 177           PLS 511 S          EBERLE   K-11-4  Control
# 176         CQM1H-CPU51           OMRON   K-11-4  Control
# 119  6ES7317-2AJ10-0AB0         SIEMENS   E-01-2  Control
# 101             3RX4001         SIEMENS   K-13-2  Control
# 98             EVD533-E           LENZE   M-11-2  Control
# 75            TCN4H-24R        AUTONICS   I-10-2  Control
# 74               191884   PEPPERL+FUCHS   E-05-3  Control
# 233         33 43303B00          BINDER   M-10-2  Control
# 613            QK-CE220           QUIKO   F-01-2  Control

# %%
THERMOSTATE = df_f[df_f['Comments'] == 'Thermostate'].sort_values(by='Comments')
THERMOSTATE
# Out:
#                      Item description  Qty.        Part # Manufacturer  \
# 54  THERMOSTATE 230V,2A, IP54, 150-7C   1.0        ATH-70         JUMO
# 55  THERMOMETER, FLAT, PT100, M44X1.5   1.0  29-999-16650        GLATT
#
#    Location     Comments
# 54   E-06-2  Thermostate
# 55   K-09-2  Thermostate

# %%
THERMOCOUPLE = df_f[df_f['Comments'] == 'Thermocouple'].sort_values(by='Comments')
THERMOCOUPLE
# Out:
#                                   Item description  Qty.    Part #  \
# 56  THERMOCOUPLE , TYPE J, TMAX=270C - 74315-01/27   1.0  IMA00034
#
#    Manufacturer Location      Comments
# 56      TERMICS   E-05-2  Thermocouple

# %%
PRENTER = df_f[df_f['Comments'] == 'Prenter'].sort_values(by='Comments')
PRENTER
# Out:
#                              Item description  Qty.            Part #  \
# 57           THERMAL TRANSFER DESKTOP PRINTER   1.0  ZD22042-T0EG00EZ
# 58  THERMAL INKJET PRENTER+ SMART JET DUE PRO   1.0     SMART JET ONE
#
#    Manufacturer Location Comments
# 57        ZEBRA   M-13-4  Prenter
# 58          MCC   M-13-3  Prenter

# %%
JUMPER = df_f[df_f['Comments'] == 'Jumper'].sort_values(by='Comments')
JUMPER
# Out:
#                           Item description  Qty.   Part # Manufacturer  \
# 59  TERMINAL JUMPER, 800V, INSULATED, GRAY  13.0  282-402         WAGO
# 60                   TERMINAL JUMPER, 800V  45.0  280-402         WAGO
#
#    Location Comments
# 59   K-13-2   Jumper
# 60   K-13-2   Jumper

# %%
CONDUCTOR = df_f[df_f['Comments'] == 'Conductor'].sort_values(by='Comments')
CONDUCTOR
# Out:
#                                      Item description  Qty.     Part #  \
# 61            TERMINAL BLOCK, 2 CONDUCTOR, 6MM2, GRAY   9.0    282-101
# 62          TERMINAL BLOCK, 2 CONDUCTOR, 2.5MM2, GRAY  66.0    280-901
# 63           TERMINAL BLOCK, 2 CONDUCTOR, 16MM2, GRAY   4.0  TOP JOB S
# 64  TERMINAL BLOCK, 2 CONDUCTOR GROUND,1 6MM2, GRE...   1.0  TOP JOB S
# 65  TERMINAL BLOCK, 2 CONDUCTOR GROUND, 6MM2, GREE...   2.0    282-107
# 66  TERMINAL BLOCK, 2 CONDUCTOR GROUND, 2.5MM2, GR...  21.0    280-907
#
#    Manufacturer Location   Comments
# 61         WAGO   K-13-2  Conductor
# 62         WAGO   K-13-2  Conductor
# 63         WAGO   K-13-2  Conductor
# 64         WAGO   K-13-2  Conductor
# 65         WAGO   K-13-2  Conductor
# 66         WAGO   K-13-2  Conductor

# %%
SPRING = df_f[df_f['Comments'] == 'Spring'].sort_values(by='Comments')
SPRING
# Out:
#                           Item description  Qty.                       Part #  \
# 67             TENSION SPRING, 1.4X10X35.3   1.0                       904511
# 68                TENSION SPRING, 1.2X9X82   1.0                       136088
# 69                          TENSION SPRING   2.0                      B402997
# 95   SPRINGS FOR LEAFLET COMPNSIATION ARM    6.0  132L 27MM DI 3MM THICKNESS
# 96                   SPRING PRESSURE PIECE  70.0                      2149276
# 180               PRESSURE SPRING, 2X12X44   1.0                        56557
# 181               PRESSURE SPRING, 1X17X30   1.0                       136118
# 182                    PRESSURE SPRING SET   1.0                       755954
#
#     Manufacturer Location Comments
# 67       UHLMANN   J-11-3   Spring
# 68       UHLMANN   J-11-3   Spring
# 69           IMA   J-11-3   Spring
# 95       FUTUER      A2-4   Spring
# 96         FETTE   J-11-3   Spring
# 180      UHLMANN   J-11-3   Spring
# 181      UHLMANN   J-11-3   Spring
# 182      UHLMANN   J-11-3   Spring

# %%
STILMA = df_f[df_f['Comments'] == 'Stilmas sensor'].sort_values(by='Comments')
STILMA
# Out:
#                                 Item description  Qty.        Part #  \
# 70            TEMPERATURE SENSOR, PT100, CLASS A   1.0  TSRT-6702UAB
# 71  TEMPERATURE SENSOR PT1000,WITH DISPLAY, M18    2.0        TN7530
# 72         TEMPERATURE SENSOR ,PT100, 200C, IP65   1.0   902820.7012
#
#       Manufacturer Location        Comments
# 70  ENDRESS+HAUSER   E-06-2  Stilmas sensor
# 71             IFM   E-06-2  Stilmas sensor
# 72            JUMO   E-06-2  Stilmas sensor

# %%
MODULE = df_f[df_f['Comments'] == 'Module'].sort_values(by='Comments')
MODULE
# Out:
#                                       Item description  Qty.  \
# 73                         TEMPERATURE MODULE, 8 INPUT   1.0
# 607                CPU + SOFTWARE FOR ECOGRAPH T RSG35   1.0
# 606                                           CPU CARD   1.0
# 605                              CPU MODULE FOR S7-200   1.0
# 544                              DIGITAL INPUT MODULE    1.0
# 543             DIGITAL INPUT/OUTPUT MODULE FOR S7-200   1.0
# 474                            FUNCTION MODULE, 13 PIN   2.0
# 661                                 CAM SWITCH MODULE    1.0
# 390                          INPUT MODULE 3DI476.6 16E   1.0
# 248                     OPTO-COUPLER 6.2MM, 24VDC, 2 A   1.0
# 247      OPTO-COUPLER MODULE, I/P 53VDC, O/P53VDC, 4 A   1.0
# 245                              OUTPUT MODULE DIGITAL   1.0
# 244               OUTPUT UNIT 16 POINT, TRANSISTOR PNP   1.0
# 243               OUTPUT UNIT 16 POINT, TRANSISTOR PNP   1.0
# 140  SELECTIVITY MODULE, 4 CHANNEL,I/P 24VDC, 40A, ...   3.0
# 249                  OPERATOR KEYPAD MODULE, 8 BUTTONS   2.0
# 700     ASSEMBLY MODULE ,MP6, MOUNTING RAIL SCREW TYPE   2.0
#
#                  Part #    Manufacturer Location Comments
# 73             2AT300.6  B&R AUTOMATION   I-10-3   Module
# 607      XPR0008-1009/0  ENDRESS+HAUSER   F-01-2   Module
# 606                 B12             GWC   E-05-2   Module
# 605  6ES7216-2AD23-0XB0         SIEMENS   E-05-4   Module
# 544            3DI476.6  B&R AUTOMATION   K-11-4   Module
# 543  6ES7223-1BH22-0XA0         SIEMENS   E-05-4   Module
# 474         E82ZAFSC100           LENZE   E-06-2   Module
# 661        2DS100.60-1   B&R AUTOMATION   I-10-3   Module
# 390              913335         UHLMANN   F-05-2   Module
# 248              526059            MURR   K-13-2   Module
# 247               50044            MURR   K-13-2   Module
# 245            2DO428.6  B&R AUTOMATION   I-10-3   Module
# 244          CQM1-OD214           OMRON   E-05-4   Module
# 243          CQM1-OD214           OMRON   E-05-4   Module
# 140       6EP1961-2BA00         SIEMENS   K-13-2   Module
# 249              E82ZBC           LENZE   E-06-2   Module
# 700               62001            MURR   K-13-2   Module

# %%
DATA_LOGGER = df_f[df_f['Comments'] == 'Data logger'].sort_values(by='Comments')
DATA_LOGGER
# Out:
#                         Item description  Qty.    Part #   Manufacturer  \
# 76  TEMPERATURE AND HUMIDITY DATA LOGGER   2.0  TGU-4500       TINY TAG
# 77        TEMPERATURE / HUMIDITY SENSOR    1.0     THC-P  LOVE CONTROLS
#
#    Location     Comments
# 76   I-09-2  Data logger
# 77   E-06-2  Data logger

# %%
PANEL = df_f[df_f['Comments'] == 'Panel'].sort_values(by='Comments')
PANEL
# Out:
#                    Item description  Qty.              Part #  \
# 79            Temp Control Unit GWK   1.0             9070766
# 250  OPERATION PANEL FOR SIMATIC S7   2.0  6AV3617-1JC20-0AX1
# 251  OPERATION PANEL FOR PESTER PAC   2.0       PCS095 M PLUS
#
#                  Manufacturer Location Comments
# 79                        GWK   A-05-3    Panel
# 250                   SIEMENS   F-01-1    Panel
# 251  ELEKTRONIK SYSTEME LAUER   E-02-1    Panel

# %%
SWITCH = df_f[df_f['Comments'] == 'Switch'].sort_values(by='Comments')
SWITCH
# Out:
#                                       Item description  Qty.          Part #  \
# 82                                  SWITCH WITH 14 PIN   1.0         6150096
# 541  DIGITAL TEMPERATURE SWITCH PROBE, PTC, -50 TO ...   1.0           TS-51
# 502                           ETHERNET SWITCH , 8XRJ45   1.0      1240900000
# 381                               KEY FOR LIMIT SWITCH   1.0          XCKY02
# 380                              KEY OPERATION SWITCH    2.0       QRJSSA12E
# 379                                            KEY SET   1.0          909761
# 366                     LIMIT SWITCH , 220V, 2A, N0/NC   1.0        WLCA12-2
# 365                LIMIT SWITCH , IP65, 220V,3A, N0/NC   4.0     L5K13MEM123
# 364  LIMIT SWITCH MECHANICAL, IP54, 15A@250VAC, 2N0...   1.0       055.000.5
# 363                    LIMIT SWITCH, NO/NC, 5A, 230VAC   1.0       151155769
# 362                    LIMIT SWITCH, NO/NC, 5A, 250VAC   1.0         ME-8104
# 361                       LINEAR ARRAY, 4'',RED, 24VDC   1.0          AL4424
# 332             MAGNETEC FLOAT SWITCH, IP65, 230VAC/DC   1.0  ELS-AA 9010038
# 331       Magnetic Reed switch ,2 wire, 24VAC/DC, 0.5m   1.0         5810117
# 330  MAGNITIC DOOR CONTACT SWITCH  WITH MAGNET, S.S...  28.0         2507A-L
# 313             MICRO SWITCH FOR FORKLEFT, 10A, 250VAC   2.0          156278
# 312                       MICRO SWITCH PS 1041 303 PHM   1.0          903931
# 311                           MICRO SWITCH, NO+NC, 15A   1.0     BZ-2RW84-A2
# 289        NON CONTACT MAGNITIC SAFETY SWITCH, 1NO+1NC   1.0         1059411
# 139              SELECTOR SWITCH WITH KNOB 2 POSITION    1.0        P9MSMD0N
# 696                     AUXILIARY SWITCH BLOCK, 1N+2NC   2.0   3RH1911-1HA12
# 699                 AUTO REED SWITCH ,SOLID STATE ,PNP   4.0           D-F7P
#
#               Manufacturer Location Comments
# 82                     IMA   M-10-3   Switch
# 541          LOVE CONTROLS   I-08-2   Switch
# 502             WEIDMULLER   M-13-3   Switch
# 381              SCHNEIDER   K-09-2   Switch
# 380               SCHLEGEL   K-13-2   Switch
# 379                UHLMANN   K-13-2   Switch
# 366                    MMR   F-06-2   Switch
# 365                   EMAS   F-06-2   Switch
# 364                   MAYR   F-06-2   Switch
# 363              SCHMERSAL   F-06-2   Switch
# 362                 MOUJEN   F-06-2   Switch
# 361  ADVANCED ILLUMINATION   M-08-2   Switch
# 332            KSR KUEBLER   A-08-2   Switch
# 331                    IMA   K-10-2   Switch
# 330                SENTROL   M-08-2   Switch
# 313                KUMATSO   N-10-3   Switch
# 312                UHLMANN   F-06-2   Switch
# 311                  MICRO   F-06-2   Switch
# 289                   SICK   E-06-2   Switch
# 139       GENERAL ELECTRIC   K-13-2   Switch
# 696                SIEMENS   M-10-2   Switch
# 699                    SMC   I-08-2   Switch

# %%
FORKLIFT_SWITCH = df_f[df_f['Comments'] == 'Forklift switch'].sort_values(by='Comments')
FORKLIFT_SWITCH
# Out:
#                      Item description  Qty.      Part # Manufacturer Location  \
# 83                SWITCH FOR FORKLIFT   2.0      156281           BT   B-10-2
# 202  POTENTIOMETER,  CPL FOR FORKLIFT   1.0      231232           BT   B-10-2
# 203           POTENTIOMETER,  AUX R/L   1.0  9600-601-4        CROWN   N-10-3
# 204           POSITION SWITCH, 1NO/NC   1.0       LS-11      MOELLER   F-06-2
#
#             Comments
# 83   Forklift switch
# 202  Forklift switch
# 203  Forklift switch
# 204  Forklift switch

# %%
Amplifier = df_f[df_f['Comments'] == 'Amplifier'].sort_values(by='Comments')
Amplifier
# Out:
#                        Item description  Qty.                     Part #  \
# 84     Switch Amplifier KFD2-ST2-Ex1.LB   1.0                     180997
# 85      Switch Amplifier KFD2-SR2-Ex2.W   1.0                     132960
# 86   Switch Amplifier KFD2-SR2-Ex1.W.LB   1.0                     132959
# 87      Switch Amplifier KFD2-SR2-Ex1.W   1.0                     132958
# 88         Switch Amplifier KFD2-SH-Ex1   1.0                      46903
# 426              IMPELLER 40-200/210 CI   1.0                   96039185
# 427               IMAGE BASED ID READER   1.0  MATRIX 210 212-110 SB4494
#
#       Manufacturer Location   Comments
# 84   PEPPERL+FUCHS   E-05-3  Amplifier
# 85   PEPPERL+FUCHS   E-05-3  Amplifier
# 86   PEPPERL+FUCHS   E-05-3  Amplifier
# 87   PEPPERL+FUCHS   E-05-3  Amplifier
# 88   PEPPERL+FUCHS   E-05-3  Amplifier
# 426       GRUNDFOS   L-13-3  Amplifier
# 427      DATALOGIC   E-06-2  Amplifier

# %%
FETTE = df_f[df_f['Comments'] == 'Fette'].sort_values(by='Comments')
FETTE
# Out:
#                          Item description  Qty.   Part # Manufacturer  \
# 92           STRIPPER 1 COMPL.P 2100, S.S   1.0  3500414        FETTE
# 154       RUBBER BOOT FOR FILL -O - MATIC   1.0  3105241        FETTE
# 602              CUPPER CURVES AND DEVICE   2.0  3500408        FETTE
# 603  CUPPER BAR FOR STRIPPER , P2000/2100   1.0  3100411        FETTE
#
#     Location Comments
# 92    J-11-3    Fette
# 154   B-02-2    Fette
# 602   J-11-3    Fette
# 603   J-11-3    Fette

# %%
Filters_CARTAGE = df_f[df_f['Comments'] == 'Filters cartage'].sort_values(by='Comments')
Filters_CARTAGE
# Out:
#                                       Item description  Qty.           Part #  \
# 93                 STERLIZING GRADE AIR AND GAS FILTER   3.0  ZEMTB-020TT-AN3
# 706  AIR FILTER CARTAGE , HIGHFLOW TETPOR H.T 0.2µm...   1.0        ZCHT/2C-N
# 707           AIR FILTER , DEMI CARTAGE, 2.5'', 0.2µm    4.0          ZHFT/BT
#
#     Manufacturer Location         Comments
# 93        PARKER   N-10-3  Filters cartage
# 706       PARKER   C-06-2  Filters cartage
# 707       PARKER   C-06-2  Filters cartage

# %%
SOLENOID_VALVE = df_f[df_f['Comments'] == 'Solenoid valve'].sort_values(by='Comments')
SOLENOID_VALVE
# Out:
#                                       Item description  Qty.  \
# 102  SOLINOID VALVE WITH ACTUATOR 2.5A, 220V, 10BAR...   2.0
# 288           NON RETURN VALVE WITH CLAMP, 1 1/2'',S.S   1.0
# 287   NON RETURN VALVE WITH CLAMP, 1/2 X 1/2'', 12 BAR   1.0
# 240  PENUMATIC FILTER WITH REGULATOR, 5µM, 0 TO 10 BAR   1.0
# 239     PENUMATIC SINGLE SOLENOID, 2 POSITION  , 24VDC   1.0
# 238       PENUMATIC/ SPRING, BUTTERFLY VALVE , NC, S.S   1.0
# 186   Pressure Regulator ,Harris Inlet 200 Bar , ArCo2   1.0
# 185      PRESSURE RELIEF SAFETY VALVE PN10,1/2''/3/4''   1.0
# 184  PRESSURE RGULAUR PENUMATIC, 8BAR, RELEAVING +G...   1.0
# 524            ELECTRIC SOLENOID ACTUATOR, 24VDC, 1A,    1.0
# 183          PRESSURE SENSOR, RANGE -0.2TO 0.2BAR,IP66   3.0
# 118    SINGLE SOLENOID PILOT ACTUATED 4/2-VALVE, 24VDC   1.0
# 117    SINGLE SOLENOID PILOT ACTUATED 5/2-VALVE, 24VDC   2.0
# 116    SINGLE SOLENOID PILOT ACTUATED 5/2-VALVE, 24VDC   1.0
# 110        SOLENOID VALVE PENUMATIC, 10BAR, 3/2, 24VDC   2.0
# 109        SOLENOID VALVE PENUMATIC, 10BAR, 3/2, 24VDC   1.0
# 108                    SOLENOID VALVE PENUMATIC, 16BAR   4.0
# 107        SOLENOID VALVE PENUMATIC, 16BAR, 3/2, 24VDC   1.0
# 106            SOLENOID VALVE PNEUMATIC , 10BAR, 3/2     1.0
# 162                 REPL..IND.POSIZ . BAND ROLLER ALVE   1.0
# 539           DISC ASEPTIC DIAPHRAM VALVE . S.S, 3/4''   1.0
#
#                Part #   Manufacturer Location        Comments
# 102           9360151            GWK   B-10-3  Solenoid valve
# 288    048Z60150PT121      RATTTINOX   D-05-2  Solenoid valve
# 287             11691          FESTO   B-10-3  Solenoid valve
# 240  LFR-M2-G3/8-C10S          FESTO   B-10-3  Solenoid valve
# 239        B5E6ACA49C         PARKER   B-10-3  Solenoid valve
# 238           102.095            AWH   J-12-3  Solenoid valve
# 186               801         Harris   D-06-2  Solenoid valve
# 185            253046  CALEFFI SOLAR   B-10-3  Solenoid valve
# 184       P31RA12BNTP         PARKER   B-10-3  Solenoid valve
# 524            70-134           FIKE   B-10-3  Solenoid valve
# 183  BR64.CKLC3MHVMXX           VEGA   A-08-2  Solenoid valve
# 118   031SA4004012B61       NUMATICS   B-10-3  Solenoid valve
# 117   181BA400A000061       NUMATICS   B-10-3  Solenoid valve
# 116   181BA400A0B1661       NUMATICS   B-10-3  Solenoid valve
# 110           LV5EM41       NUMATICS   B-10-3  Solenoid valve
# 109   L22BA452BG00061       NUMATICS   B-10-3  Solenoid valve
# 108   L88EM44GGS00061       NUMATICS   B-10-3  Solenoid valve
# 107   L78EM45GGS00061       NUMATICS   B-10-3  Solenoid valve
# 106         MCH-3-1/4          FESTO   B-10-3  Solenoid valve
# 162       919BH166700           SIKO   E-05-2  Solenoid valve
# 539     061A60075PT70      RATTTINOX   D-05-2  Solenoid valve

# %%
SOCKET = df_f[df_f['Comments'] == 'Socket'].sort_values(by='Comments')
SOCKET
# Out:
#                        Item description  Qty.     Part #     Manufacturer  \
# 112  SOCKET ON DIN RAIL, 16A,250V, 2P+E   1.0     USA-2P            VIMAR
# 609   COUPLING SOCKET, 6+PE,  10A, 250V   1.0  T3104 001  AMPHENOL-TUCHEL
#
#     Location Comments
# 112   K-13-2   Socket
# 609   M-10-3   Socket

# %%
RELAY = df_f[df_f['Comments'] == 'Relay'].sort_values(by='Comments')
RELAY
# Out:
#                                      Item description  Qty.          Part #  \
# 103                 SOLID STATE RELAY ,90A,24-600VAC    1.0        SO967960
# 104         SOLID STATE RELAY ,25A,CONTROL V 4-32VDC    5.0  RA 2425 -D 06
# 105        SOLID STATE RELAY ,100A,CONTROL V 4-32VDC    3.0      RM1A48D100
# 145                 SAFETY SWITCH MAGNITIC, NC+NO, 4A   1.0       101152094
# 146                  SAFETY RELAY PNOZ m1p 24V DC 28W   1.0          773100
# 147                SAFETY RELAY 2SAFETY CONTACT, 3.5W   5.0          475695
# 148                    Safety relay 2NO , 24VDC, 2.5W   1.0          751103
# 149                                     SAFETY RELAY    1.0       101120594
# 150                          SAFETY CONTACT EXPANTION   3.0          774580
# 163                             RELAY, 8 PIN,24VDC,5A   1.0           G2R-2
# 164                         RELAY, 24VDC,10A - 2228H1   1.0           G2R-1
# 242                         OVERLOAD RELAY, 42 TO 55A   1.0            RT2G
# 304                   MINI RELAY 6A, 24VDC - 84229090   1.0         6400117
# 305                              MINI RELAY 6A, 24VDC   NaN             NaN
# 329  MAGNITIC SAFETY SENSOR, 1NO,1NC, 24VDC,1W, 100MA   4.0       101120670
#
#          Manufacturer Location Comments
# 103            CELDUC   M-10-2    Relay
# 104     CARLO GAVAZZI   M-10-2    Relay
# 105     CARLO GAVAZZI   L-10-4    Relay
# 145         SCHMERSAL   E-06-2    Relay
# 146              PILZ   E-06-2    Relay
# 147              PILZ   K-09-2    Relay
# 148              PILZ   E-06-2    Relay
# 149         SCHMERSAL   E-06-2    Relay
# 150              PILZ   K-09-2    Relay
# 163             OMRON   E-05-2    Relay
# 164             OMRON   E-05-2    Relay
# 242  GENERAL ELECTRIC   M-10-2    Relay
# 304            FINDER   E-05-2    Relay
# 305               NaN      NaN    Relay
# 329         SCHMERSAL   E-06-2    Relay

# %%
neumatic_HOSE = df_f[df_f['Comments'] == 'Neumatic hose'].sort_values(by='Comments')
neumatic_HOSE
# Out:
#                                       Item description  Qty.         Part #  \
# 111               SOFT PVC HOSE ARMORED , FOOD CONTACT   2.0       ARMORVIN
# 171  PVC TRANSPERANT HOSE 38*5,FOOD GRADE WITH END ...   1.0  IH35641038/50
# 172  PVC 30*25MM AIR HOSE , FOOD GRADE, W.P 10 BAR ...   1.0          30X25
# 234         PENUMATICE HOSE POLYURTHAN 8X5,150PSI, 15M   1.0            805
# 235              PENUMATICE HOSE POLYURTHAN 6X4,150PSI   1.0            604
# 236              PENUMATICE HOSE POLYURTHAN 6X4,150PSI   1.0            6X4
# 237             PENUMATICE HOSE POLYURTHAN 12X8,150PSI   1.0           1280
# 431  HOSE, SILICONE, WITH TEXTILE REINFORCEMENT, WH...   1.0   GSI 65NT-FDA
# 432  HOSE WITH FABRIC LINING L=2.7, 19*4MM FOOD GRA...   1.0    OCO601716EH
# 433                                HOSE 3/4 W.P=30BAR    1.0            NaN
# 485    FLEXIBLE HOSE 1'', GRAY, 3M, FOR VACUUM CLEANER   2.0     1INCH HOSE
# 525      ELECTRIC PLASTIC HOSE WITH END GLANDS M20X1.5   1.0            NaN
# 687          BLACK NYLON HOSE 1/2'' FOR HIGH PRESSURE    1.0        DASH 10
#
#     Manufacturer Location       Comments
# 111    ARMORVIN    L-08-3  Neumatic hose
# 171       PARKER   L-08-3  Neumatic hose
# 172          AMA   L-08-3  Neumatic hose
# 234          ggi   D-02-2  Neumatic hose
# 235         SAZN   D-02-2  Neumatic hose
# 236          ABA   D-02-2  Neumatic hose
# 237         SAZN   D-02-2  Neumatic hose
# 431     GECITECH   L-08-2  Neumatic hose
# 432        GLATT   L-08-3  Neumatic hose
# 433     AIR HOSE   L-08-3  Neumatic hose
# 485      NILFISK   L-08-2  Neumatic hose
# 525      TEAFLEX   E-05-2  Neumatic hose
# 687  MASTER PLUS   L-08-3  Neumatic hose

# %%
Power_Supply = df_f[df_f['Comments'] == ''].sort_values(by='Comments')
Power_Supply
# Out:
# Empty DataFrame
# Columns: [Item description, Qty., Part #, Manufacturer, Location, Comments]
# Index: []

# %%
leaflet_rooler = df_f[df_f['Comments'] == 'Leaflet rooler'].sort_values(by='Comments')
leaflet_rooler
# Out:
#                                    Item description  Qty.  \
# 114  Size 220mm/50mm Alumnum Dorval leaflet rooler    5.0
# 115  Size 220mm/15mm Alumnum Dorval leaflet roller    4.0
# 122                Short Manual Leaflet real shaft    2.0
# 123                                 SHIM PS 15X22X1   1.0
# 341                 Long Manual Leaflet real shaft    1.0
# 685  Black rubber roller for leaflet 315 mm 220mm L   4.0
# 686    Black rubber roller for leaflet 210mm 22mm L   2.0
#
#                        Part # Manufacturer Location        Comments
# 114  220x50mm almunum Roller        Local      A2-4  Leaflet rooler
# 115               220mm/15mm      Oregnal      A2-4  Leaflet rooler
# 122         350mm L 690mm Di      Oregnal      A2-4  Leaflet rooler
# 123                    904594      UHLMANN   N-08-3  Leaflet rooler
# 341          475mm L 750mm Di     Oregnal      A2-4  Leaflet rooler
# 685      220mm 315mm dimater      Oregnal      A2-4  Leaflet rooler
# 686      220mm 210mm dimater      Oregnal      A2-4  Leaflet rooler

# %%
SHAFT = df_f[df_f['Comments'] == 'Shaft'].sort_values(by='Comments')
SHAFT
# Out:
#               Item description  Qty.           Part # Manufacturer Location  \
# 124  SHAFT SEAL KIT BAQE D28MM   1.0         96488302     GRUNDFOS   L-13-3
# 328          main index shaft    2.0  335mm L x 20mm      uhlmann       NaN
#
#     Comments
# 124    Shaft
# 328    Shaft

# %%
SERVO_DRIVER = df_f[df_f['Comments'] == 'Servo driver'].sort_values(by='Comments')
SERVO_DRIVER
# Out:
#                                       Item description  Qty.  \
# 127  SERVO DRIVER I/P 3~,1.2A,O/P 3~ ,0-480V, 0-300...   1.0
# 128  SERVO DRIVER I/P 3~, 3.7A,O/P 3~, 0-480V, 0-30...   1.0
# 129  SERVO DRIVER I/P 3~, 2.5A,O/P 3~, 0-480V, 0-30...   1.0
# 130                         SERVO DRIVE 1.5KW, 0-400HZ   1.0
# 681                   BRUSHLESS MOTOR 0.3KW ,400V,1.3A   1.0
# 724  AC SERVO DRIVER, I/P 1Ø, 4.1A, O/P 3Ø, 400W, 2.6A   1.0
# 725  AC SERVO DRIVER, I/P 1Ø, 2.4A, O/P 3Ø, 200W, 1.6A   1.0
# 726  AC SERVO DRIVER, I/P 1~,6.6A,O/P 3~, 0-240V, 4...   1.0
# 727  AC SERVO DRIVER, I/P 1~,1.6A,O/P 3~, 0-240V, 1.2A   1.0
# 728  AC SERVO DRIVE I/P 3~,400V,2.5A,O/P 3~,0-480V,...   4.0
# 729  AC SERVO DRIVE I/P 1~,230V,2A,O/P 3~,90.3V,1.6...   1.0
# 730     AC DRIVE, I/P 1~,5A,O/P 3~2.4A,0.37KW, 0-650HZ   1.0
# 731  AC DRIVE, 1.1KW, I/P 1Ø, 9.2A, O/P 3Ø, 0-400HZ...   1.0
# 732             AC DRIVE ,7.5KW, 17A,3Ø, 0-500HZ, IP21   0.0
# 733             AC DRIVE ,11KW, 25A, 3Ø, 0-500HZ, IP21   0.0
# 734            AC DRIVE , 15 KW, 32A,3Ø, 0-500HZ, IP21   0.0
#
#                     Part # Manufacturer Location      Comments
# 127           SGDV-1R9D11A      YASKAWA   A-09-2  Servo driver
# 128           SGDV-5R4D11A      YASKAWA   F-01-1  Servo driver
# 129           SGDV-3R5D11A      YASKAWA   M-11-3  Servo driver
# 130      VF1404MC9PT1BR1_1         LUST   M-11-2  Servo driver
# 681          SGMEV-03DDA61      YASKAWA   E-05-2  Servo driver
# 724              MBDKT2510    PANASONIC   F-02-1  Servo driver
# 725              MADHT1507    PANASONIC   F-02-1  Servo driver
# 726              MCDHT3520    PANASONIC   M-12-4  Servo driver
# 727              MADHT1505    PANASONIC   M-12-4  Servo driver
# 728           SGDV-3R5D11A      YASKAWA   F-01-1  Servo driver
# 729              MADDT1207    PANASONIC   M-12-4  Servo driver
# 730         E82EV371K2C200        LENZE   M-11-3  Servo driver
# 731         N 0002 2S XBK2        SINUS   M-11-3  Servo driver
# 732  ACS580_01-018A-4+J400          ABB   F-03-4  Servo driver
# 733  ACS580_01-026A-4+J400          ABB   F-03-4  Servo driver
# 734  ACS580-01-033A-4+J400          ABB   F-03-4  Servo driver

# %%
SERVO_MOTOR = df_f[df_f['Comments'] == 'Servo motor'].sort_values(by='Comments')
SERVO_MOTOR
# Out:
#                                      Item description  Qty.         Part #  \
# 94            STEPPING MOTOR DRIVING CARD I/P 4-90VAC   2.0        6042501
# 125              SERVO MOTOR, 3Ø, 1.3KW,5.4A, 1500RPM   2.0  SGMGV-13DDA6H
# 126          SERVO MOTOR 2.9KW, 11.9A, 1500RPM,18.6NM   1.0  SGMGV-30DDA6H
# 718   AC SERVOMOTOR 3~AC,94V,1.5A,0.2KW,250HZ,3000RPM   2.0     MSME022G1U
# 719        AC SERVOMOTOR 3~AC,220V,0.89A,100W,3000RPM   1.0  SGMEV-01ADA61
# 720  AC SERVOMOTOR 3~AC,114V,2.4A,0.4KW,250HZ,3000RPM   1.0     MSME042G1U
# 721      AC SERVO MOTOR, 3Ø, 120V, 4.1A, 0.75KW, IP67   1.0     MSME082G1U
# 722       AC SERVO MOTOR 400V,250HZ,2.2A,650W,3000RPM   1.0  SGMEV-07DDA61
# 723   AC SERVO MOTOR 3~, 78V,250HZ,1.1A,0.1KW,3000RPM   1.0     MSME012G1U
#
#           Manufacturer Location     Comments
# 94   EVER ELECTRONICS    E-05-2  Servo motor
# 125            YASKAWA   M-12-1  Servo motor
# 126            YASKAWA   D-04-3  Servo motor
# 718          PANASONIC   F-02-1  Servo motor
# 719            YASKAWA   F-02-1  Servo motor
# 720          PANASONIC   F-02-1  Servo motor
# 721          PANASONIC   F-02-1  Servo motor
# 722            YASKAWA   M-12-1  Servo motor
# 723          PANASONIC   F-02-1  Servo motor

# %%
Water_CONDUCTIVITY = df_f[df_f['Comments'] == 'Water conductivity'].sort_values(by='Comments')
Water_CONDUCTIVITY
# Out:
#                              Item description  Qty.       Part #  \
# 133  SENSOR FOR LIQUID ANALYSIS, CONDUCTIVITY   1.0  CLS21-C1N2D
#
#        Manufacturer Location            Comments
# 133  ENDRESS+HAUSER   D-05-2  Water conductivity

# %%
PUMP = df_f[df_f['Comments'] == 'Pump'].sort_values(by='Comments')
PUMP
# Out:
#                                       Item description  Qty.  \
# 155                  ROTARY LOBE PUMP,S.S, 7 BAR, 150C   1.0
# 187  PREPHERAL WHEEL PUMP, 1.5KW, 3.3A, 400V, IP54,...   1.0
# 212            PILE CARBET PA 50X50CM , 5M2, 20 PIECES   1.0
#
#                                     Part # Manufacturer Location Comments
# 155  TopWing TW1/00082 25/02-W12-GW11-EFEF          SPX   L-12-1     Pump
# 187                                5055169          GWK   L-12-1     Pump
# 212                              Alpha 823        ALPHA   L-09-2     Pump

# %%
CYLINDER = df_f[df_f['Comments'] == 'Cylinder'].sort_values(by='Comments')
CYLINDER
# Out:
#                                 Item description  Qty.             Part #  \
# 156       RODLESS PENUMATIC CYLINDER , 8 BAR MAX   1.0  ORIGA SYSTEM PLUS
# 205                           PNEUMATIC CYLINDER   1.0             909003
# 206                    PNEUM CYLINDER TBC 32x80    1.0          TBC 32x80
# 207                 PNEUM CYLINDER Parker 32x80    1.0       B32-7112B-80
# 241                       PENUMATIC CYLINDER SET   1.0             900279
# 306   MINI ISO CYLINDER, BORE =25MM, 25MM STROKE   1.0    P1A-S025MS-0025
# 307   MINI ISO CYLINDER, BORE =20MM, 80MM STROKE   4.0    P1A-S020DS-0080
# 308   MINI ISO CYLINDER, BORE =20MM, 80MM STROKE   2.0    P1A-S020DS-0100
# 309  MINI ISO CYLINDER, BORE =20MM, 300MM STROKE   1.0    P1A-S020DS-0300
# 310  MINI ISO CYLINDER, BORE =20MM, 300MM STROKE   2.0    P1A-S020DS-0160
# 531       DOUBLE ACTING CYLINDER, PISTON DIA25MM   1.0               2469
# 538     DISPLACEMENT LINEAR POSITION TRANSDUCER    1.0     JX-EP-60-70282
#
#     Manufacturer Location  Comments
# 156       PARKER   N-10-2  Cylinder
# 205      UHLMANN   A-03-1  Cylinder
# 206         E.MC   A-03-1  Cylinder
# 207       PARKER   A-03-1  Cylinder
# 241      ROGATTI   J-11-2  Cylinder
# 306       PARKER   A-03-1  Cylinder
# 307       PARKER   A-03-1  Cylinder
# 308       PARKER   A-03-1  Cylinder
# 309       PARKER   A-03-1  Cylinder
# 310       PARKER   A-03-1  Cylinder
# 531        FESTO   A-03-1  Cylinder
# 538  UNIMEASURE    M-13-4  Cylinder

# %%
electricity = df_f[df_f['Comments'] == 'Electricity'].sort_values(by='Comments')
electricity
# Out:
#                                       Item description  Qty.     Part #  \
# 160  RJ45 PANEL CONNECTOR WITH M22 THREAD FOR FRONT...   3.0     492075
# 448                             GROUP MARKER CARRIER,   10.0    249-119
# 498                    FELT PADS FOR PUNCH HEADS, 19MM   9.0    3100493
# 501                      F INSERT CRIMP, FEMALE, 40PIN   1.0  HAN 40D-F
# 505                         END AND INTERMEDIATE PLATE   8.0    280-312
# 506                         END AND INTERMEDIATE PLATE   2.0  2016-1291
# 507                         END AND INTERMEDIATE PLATE   3.0        282
# 536        DISTRIBUTION BOX IN WALL, 2-4 GANG, PLASTIC   2.0   2-4 GANG
# 537                DISTRIBUTION BOX  165*220*108 ,IP20   1.0     BR 806
#
#     Manufacturer Location     Comments
# 160        LUTZE   K-13-2  Electricity
# 448         WAGO   K-13-2  Electricity
# 498        FETTE   J-11-3  Electricity
# 501      HARTING   K-13-2  Electricity
# 505         WAGO   K-13-2  Electricity
# 506         WAGO   K-13-2  Electricity
# 507         WAGO   K-13-2  Electricity
# 536      KENWELL   E-08-3  Electricity
# 537       BORSAN   E-08-3  Electricity

# %%
BUTTON = df_f[df_f['Comments'] == 'Button'].sort_values(by='Comments')
BUTTON
# Out:
#        Item description  Qty.  Part # Manufacturer Location Comments
# 173  PUSH BUTTON, WHITE   3.0  912313      UHLMANN   K-13-2   Button

# %%
FORKLIFT_coolant = df_f[df_f['Comments'] == 'Forklift coolant'].sort_values(by='Comments')
FORKLIFT_coolant
# Out:
#                                Item description  Qty.         Part #  \
# 175  PROPYLENE GLYCOL PREMIXED coolant 5GAL 20L   1.0  013-03344-000
#
#     Manufacturer Location          Comments
# 175         YORK   K-10-1  Forklift coolant

# %%
PRE_FILTER = df_f[df_f['Comments'] == 'Pre-filter'].sort_values(by='Comments')
PRE_FILTER
# Out:
#                                       Item description  Qty.   Part #  \
# 188   PRE-FILTER PLEATED (2-LINE)WASHABLE 496X496X47MM   2.0      NaN
# 189   PRE-FILTER (Z LINE),ALUMINIUM FRAME 491*762*22MM   4.0      NaN
# 190  PRE-FILTER (CLASS G4),ALUMINIUM FRAME 491*762*...   2.0      NaN
# 705         AIR FILTER, IFI 596*287*22, G3 (PreFilter)  18.0  9026756
#
#     Manufacturer Location    Comments
# 188          FCV   C-07-2  Pre-filter
# 189  ATECO GROUP   L-12-4  Pre-filter
# 190  ATECO GROUP   L-12-4  Pre-filter
# 705     AIR FLOW   C-07-2  Pre-filter

# %%
CONTROLLER  = df_f[df_f['Comments'] == 'Controller'].sort_values(by='Comments')
CONTROLLER
# Out:
#                                       Item description  Qty.           Part #  \
# 200  POWER CONTACTOR 3Ø, 7.5KW, 2NC,2NO, CONTROL 24VDC   2.0     3RT10251BB44
# 201  POWER 2 LINE FILTER, 3A, 250VA, 2×0,47 μF (X2)...   1.0     B84114-D-B30
# 298      MOTOR CONTROLLER, DC PWM,U1=28V, U2=0 TO 24V    1.0        BV3.815K3
# 299      MOTOR CONTROLLER, DC PWM,U1=28V, U2=0 TO 24V    1.0        BV3.815K2
# 300  MOTOR CONTROLLER SINGLE DRIVE, I/P MAX 700VDC,...   1.0  LXM62DD27C21020
# 302     MOTION CONTROLLER 8AXIS , 8DISCRETE I/P, 24VDC   1.0          LMC201C
#
#         Manufacturer Location    Comments
# 200          SIEMENS   M-10-2  Controller
# 201            EPCOS   M-10-3  Controller
# 298         LUTRONIK   M-12-4  Controller
# 299         LUTRONIK   M-12-4  Controller
# 300  UHLMANN BLISTER   M-11-2  Controller
# 302        SCHNEIDER   E-02-1  Controller

# %%
FORKLIFT_Switches = df_f[df_f['Comments'] == 'Forklift switch'].sort_values(by='Comments')
FORKLIFT_Switches
# Out:
#                      Item description  Qty.      Part # Manufacturer Location  \
# 83                SWITCH FOR FORKLIFT   2.0      156281           BT   B-10-2
# 202  POTENTIOMETER,  CPL FOR FORKLIFT   1.0      231232           BT   B-10-2
# 203           POTENTIOMETER,  AUX R/L   1.0  9600-601-4        CROWN   N-10-3
# 204           POSITION SWITCH, 1NO/NC   1.0       LS-11      MOELLER   F-06-2
#
#             Comments
# 83   Forklift switch
# 202  Forklift switch
# 203  Forklift switch
# 204  Forklift switch

# %%
electricity_PIN = df_f[df_f['Comments'] == 'Electricity pin'].sort_values(by='Comments')
electricity_PIN
# Out:
#                     Item description  Qty.    Part # Manufacturer Location  \
# 210  PIN 094054 WITH STANADARD PARTS   1.0       NaN      UHLMANN   M-13-2
# 211  PIN 052397 WITH STANADARD PARTS   1.0  70000296      UHLMANN   M-13-2
#
#             Comments
# 210  Electricity pin
# 211  Electricity pin

# %%
OIL_GREASE = df_f[df_f['Comments'] == 'Oil _ grease'].sort_values(by='Comments')
OIL_GREASE
# Out:
#                                  Item description  Qty.  \
# 263                OIL MOLY ULTRA RED GREASE NO.2   1.0
# 264                           OIL FOR VACUME PUMP   1.0
# 338            LUBRICATING OIL FOR PAPER SHREDERS   1.0
# 339  LUBRICATING FLUID FOR KEMET PRODUCTS TYPE OS   1.0
# 429                     HYDRAULIC OIL H-1 ISO-150   1.0
# 430                        HYDRAULIC DOOR CLOSSER   1.0
# 452                              GREASE NLG1 NO.2   1.0
# 458              GEAR OIL  H-1 FOOD GRADE ISO 320   1.0
# 459   Gear Lubricant ISO-220 , API GL-5 MT-1 PG-2   1.0
# 460      GEAR LUB OIL ISO 460 , API GL5 MT-1 PG-2   1.0
#
#                      Part # Manufacturer Location      Comments
# 263                     229  Schaeffer's      TBC  Oil _ grease
# 264                     NaN          NaN      TBC  Oil _ grease
# 338           1.235.997.401  HSM PRESSEN   N-09-1  Oil _ grease
# 339                  301103        KEMET   N-09-1  Oil _ grease
# 429           0269150 - 005  Schaeffer's      TBC  Oil _ grease
# 430                    D720      HYUNDAE   L-11-3  Oil _ grease
# 452  229 ULTRA RED SUPEREME  Schaeffer's      TBC  Oil _ grease
# 458                     276  Schaeffer's      TBC  Oil _ grease
# 459             268 moly ss  Schaeffer's   N-09-1  Oil _ grease
# 460            286 MOLY SS   Schaeffer's   N-09-1  Oil _ grease

# %%
CABLE = df_f[df_f['Comments'] == 'Cable'].sort_values(by='Comments')
CABLE
# Out:
#                                       Item description  Qty.       Part #  \
# 290                 NETWORK CABLE RJ45/IP20 - 85445190   1.0      6053787
# 451          GROUNDING CABLE, 1.3MM, WITH MOUNTING SET   2.0  1-105-00215
# 453        GLASS FIBER OPTIC CABLE, THROUGH BEAM MODEL   2.0      SLK2226
# 600                                         DATA CABLE   1.0      9180192
# 629                     CONNECTION FOR VALVE CABLE 3MT   1.0      6600174
# 630  CONNECTING CABLE  5M.FOR SOLENOID VALVE VIA M2...   2.0      8047680
# 649              CAT6 CABLE COMMUNICATION CABLE, AWG23   1.0  7965E.K1305
# 650          CAT6 CABLE COMMUNICATION CABLE, 24AWG.75C   1.0          NK6
# 676  CABLE 20 X0,5MMQ - LAPP UNITRONIC LIYY - 84229090   1.0      6011492
#
#          Manufacturer Location Comments
# 290  PHOENIX  CONTACT   E-05-2    Cable
# 451             GLATT   M-10-3    Cable
# 453           WENGLOR   M-10-3    Cable
# 600               NaN   N-09-3    Cable
# 629               SMC   E-05-2    Cable
# 630             FESTO   E-05-4    Cable
# 649            BELDEN   M-12-4    Cable
# 650           PANDUIT   M-12-4    Cable
# 676              LAPP   E-05-2    Cable

# %%
FEEDBACK = df_f[df_f['Comments'] == 'Feedback'].sort_values(by='Comments')
FEEDBACK
# Out:
#               Item description  Qty.          Part # Manufacturer Location  \
# 297  MOTOR FEEDBACK ,7-12VDC,    1.0  SFS60-HRATZS01         SICK   J-12-3
#
#      Comments
# 297  Feedback

# %%
Water_RO= df_f[df_f['Comments'] == 'Water ro'].sort_values(by='Comments')
Water_RO
# Out:
#                  Item description  Qty.                 Part # Manufacturer  \
# 316  MEMBRANE ELEMENT FOR RO UNIT   1.0  FILMTEC BW30-4040 DRY          DOW
#
#     Location  Comments
# 316   C-06-1  Water ro

# %%
Clutch = df_f[df_f['Comments'] == 'Clutch'].sort_values(by='Comments')
Clutch
# Out:
#                           Item description  Qty.                 Part #  \
# 327  main real Clutch KEP 09P1300011724VDC   1.0   KEP 09P1300011724VDC
# 523   ELECTROMAGNETIC MOTOR BRAKE 24V, 38W   1.0              6/500.100
# 636                   COMPLETE CLUTCH UNIT   1.0                    NaN
#
#     Manufacturer Location Comments
# 327          KEP     A2-4   Clutch
# 523         MAYR   N-08-3   Clutch
# 636          NaN   N-08-1   Clutch

# %%
LOTOTO = df_f[df_f['Comments'] == 'Lototo'].sort_values(by='Comments')
LOTOTO
# Out:
#                          Item description  Qty.   Part # Manufacturer  \
# 340                          LOTOTO CARDS  10.0      NaN          NaN
# 342              LOCKOUT STATION - LOTOTO   1.0  EP-B101          NaN
# 343  LOCKOUT - TAGOUT SAFETY KIT - LOTOTO   1.0      NaN     PRINZING
# 344                 LOCK AND KEY - LOTOTO   4.0      NaN          NaN
# 449             GROUP LOCK HASPS - LOTOTO  10.0      NaN          NaN
# 450               GROUP LOCK BOX - LOTOTO   5.0      NaN          NaN
#
#     Location Comments
# 340   C-01-3   Lototo
# 342   C-01-3   Lototo
# 343   C-01-3   Lototo
# 344   C-01-3   Lototo
# 449   C-01-3   Lototo
# 450   C-01-3   Lototo

# %%
BATTERY = df_f[df_f['Comments'] == 'Battery'].sort_values(by='Comments')
BATTERY
# Out:
#                                       Item description  Qty.         Part #  \
# 168                   RECHAGEBLE  BATTERY 12V 2AH/20HR   1.0      UL 7.2-12
# 346                         LITHIUM PLC BATTERY, 1.7AH   1.0    3G2A9-BAT08
# 347                        LITHIUM BATTERY, 3V, 950MAH   1.0        CR2477N
# 691                                     BATTERY MODULE   1.0  6EP1935/6ME21
# 692  BATTERY CHARGER FOR ADFLO/JUPITER,O/P 3-9VDC, ...   1.0   003-00-58PEU
#
#     Manufacturer Location Comments
# 168  ULTRA CELL    F-01-4  Battery
# 346        OMRON   F-02-2  Battery
# 347       RENATA   K-08-4  Battery
# 691      SEIMENS   F-01-4  Battery
# 692           3M   M-11-3  Battery

# %%
Inverter = df_f[df_f['Comments'] == 'Inverter'].sort_values(by='Comments')
Inverter
# Out:
#                                       Item description  Qty.  \
# 382  Inverter, I/P 1~,3.7A,O/P 3~,2.4A,0.95KVA, 0-4...   1.0
# 383                               Inverter, 3Ø, 0.75KW   1.0
# 384                          Inverter, 0.75KW, 240V,4A   2.0
# 385  Inverter MICROMASTER 440 WITHOUT FILTER, 3Ø,  ...   1.0
# 386                               Inverter L100 Series   1.0
# 387                             Inverter  SJ100 SERIES   1.0
#
#                   Part # Manufacturer Location  Comments
# 382  LSLV0004M100-1EOFNS         Lsis   E-07-3  Inverter
# 383             195N1015      DANFOSS   E-07-3  Inverter
# 384          E82EV751K2C        LENZE   E-07-3  Inverter
# 385   6SE6440-2UD17-5AA1      SIEMENS   E-07-3  Inverter
# 386          L100-004NFE      HITACHI   E-07-3  Inverter
# 387         SJ100-004NFE      HITACHI   I-09-3  Inverter

# %%
Water_Intermediate = df_f[df_f['Comments'] == 'Water intermediate'].sort_values(by='Comments')
Water_Intermediate
# Out:
#                              Item description  Qty. Part # Manufacturer  \
# 388  Intermediate Piece 16 Bar , DIN50 , PN40   1.0   CF8M        LOCAL
#
#     Location            Comments
# 388   C-04-3  Water intermediate

# %%
HIGH_FILTER = df_f[df_f['Comments'] == 'High filter'].sort_values(by='Comments')
HIGH_FILTER
# Out:
#                                       Item description  Qty.  \
# 436  HIGH TEMPERATURE FILTER UPTO 120C, 592*592*292...   1.0
#
#                    Part # Manufacturer Location     Comments
# 436  COMATEX FP-F61592-HT        VOKES   L-13-4  High filter

# %%
HEPA_FILTER = df_f[df_f['Comments'] == 'Hepa filter'].sort_values(by='Comments')
HEPA_FILTER
# Out:
#                                 Item description  Qty.        Part #  \
# 437       HEPA FILTER, 610*1220*69, 0.3µM,0.4M/S   1.0  M575-233-008
# 438                     HEPA EXUAUST FILTER, H13   2.0      21738000
# 639  CLEAN ROOM HEPA AIR FILTER 610X610X69 0.3µm   1.0  M575-233-005
# 640      CLEAN ROOM AIR FILTER 610X1220X69 0.3µm   1.0  M575-233-008
# 641                  CLAMPING MODULE, P MAX=8BAR   1.0    AV-35-2-SA
#
#     Manufacturer Location     Comments
# 437          AAF   L-13-4  Hepa filter
# 438      NILFISK   B-10-2  Hepa filter
# 639          AFF   C-06-2  Hepa filter
# 640          AFF      TBD  Hepa filter
# 641        FESTO   N-08-3  Hepa filter

# %%
Gearbox = df_f[df_f['Comments'] == 'Gearbox'].sort_values(by='Comments')
Gearbox
# Out:
#                              Item description  Qty.      Part # Manufacturer  \
# 457                       GEARBOX , RATIO 1/7   1.0  NRVS016163          SNT
# 461                      GEAR BOX IMA GIANT 1   1.0         NaN          NaN
# 688  BEVEL GEARBOX SIZE 11O, RATIO 1/1, Ø26H7   2.0    RS00110        UNIMEC
# 689                        BEVEL GEARBOX ,GWP   1.0     GWP 14W          GWP
#
#     Location Comments
# 457   D-04-3  Gearbox
# 461   K-09-1  Gearbox
# 688   D-04-3  Gearbox
# 689   D-04-3  Gearbox

# %%
FUSE = df_f[df_f['Comments'] == 'Fuse'].sort_values(by='Comments')
FUSE
# Out:
#               Item description  Qty.    Part # Manufacturer Location Comments
# 472  FUSE 1A, 6.3X32MM, CRAMIC   5.0       T1A        OMEGA   K-13-2     Fuse
# 473     FUSE 1A, 5X20MM, GLASS   3.0  50F F1AL        OMEGA   K-13-2     Fuse

# %%
FLOWMETER_CONTROLLER = df_f[df_f['Comments'] == 'Flowmeter controller'].sort_values(by='Comments')
FLOWMETER_CONTROLLER
# Out:
#                                    Item description  Qty.     Part #  \
# 479  FLOWMETER OF BATCH CONTROLLER, 4-20MA,12-36VDC   1.0  SE35/8035
#
#     Manufacturer Location              Comments
# 479      BURKERT   A-08-2  Flowmeter controller

# %%
MONITOR_SENSOR = df_f[df_f['Comments'] == 'Flow monitor sensor'].sort_values(by='Comments')
MONITOR_SENSOR
# Out:
#                       Item description  Qty.      Part #    Manufacturer  \
# 480    FLOW MONITOR SENSOR , M18, IP67   1.0      SI1000             IFM
# 482  FLOW  ASSEMBLY FOR PH/ORP SENSORS   1.0  CPA250-A00  ENDRESS+HAUSER
#
#     Location             Comments
# 480   E-06-2  Flow monitor sensor
# 482   D-05-2  Flow monitor sensor

# %%
FLANGE_GASKET  = df_f[df_f['Comments'] == 'Flange gasket'].sort_values(by='Comments')
FLANGE_GASKET
# Out:
#                         Item description  Qty.        Part # Manufacturer  \
# 487  FLANGE GASKET , GCM I, EXHAUST SHOE   1.0  3-740-01430A          NaN
# 488   FLANGE 061 216 WITH STANDARD PARTS   1.0      70000810      UHLMANN
#
#     Location       Comments
# 487   B-03-2  Flange gasket
# 488   M-13-2  Flange gasket

# %%
Water_FILTER_CARTAGE = df_f[df_f['Comments'] == 'Water filter cartage'].sort_values(by='Comments')
Water_FILTER_CARTAGE
# Out:
#                            Item description  Qty.       Part # Manufacturer  \
# 492  FILTER CARTAGE,20'', 5µ, POLYPROPYLENE   9.0   RM2F050H21         PALL
# 493       FILTER CARTAGE, PAPER, 64X38X70MM   3.0  90950500000       BECKER
#
#     Location              Comments
# 492   C-06-2  Water filter cartage
# 493   B-10-2  Water filter cartage

# %%
FIBER_SENSOR = df_f[df_f['Comments'] == 'Fiber sensor'].sort_values(by='Comments')
FIBER_SENSOR
# Out:
#                                       Item description  Qty.      Part #  \
# 495                                  FIBER-OPT NPN/PNP   1.0  S5-5-E1-30
# 496        FIBER OPTIC AMPILIFIER,NPN, M12, NC+NO, M12   1.0     UM55PA2
# 497  FIBER OPTIC AMPILIFIER, NPN, WITH TIMER, INCLU...   1.0       FS-M1
#
#     Manufacturer Location      Comments
# 495    DATALOGIC   E-05-4  Fiber sensor
# 496      WENGLOR   E-07-3  Fiber sensor
# 497      KEYENCE   K-09-2  Fiber sensor

# %%
Enconders = df_f[df_f['Comments'] == 'Enconders'].sort_values(by='Comments')
Enconders
# Out:
#                                       Item description  Qty.  \
# 508                                ENCODER, STEPS=8192   2.0
# 509                                 ENCODER, STEPS=360   2.0
# 510                                 ENCODER, STEPS=256   1.0
# 511                              ENCODER TYPE D, RS422   2.0
# 512           ENCODER SINGLE TURN, 13BIT, FLAGE SOCKET   1.0
# 513               ENCODER ,STEPS=32768 - CEV582S-90041   1.0
# 514                                    ENCODER , LIKA    1.0
# 735  ABSOULUTE ENCODER , 360X1 STEPS, 10-32VDC - AG...   1.0
# 736               ABSOLUTE ENCODER, 24VDC, 360*1 STEPS   2.0
#
#                           Part #   Manufacturer Location   Comments
# 508                      6362018  TR ELECTRONIC   E-05-2  Enconders
# 509               ARS60-G4Z0-S02           SICK   F-06-2  Enconders
# 510            AS508/GY-6-Z/S412           LIKA   F-06-2  Enconders
# 511  DIG 58D-2500-AB-105-SC8-D78          WOLKE   F-06-2  Enconders
# 512                6FX2001-5QS12        SIEMENS   F-06-2  Enconders
# 513                      6362135  TR ELECTRONIC   E-05-2  Enconders
# 514         AS58S12/GS-10-R/S625           LIKA   E-05-2  Enconders
# 735                      1033274  SICK STEGMANN   F-06-2  Enconders
# 736                      1034599  SICK STEGMANN   F-06-2  Enconders

# %%
ELECTRONIC_Board = df_f[df_f['Comments'] == 'Electronic board'].sort_values(by='Comments')
ELECTRONIC_Board
# Out:
#                    Item description  Qty.      Part # Manufacturer Location  \
# 517  ELECTRONIC CARD KRINT V5.1 GWK   1.0     9071114          GWK   F-01-2
# 518      ELECTRONIC CARD KRANL V2.0   1.0     9070459          GWK   F-01-2
# 519      ELECTRONIC CARD KRADC V1.1   1.0     9070880          GWK   F-01-2
# 520                 ELECTRONIC CARD   1.0  CQM1-ME08K        OMRON   F-02-2
# 521       Electronic Board for VFD    1.0     9070747          GWK   A-05-2
#
#              Comments
# 517  Electronic board
# 518  Electronic board
# 519  Electronic board
# 520  Electronic board
# 521  Electronic board

# %%
ELECTRONIC_BUZZER = df_f[df_f['Comments'] == 'Electronic buzzer'].sort_values(by='Comments')
ELECTRONIC_BUZZER
# Out:
#                         Item description  Qty.    Part # Manufacturer  \
# 522  ELECTROMAGNITIC PANEL BUZZER, 24VDC   1.0  HRB-PS30          MAG
#
#     Location           Comments
# 522   K-13-2  Electronic buzzer

# %%
Electric_Gauge = df_f[df_f['Comments'] == 'Electric gauge'].sort_values(by='Comments')
Electric_Gauge
# Out:
#                                 Item description  Qty.   Part # Manufacturer  \
# 526  Electric Contact Gauge,WITH HIGH/LOW SWITCH   1.0  AISI316    BADOTHERM
# 527                      Electric Contact Gauge,   1.0  AISI316         E.ma
#
#     Location        Comments
# 526   D-06-2  Electric gauge
# 527   D-06-2  Electric gauge

# %%
SIEVE_GLATT = df_f[df_f['Comments'] == 'Sieve glatt'].sort_values(by='Comments')
SIEVE_GLATT
# Out:
#         Item description  Qty.   Part # Manufacturer Location     Comments
# 529  DOUBLE SIEVE INSERT   1.0  3450050          NaN   B-10-3  Sieve glatt

# %%
DOOR  = df_f[df_f['Comments'] == 'Door'].sort_values(by='Comments')
DOOR
# Out:
#                        Item description  Qty.    Part # Manufacturer Location  \
# 532               DOOR LOCK WITHOUT KEY   2.0     72X60       AMIRCO   L-11-3
# 533                  DOOR LEVER HANDLE    2.0   DDTH002       WELDER   D-04-2
# 534       DOOR CLOSER SLIDE ARM&CHANNEL   3.0  64010001        DORMA   D-04-2
# 535              DOOR CLOSER CAM ACTION   5.0  42020101        DORMA   D-04-2
# 611  CONVENTIONAL DOOR CLOSER, MAX 60KG   1.0     60150         CISA   D-04-2
#
#     Comments
# 532     Door
# 533     Door
# 534     Door
# 535     Door
# 611     Door

# %%
DIGITA_PRECISION = df_f[df_f['Comments'] == 'Digital precision'].sort_values(by='Comments')
DIGITA_PRECISION
# Out:
#                    Item description  Qty.  Part # Manufacturer Location  \
# 542  DIGITAL PRECISION SETTING KNOB   1.0  912690      UHLMANN   K-13-2
#
#               Comments
# 542  Digital precision

# %%
Differential_Pressure_Gauge = df_f[df_f['Comments'] == 'Differential pressure gauge'].sort_values(by='Comments')
Differential_Pressure_Gauge
# Out:
#                                       Item description  Qty.           Part #  \
# 545  Differential Pressure Gauge for Filter, Max 16...   2.0            PD120
# 553         DEFFERENTIAL PRESSURE RANGE -3000TO3000 PA   1.0  Delta bar PMD75
#
#        Manufacturer Location                     Comments
# 545     ATLAS COPCO   D-06-2  Differential pressure gauge
# 553  ENDRESS+HAUSER   A-08-2  Differential pressure gauge

# %%
DIAPHRAGM = df_f[df_f['Comments'] == 'Diaphragm'].sort_values(by='Comments')
DIAPHRAGM
# Out:
#                      Item description  Qty.             Part #  \
# 546             DIAPHRAGM, DN50, EPDM   3.0          DD20-ITFM
# 547             DIAPHRAGM, DN25, EPDM   1.0          DD10-ITFM
# 548             DIAPHRAGM, DN20, EPDM   1.0          DD07-ITFM
# 549             DIAPHRAGM, DN15, EPDM   1.0          DD05-ITFM
# 632  CONCAVE DIAPHRAGM, DN32-40, EPDM   1.0  Diaphragm code 13
# 633  CONCAVE DIAPHRAGM, DN15-25, EPDM   2.0  Diaphragm code 13
# 634     CONCAVE DIAPHRAGM, DN12, EPDM   1.0  Diaphragm code 13
#
#          Manufacturer Location   Comments
# 546  DIAPHRAGM DIRECT   L-13-3  Diaphragm
# 547  DIAPHRAGM DIRECT   L-13-3  Diaphragm
# 548  DIAPHRAGM DIRECT   L-13-3  Diaphragm
# 549  DIAPHRAGM DIRECT   L-13-3  Diaphragm
# 632              GEMU   L-13-3  Diaphragm
# 633              GEMU   L-13-3  Diaphragm
# 634              GEMU   L-13-3  Diaphragm

# %%
value_transformer  = df_f[df_f['Comments'] == 'Value transformer'].sort_values(by='Comments')
value_transformer
# Out:
#                            Item description  Qty.  Part #   Manufacturer  \
# 601  Current value transformer KFD2-CD-1.32   1.0  104218  PEPPERL+FUCHS
#
#     Location           Comments
# 601   E-05-3  Value transformer

# %%
FORKLIFT_CONTROL   = df_f[df_f['Comments'] == 'Forklift control'].sort_values(by='Comments')
FORKLIFT_CONTROL
# Out:
#                                   Item description  Qty.  Part # Manufacturer  \
# 620  CONTACTOR , FOR FORKLIFT, 24V, WITH TERMINALS   2.0  135654           BT
#
#     Location          Comments
# 620   N-09-3  Forklift control

# %%
FORKLIFT_CARBON = df_f[df_f['Comments'] == 'Forklift carbon'].sort_values(by='Comments')
FORKLIFT_CARBON
# Out:
#               Item description  Qty.   Part # Manufacturer Location  \
# 653  CARBON BRUSH SET 10X25X20   4.0  7509136           BT   B-10-2
# 654  CARBON BRUSH FOR FORKLIFT   1.0   161611           BT   B-10-2
#
#             Comments
# 653  Forklift carbon
# 654  Forklift carbon

# %%
CONDUCTIVITY_TRANSMITTER = df_f[df_f['Comments'] == 'Conductivity transmitter'].sort_values(by='Comments')
CONDUCTIVITY_TRANSMITTER
# Out:
#                                Item description  Qty.  Part #    Manufacturer  \
# 631  CONDUCTIVITY TRANSMITTER/Liquisys M +PT100   1.0  CLM223  ENDRESS+HAUSER
#
#     Location                  Comments
# 631   A-03-3  Conductivity transmitter

# %%
CHAIN_L1 = df_f[df_f['Comments'] == 'Chain'].sort_values(by='Comments')
CHAIN_L1
# Out:
#                           Item description  Qty.         Part # Manufacturer  \
# 651  CARTON METAL FINGERS OF CARTON CHAIN    1.0  SET OF CHAIN      UHLMANN
#
#     Location Comments
# 651   A-02-3    Chain

# %%
regulator = df_f[df_f['Comments'] == 'Regulator'].sort_values(by='Comments')
regulator
# Out:
#                     Item description  Qty.     Part # Manufacturer Location  \
# 657  Camozzi Filter regulator 16 Bar   2.0  MC202-D10      Camozzi      NaN
#
#       Comments
# 657  Regulator

# %%
BEARING_YOKE = df_f[df_f['Comments'] == 'Bearing  yoke'].sort_values(by='Comments')
BEARING_YOKE
# Out:
# Empty DataFrame
# Columns: [Item description, Qty., Part #, Manufacturer, Location, Comments]
# Index: []

# %%
CAM = df_f[df_f['Comments'] == 'Cam'].sort_values(by='Comments')
CAM
# Out:
#                                       Item description  Qty.         Part #  \
# 662  CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIA...   4.0       KR16-NMT
# 663  CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIA...  10.0      KR16-PP-A
# 664  CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIA...   1.0          KR 30
# 665  CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIA...   2.0      KR30-PP-A
# 666  CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIA...   1.0        KR30-PP
# 667  CAM FOLLOWER,YOKE TYPE TRACK ROLLERS WITH AXIA...   3.0          KR 22
# 668                            CAM FOLLOWER, 8X19X11MM   5.0  KR19-PP-A-NMT
# 669                            CAM FOLLOWER, 8X19X11MM   6.0            CF8
# 670                            CAM FOLLOWER, 6X16X28MM   5.0            CF6
# 671                        CAM FOLLOWER, 6.35X15.875MM   4.0           CR10
# 672                         CAM FOLLOWER, 22X10X36.2MM   6.0          KR 22
# 673                         CAM FOLLOWER, 22X10X36.2MM   2.0        KR22 PP
# 674                        CAM FOLLOWER, 12X30XM12X1.5   2.0           CF12
# 675                     CAM FOLLOWER, 12X26XM10X1.25MM   1.0           CF10
#
#     Manufacturer Location Comments
# 662          INA   M-12-2      Cam
# 663          INA   M-12-2      Cam
# 664          SKF   M-12-2      Cam
# 665          INA   M-12-2      Cam
# 666          INA   M-12-2      Cam
# 667          SKF   M-12-2      Cam
# 668          INA   M-12-2      Cam
# 669          HFB   M-12-2      Cam
# 670          IKO   M-12-2      Cam
# 671          IKO   M-12-2      Cam
# 672          SKF   M-12-2      Cam
# 673          INA   M-13-2      Cam
# 674          HFB   M-13-2      Cam
# 675          JNS   M-12-2      Cam

# %%
power_strip  = df_f[df_f['Comments'] == 'Power strip'].sort_values(by='Comments')
power_strip
# Out:
#                                 Item description  Qty.  Part # Manufacturer  \
# 677  CABINET SCHUKO SOCKET ON OMEGA BAR 16A,250V   1.0  680572       LUETZE
#
#     Location     Comments
# 677       te  Power strip

# %%
VALVE_AHU = df_f[df_f['Comments'] == 'Valve ahu'].sort_values(by='Comments')
VALVE_AHU
# Out:
#                          Item description  Qty.      Part # Manufacturer  \
# 678  BUTTERFLY VALVE , DN 25 PS 12, 0-90C   1.0  VSM0073049          SVS
# 679    BUTTERFLY VALVE , DN ,PS 12, 0-90C   1.0  VSM0073052          SVS
#
#     Location   Comments
# 678   D-05-2  Valve ahu
# 679   D-05-2  Valve ahu

# %%
FORKLIFT_BREAK = df_f[df_f['Comments'] == 'Forklift break'].sort_values(by='Comments')
FORKLIFT_BREAK
# Out:
#             Item description  Qty.  Part # Manufacturer Location  \
# 683  BREAK SHOE FOR FORKLIFT   1.0  174967           BT   B-10-2
#
#            Comments
# 683  Forklift break

# %%
COUPLIN = df_f[df_f['Comments'] == 'Couplin'].sort_values(by='Comments')
COUPLIN
# Out:
#                               Item description  Qty.        Part #  \
# 684                              BOEX COUPLING   1.0       3700955
# 742  1060T10 COVER-GRID ASSY (SPRING COUPLING)   1.0  23012060-GRD
#
#     Manufacturer Location Comments
# 684        FETTE   J-11-3  Couplin
# 742         FALK   A-02-4  Couplin

# %%
PACKFilter = df_f[df_f['Comments'] == 'Packfilter'].sort_values(by='Comments')
PACKFilter
# Out:
#                                Item description  Qty.  \
# 708  AIR FILTER , 600X600X125 -Ø250 (PACK OF 3)   2.0
# 709  AIR FILTER , 600X600X125 -Ø250 (PACK OF 3)   2.0
# 710                                  AIR FILTER   2.0
#
#                              Part # Manufacturer Location    Comments
# 708  HTH-H14-AL-600X600X125-FC2/1PM      ULPATEK    K12-3  Packfilter
# 709  HTH-H14-AL-600X600X125-FC2/1PM      ULPATEK    K12-2  Packfilter
# 710                             NaN          NaN   B-10-2  Packfilter

# %%
pump_FILTER = df_f[df_f['Comments'] == 'Pump filter'].sort_values(by='Comments')
pump_FILTER
# Out:
#                Item description  Qty.     Part # Manufacturer Location  \
# 711  AIR FILTER for Vaccum pump   2.0  102094-ET          NaN   B-10-2
#
#         Comments
# 711  Pump filter

# %%
EMFLON_FILTER  = df_f[df_f['Comments'] == 'Emflon filter'].sort_values(by='Comments')
EMFLON_FILTER
# Out:
#                             Item description  Qty.          Part #  \
# 712  AILR FILTER ,EMFLON FILTER 0.2µm, 87mmL   0.0   AVF021V002PVJ
# 713    AILR FILTER ,EMFLON FILTER 0.2µm, 20"   0.0     AB2PFR7PVH4
# 714        AILR FILTER ,EMFLON FILTER 0.2µm    1.0         C3PFRP1
# 715         AILR FILTER ,EMFLON FILTER 0.2µm   0.0  AVF021V002PVH4
#
#     Manufacturer Location       Comments
# 712         PALL   K-13-3  Emflon filter
# 713         PALL   K-13-3  Emflon filter
# 714         PALL    K13-3  Emflon filter
# 715         PALL    K13-3  Emflon filter

# %%
SELECTOR = df_f[df_f['Comments'] == 'Selector'].sort_values(by='Comments')
SELECTOR
# Out:
#         Item description  Qty.      Part # Manufacturer Location  Comments
# 737  3 POSITION SELECTOR   2.0         NaN     SCHLEGEL   K-13-2  Selector
# 738  3 POSITION SELECTOR   1.0  6152520900          IMA   M-10-3  Selector

# %%
CONTACTOR = df_f[df_f['Comments'] == 'Contactor'].sort_values(by='Comments')
CONTACTOR
# Out:
#                                     Item description  Qty.           Part #  \
# 614                 CONTACTOR, 3Ø, 90KW, 400V,2C+2N0   1.0     DILM185-S/22
# 644                        Circuit-breaker, 3p, 200A   1.0       NZMB2-A200
# 628                              CONNECTOR >PC-GF20<   1.0       7202001-01
# 627                              CONNECTOR, 230-363A   1.0           909948
# 626                          CONTACT BLOCK REED, 1NO   1.0          P9B10FH
# 625                        CONTACT BLOCK, 250V, 1.5W   2.0              AL5
# 624                 CONTACT BLOCK, 250VAC, 6A, 8 PIN   1.0              AT2
# 645                        Circuit-breaker, 3p, 160A   1.0       NZMB2-A160
# 623            CONTACTOR , 230VAC, 3Ø, 30KW, 1NO+1NC   1.0       CL07A311MN
# 621                      CONTACTOR , 4KW, 400VAC, 9A   1.0         XTMC9A10
# 619  CONTACTOR COMBINATION FOR SAFETY CIRCUITS,24VDC   3.0     3TK2804-0BB4
# 618              CONTACTOR, 24VAC, 3Ø, 4KW, 400V,1NC   1.0    3RT2016-1AB02
# 617            CONTACTOR, 24VAC, 3Ø, 7.5KW, 400V,1NC   1.0    3RT1025-1AC20
# 616                  CONTACTOR, 24VDC, 3Ø,  4KW, 1NO   1.0    3RT1016-1BB41
# 615                     CONTACTOR, 3Ø, 75KW, 400V,AC   2.0  DILM150(RAC240)
# 622              CONTACTOR , 400VAC, 3Ø, 7.5KW, 1NO    1.0       CL02A310TU
# 646                         Circuit-breaker, 3p, 160   1.0      NZMN2-A160
#
#          Manufacturer Location   Comments
# 614           MOELLER   F-04-4  Contactor
# 644           MOELLER   F-04-4  Contactor
# 628           SIEMENS   E-05-4  Contactor
# 627           UHLMANN   A-03-1  Contactor
# 626  GENERAL ELECTRIC   N-10-3  Contactor
# 625          SCHLEGEL   M-10-3  Contactor
# 624          SCHLEGEL   M-10-3  Contactor
# 645           MOELLER   F-04-4  Contactor
# 623  GENERAL ELECTRIC   M-10-2  Contactor
# 621             EATON   M-10-2  Contactor
# 619           SIEMENS   E-08-3  Contactor
# 618           SIEMENS   M-10-2  Contactor
# 617           SIEMENS   M-10-2  Contactor
# 616           SIEMENS   M-10-2  Contactor
# 615           MOELLER   F-04-4  Contactor
# 622  GENERAL ELECTRIC   M-10-2  Contactor
# 646           MOELLER   F-04-4  Contactor

# %%
# %%writefile Engineering.py
import streamlit as st
import pandas as pd
import numpy as np

st.set_page_config(
    layout="wide",
    page_title='Earthquake analysis',
    page_icon='🪙'
)


df_f = pd.read_csv('Eng Spare parts.csv')









page =  st.sidebar.radio('Select page', ['About','Utility area','Mechanical parts', 'Electrical parts',
                    'Pneumatic parts','GLATT','FETTE','FORKLIFT','LOTOTO'])


if page == '+':
    
    def main():
        st.subheader('Select from these items')
        
    if __name__ == '__main__':

        main()

if page == 'Mechanical parts':
    def main():
        st.markdown("""
    <style>
        /* Add your custom CSS styles here */
        .stProgress > div > div > div {
            background-color: #FFD700; /* Change the color of the loading spinner */
            border-radius: 50%; /* Make the loading spinner circular */
        }
    </style>
""", unsafe_allow_html=True)

# Display a placeholder while loading data
        with st.spinner("Data loaded successfully!"):
            # Simulate loading data
            import time
            time.sleep(2)

        # Once data is loaded, display a message
        st.markdown("""
    <h2 style='text-align: center; font-size: 40px; color: red;'>
        Find your Mechanical parts
    </h2>
""", unsafe_allow_html=True)
        st.subheader('Select from these items')

        tab1, tab2 ,tab3, tab4,tab5, tab6 ,tab7, tab8 ,tab10, tab11 ,tab12, tab13, tab14  = st.tabs(['Bearing', 'Belts','Shaft','Spring',
        'leaflet rooler','Cam','Clutch','Oil _ grease','Chain','Gearbox','Door','Couplin','Wheel CASTOR'])


        with tab1:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                peraing = df_f[df_f['Comments'] == 'Bearing'].sort_values(by='Comments')
                st.dataframe(peraing,width=2000)
            with col3:
                st.subheader('image  for  these  part')

                SKF,ASAHI,INA,KBC,IKO,NTN,NB = st.tabs(['SKF','ASAHI','INA','IKO','KBC','NB','NTN'])

                with SKF:
                    image1 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/1.jpeg', 'rb').read()
                    st.image(image1, width=150)
                    url = 'https://www.skf.com/id/productinfo/productid-6001-2Z%2FC3'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with ASAHI:
                    image2 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/2.jpg', 'rb').read()
                    st.image(image2, caption='FETTE', width=150)
                    url = 'https://th.misumi-ec.com/en/vona2/detail/221000612127/?HissuCode=JAF10'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with INA:
                    image3 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/3.jpg', 'rb').read()
                    st.image(image3, caption='FETTE', width=150)
                    url = 'https://www.abf.store/s/en/bearings/STO12-INA/450653'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with IKO:
                    image4 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/4.jpg', 'rb').read()
                    st.image(image4, caption='FETTE', width=150)
                    url = 'https://www.acorn-ind.co.uk/p/iko/closed-type-linear-ball-bearings/lme122232n-iko/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with KBC:
                    image5 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/5.jpg', 'rb').read()
                    st.image(image5, caption='FETTE', width=150)
                    url = 'https://trimantec.com/products/kbc-bearings-radial-bearing-6004-d-6004-rs'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with NTN:
                    image6 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/6.png', 'rb').read()
                    st.image(image6, caption='FETTE', width=150)
                    url = 'https://www.2rs.bg/en-gb/6004-llu-5k-ntn.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with NB:
                    image7 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/7.jpg', 'rb').read()
                    st.image(image7, caption='FETTE', width=150)
                    url = 'https://www.abf.store/s/en/bearings/6212-2NSE-NACHI/381266'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')


        with tab2:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                Belts = df_f[df_f['Comments'] == 'Belts'].sort_values(by='Comments')
                st.dataframe(Belts,width=2000)
            with col3:
                st.subheader('image  for  these  part')
                OPTIBELT ,FEC, timing_belt = st.tabs(['OPTIBELT','FEC','timing belt'])

                with OPTIBELT:
                    image8 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/8.jpg', 'rb').read()
                    st.image(image8, width=150)
                    url = 'https://www.optibelt.com/en/home/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')


                with FEC:
                    image9 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/9.jpg', 'rb').read()
                    st.image(image9, width=150)
                    url = 'https://www.fecconsulting.dk/en/timing-belts/megaflex-timing-belts/pu-timing-belts-t10-flex/t10-2550.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with timing_belt:
                    image10 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/10.jpg', 'rb').read()
                    st.image(image10, width=150)
                    url = 'https://www.konlidainc.com/gear/timing-belt.asp'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            

        with tab3:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                Shaft = df_f[df_f['Comments'] == 'Shaft'].sort_values(by='Comments')
                st.dataframe(Shaft)
            with col3:
                st.subheader('image  for  these  part')
                GRUNDFOS, uhlmann  = st.tabs(['GRUNDFOS','uhlmann'])

                with GRUNDFOS:
                    image11 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/11.jpeg', 'rb').read()
                    st.image(image11, width=150)
                    url = 'https://product-selection.grundfos.com/eg/products/service-partkit/spare-shaft-seal-96488302?pumpsystemid=2346046284&tab=variant-specifications'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')


                with uhlmann:
                    image12 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/12.jpg', 'rb').read()
                    st.image(image12, width=150)
                    url = 'https://www.uhlmann.de/services/support-services/spare-parts/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            

        with tab4:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                Spring = df_f[df_f['Comments'] == 'Spring'].sort_values(by='Comments')
                st.dataframe(Spring)
            with col3:
                st.subheader('image  for  these  part')

                TENSION,PRESSURE  = st.tabs(['TENSION','PRESSURE'])
                with TENSION:
                    image13 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/13.jpg', 'rb').read()
                    st.image(image13, width=150)
                    url = 'https://www.sawane-spring.com/product/use/tension_spring_extension_spring.php'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')


                with PRESSURE:
                    image14 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/14.jpg', 'rb').read()
                    st.image(image14, width=150)
                    url = 'https://metal-spring.com/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')


        with tab5:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                leaflet_rooler = df_f[df_f['Comments'] == 'Leaflet rooler'].sort_values(by='Comments')
                st.dataframe(leaflet_rooler)
            with col3:
                st.subheader('image  for  these  part')

                Alumnum,rubber  = st.tabs(['Alumnum','rubber'])
                with Alumnum:
                    image15 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/15.jpg', 'rb').read()
                    st.image(image15, width=150)
                    url = 'https://www.jctprinting.com/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with rubber:
                    image16 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/16.jpeg', 'rb').read()
                    st.image(image16, width=150)
                    url = 'https://www.jctprinting.com/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            

        with tab6:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Cam = df_f[df_f['Comments'] == 'Cam'].sort_values(by='Comments')
                st.dataframe(Cam)
            with col3:
                st.subheader('image  for  these  part')

                Cam_SKF,Cam_INA,Cam_IKO  = st.tabs(['Cam_SKF','Cam_INA','Cam_IKO'])
                with Cam_SKF:
                    image17 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/17.jpg', 'rb').read()
                    st.image(image17, width=150)
                    url = 'https://www.skf.com/sg/products/rolling-bearings/track-rollers/cam-followers/productid-KR%2022'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with Cam_INA:
                    image18 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/18.jpg', 'rb').read()
                    st.image(image18, width=150)
                    url = 'https://www.abf.store/s/en/bearings/KR19-PP-A-NMT-INA/501413'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with Cam_IKO:
                    image19 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/19.jpg', 'rb').read()
                    st.image(image19, width=150)
                    url = 'https://www.acorn-ind.co.uk/p/iko/cam-followers/cr10-iko/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            

        with tab7:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Clutch = df_f[df_f['Comments'] == 'Clutch'].sort_values(by='Comments')
                st.dataframe(Clutch)
            with col3:
                st.subheader('image  for  these  part')

                Mechanical,Electrical   = st.tabs(['Mechanical','Electrical '])
                with Mechanical:
                    image20 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/20.jpg', 'rb').read()
                    st.image(image20, width=150)
                    url = 'https://www.psbearings.com/html_products/mzeu-series-cam-type-cam-clutch-346.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with Electrical :
                    image21 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/21.jpeg', 'rb').read()
                    st.image(image21, width=150)
                    url = 'https://peacosupport.com/electromagnetic-brake-6nm-400nm'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            

        with tab8:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Oil_grease = df_f[df_f['Comments'] == 'Oil _ grease'].sort_values(by='Comments')
                st.dataframe(Oil_grease)
            with col3:
                st.subheader('image  for  these  part')

                HYDRAULIC,Gear   = st.tabs(['HYDRAULIC','Gear '])
                with HYDRAULIC:
                    image22 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/22.jpg', 'rb').read()
                    st.image(image22, width=150)
                    url = 'https://www.schaefferoil.com/h1-hydraulic-oil.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with Gear :
                    image23 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/23.jpg', 'rb').read()
                    st.image(image23, width=150)
                    url = 'https://stores.buy1oils.com/new-schaeffer-products/schaeffer-2009-supreme-open-gear-lube-37-lbs/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            

        with tab10:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Chain = df_f[df_f['Comments'] == 'Chain'].sort_values(by='Comments')
                st.dataframe(Chain)
            with col3:
                st.subheader('image  for  these  part')
                image24 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/24.jpg', 'rb').read()
                st.image(image24, width=150)
                url = 'https://www.uhlmann.de/services/support-services/spare-parts/'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

            
            
        with tab11:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Gearbox = df_f[df_f['Comments'] == 'Gearbox'].sort_values(by='Comments')
                st.dataframe(Gearbox)
            with col3:
                st.subheader('image  for  these  part')

                BEVEL,Nema   = st.tabs(['BEVEL','Nema '])
                with BEVEL:
                    image25 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/25.jpg', 'rb').read()
                    st.image(image25, width=150)
                    url = 'https://www.unimec.eu/en/products/bevel-gearboxes/110/RR.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with Nema :
                    image26 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/26.jpg', 'rb').read()
                    st.image(image26, width=150)
                    url = 'https://www.phidgets.com/?prodid=1082'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            

        with tab12:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Door = df_f[df_f['Comments'] == 'Door'].sort_values(by='Comments')
                st.dataframe(Door)
            with col3:
                st.subheader('image  for  these  part')

                Dorma,Cam_Hydraulic,Handl  = st.tabs(['Dorma','Cam_Hydraulic','Handl'])
                with Dorma:
                    image27 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/27.jpg', 'rb').read()
                    st.image(image27, width=150)
                    url = 'https://doorcontrolsdirect.co.uk/door-closer-spare-parts/1043-dorma-g-n-slide-arm-channel'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with Cam_Hydraulic:
                    image28 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/28.jpg', 'rb').read()
                    st.image(image28, width=150)
                    url = 'https://www.dnd.com.tw/en/category/Door-Closer.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with Handl:
                    image29 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/29.jpg', 'rb').read()
                    st.image(image29, width=150)
                    url = 'https://www.handleking.co.uk/heavy-duty-door-handles-with-return-to-door-lever-grade-3'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
            
        with tab13:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Couplin = df_f[df_f['Comments'] == 'Couplin'].sort_values(by='Comments')
                st.dataframe(Couplin)
            with col3:
                st.subheader('image  for  these  part')

                Flexible_Couplin, BoWex_Couplin   = st.tabs(['Flexible_Couplin','BoWex_Couplin '])
                with Flexible_Couplin:
                    image30 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/30.jpeg', 'rb').read()
                    st.image(image30, width=150)
                    url = 'https://www.ttco.com/encoders/ae087-10-10.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with BoWex_Couplin :
                    image31 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/31.jpg', 'rb').read()
                    st.image(image31, width=150)
                    url = 'https://www.ktr.com/no/products/bowex-curved-tooth-gear-couplings/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            

        with tab14:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Wheel_CASTOR = df_f[df_f['Comments'] == 'Swivel castor'].sort_values(by='Comments')
                st.dataframe(Wheel_CASTOR)
            with col3:
                st.subheader('image  for  these  part')
                image32 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/32.jpg', 'rb').read()
                st.image(image32, width=150)
                url = 'https://www.shoplinco.com/colson-polyurethane-heavy-duty-total-lock-swivel-caster-8-x-2-1000-lbs-cap/'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            

    if __name__ == '__main__':

        main()

if page == 'Electrical parts': 
    def main():
        st.markdown("""
    <style>
        /* Add your custom CSS styles here */
        .stProgress > div > div > div {
            background-color: #FFD700; /* Change the color of the loading spinner */
            border-radius: 50%; /* Make the loading spinner circular */
        }
    </style>
""", unsafe_allow_html=True)

# Display a placeholder while loading data
        with st.spinner("Data loaded successfully!"):
            # Simulate loading data
            import time
            time.sleep(2)

            st.markdown("""
    <h2 style='text-align: center; font-size: 40px; color: red;'>
        Find your Electrical parts
    </h2>
""", unsafe_allow_html=True)
        st.subheader('Select from these items')
        
        tab1, tab2 ,tab3, tab4,tab5, tab6 ,tab7, tab8, tab9 ,tab10, tab11 ,tab12  = st.tabs(['Proximity','Sensor','Fiber sensor','Amplifier','Socket',
        'Selector','Button','Switch','Light','Fan','Cable','Fuse'])

        with tab1:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Proximity = df_f[df_f['Comments'] == 'Proximity'].sort_values(by='Comments')
                st.dataframe(Proximity)
            with col3:
                st.subheader('image  for  these  part')

                BALLUFF,MICRO_DETECTORS,IFM  = st.tabs(['BALLUFF','MICRO_DETECTORS','IFM'])
                with BALLUFF:
                    image57 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/57.PNG', 'rb').read()
                    st.image(image57, width=150)
                    url = 'https://valinonline.com/products/dw-as-503-m30-002'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with MICRO_DETECTORS:
                    image58= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/58.PNG', 'rb').read()
                    st.image(image58, width=150)
                    url = 'https://www.electricautomationnetwork.com/en/micro-detectors/am1-an-1a-micro-detectors-inductive-sensor-m12-shielded-no-npn-cable-2m-axial'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with IFM:
                    image59 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/59.PNG', 'rb').read()
                    st.image(image59, width=150)
                    url = 'https://www.ifm.com/in/en/product/IF5345'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab2:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Sensor = df_f[df_f['Comments'] == 'Sensor'].sort_values(by='Comments')
                st.dataframe(Sensor)
            with col3:
                st.subheader('image  for  these  part')

                SICK,BAUMER,DATALOGIC  = st.tabs(['SICK','BAUMER','DATALOGIC'])
                with SICK:
                    image60 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/60.PNG', 'rb').read()
                    st.image(image60, width=150)
                    url = 'https://www.sick.com/be/en/catalog/products/detection-sensors/color-sensors/cs8/cs81-p1112/p/p138054'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with BAUMER:
                    image61= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/61.PNG', 'rb').read()
                    st.image(image61, width=150)
                    url = 'https://www.kempstoncontrols.com/FPDK-10N5101-S35A/Baumer/sku/136377'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with DATALOGIC:
                    image62 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/62.PNG', 'rb').read()
                    st.image(image62, width=150)
                    url = 'https://www.electricautomationnetwork.com/en/datalogic/s41-photoelectric-sensors-datalogic-s41-2-c-p-950701010'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab3:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Fiber_sensor = df_f[df_f['Comments'] == 'Fiber sensor'].sort_values(by='Comments')
                st.dataframe(Fiber_sensor)
            with col3:
                st.subheader('image  for  these  part')
                image63 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/63.PNG', 'rb').read()
                st.image(image63, width=150)
                url = 'https://www.wenglor.com/en/Sensors/Photoelectronic-Sensors/Fiber-Optic-Sensors/Fiber-Optic-Cable-Amplifiers/Fiber-optic-amplifier/p/UM55PA2'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
        
        with tab4:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Amplifier = df_f[df_f['Comments'] == 'Amplifier'].sort_values(by='Comments')
                st.dataframe(Amplifier)
            with col3:
                st.subheader('image  for  these  part')
                image64 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/64.PNG', 'rb').read()
                st.image(image64, width=150)
                url = 'https://www.pepperl-fuchs.com/global/en/classid_6.htm?view=productdetails&prodid=95425'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab5:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Socket = df_f[df_f['Comments'] == 'Socket'].sort_values(by='Comments')
                st.dataframe(Socket)
            with col3:
                st.subheader('image  for  these  part')
                image65 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/65.PNG', 'rb').read()
                st.image(image65, width=150)
                url = 'https://ie.farnell.com/hirschmann/ca6ld/cir-connector-receptacle-6pos/dp/3611905'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab6:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Selector = df_f[df_f['Comments'] == 'Selector'].sort_values(by='Comments')
                st.dataframe(Selector)
            with col3:
                st.subheader('image  for  these  part')
                image66 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/66.PNG', 'rb').read()
                st.image(image66, width=150)
                url = 'https://www.se.com/eg/en/product/XA2ED33/selector-switch-%C3%B822-standard-handle-3-positions-2no/'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab7:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Button = df_f[df_f['Comments'] == 'Button'].sort_values(by='Comments')
                st.dataframe(Button)
            with col3:
                st.subheader('image  for  these  part')
                image67= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/67.PNG', 'rb').read()
                st.image(image67, width=150)
                url = 'https://za.rs-online.com/web/p/push-button-heads/3308975/'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab8:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Switch = df_f[df_f['Comments'] == 'Switch'].sort_values(by='Comments')
                st.dataframe(Switch)
            with col3:
                st.subheader('image  for  these  part')

                SICK,MOUJEN,SCHNEIDER  = st.tabs(['SICK','MOUJEN','SCHNEIDER'])
                with SICK:
                    image68 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/68.PNG', 'rb').read()
                    st.image(image68, width=150)
                    url = 'https://www.sick.com/us/en/catalog/products/safety/safety-switches/re1/re11-sa03/p/p315664'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with MOUJEN:
                    image69= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/69.PNG', 'rb').read()
                    st.image(image69, width=150)
                    url = 'https://www.moujenswitch.com/product/me-8108-m/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with SCHNEIDER:
                    image70 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/70.PNG', 'rb').read()
                    st.image(image70, width=150)
                    url = 'https://www.se.com/th/en/all-products'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab9:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Light = df_f[df_f['Comments'] == 'Light'].sort_values(by='Comments')
                st.dataframe(Light)
            with col3:
                st.subheader('image  for  these  part')

                Filux,LED_OUTLET  = st.tabs(['Filux','LED OUTLET'])
                with Filux:
                    image71 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/71.PNG', 'rb').read()
                    st.image(image71, width=150)
                    url = 'https://filux.com/en/t8-pro-led-tubes/-t8-led-tube-9w-60cm-cct-3000k-4000k-6500k-130lm-w-5-years-warranty-6350.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with LED_OUTLET:
                    image72= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/72.PNG', 'rb').read()
                    st.image(image72, width=150)
                    url = 'https://www.ledoutletpr.com/products/flood-lamp-200w'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab10:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Fan = df_f[df_f['Comments'] == 'Fan'].sort_values(by='Comments')
                st.dataframe(Fan)
            with col3:
                st.subheader('image  for  these  part')
                image73= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/73.PNG', 'rb').read()
                st.image(image73, width=150)
                url = 'https://au.element14.com/multicomp/sf23080a-2083hsl-gn/fan-80mm-230vac-23cfm-31dba/dp/9606238'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab11:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Cable = df_f[df_f['Comments'] == 'Cable'].sort_values(by='Comments')
                st.dataframe(Cable)
            with col3:
                st.subheader('image  for  these  part')

                CONNECTION,CAT6_CABLE,FIBER_OPTIC  = st.tabs(['SICK','CAT6 CABLE','FIBER OPTIC'])
                with CONNECTION:
                    image74 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/74.PNG', 'rb').read()
                    st.image(image74, width=150)
                    url = 'https://asi.net.nz/category/Sensor-Leads-Connectors-Valve-Cables'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with CAT6_CABLE:
                    image75= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/75.PNG', 'rb').read()
                    st.image(image75, width=150)
                    url = 'https://de.assmann.shop/en/Copper-Network-Technology/Network-Cables/Installation-Cables/ASSNET250-Cat-6-U-UTP-installation-cable-305-m-Eca.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with FIBER_OPTIC:
                    image76 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/76.PNG', 'rb').read()
                    st.image(image76, width=150)
                    url = 'https://www.wenglor.com/pt/Sensors/Sensores-optoelectronicos/Fiber-Optic-Sensors/Glass-Fiber-Optic-Cables/Glass-Fiber-Optic-Cable-Through-Beam-Mode/p/SLK2313'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
            
        with tab12:
            col1, col2, col3 = st.columns([30,3,13])
            with col1:
                
                Fuse = df_f[df_f['Comments'] == 'Fuse'].sort_values(by='Comments')
                st.dataframe(Fuse)
            with col3:
                st.subheader('image  for  these  part')

                GLASS,CRAMIC  = st.tabs(['GLASS','CRAMIC'])
                with GLASS:
                    image77 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/77.PNG', 'rb').read()
                    st.image(image77, width=150)
                    url = 'https://makerselectronics.com/product/fuse-1a-250v-t5x20mm'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                with CRAMIC:
                    image78= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/78.PNG', 'rb').read()
                    st.image(image78, width=150)
                    url = 'https://witonics.com/products/siba-ceramic-fuse-6-3x32mm-time-delay-t200ma-7006565-0-200'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
           

        st.header('Select from these items')

        tab13, tab14 ,tab15, tab16,tab17, tab18 ,tab19, tab20, tab21 ,tab22, tab23 ,tab24  = st.tabs(['Converter','Control','Conductor','Contactor','Controller',
        'Inverter','Relay','Jumper','Panel','Heater','Thermostate','Thermocouple'])

        with tab13:
            Converter = df_f[df_f['Comments'] == 'Converter'].sort_values(by='Comments')
            st.dataframe(Converter)
        with tab14:
            Control = df_f[df_f['Comments'] == 'Control'].sort_values(by='Comments')
            st.dataframe(Sensor)
        with tab15:
            Conductor = df_f[df_f['Comments'] == 'Conductor'].sort_values(by='Comments')
            st.dataframe(Conductor)
        with tab16:
            Contactor = df_f[df_f['Comments'] == 'Contactor'].sort_values(by='Comments')
            st.dataframe(Contactor)
        with tab17:
            Controller = df_f[df_f['Comments'] == 'Controller'].sort_values(by='Comments')
            st.dataframe(Controller)
        with tab18:
            Inverter = df_f[df_f['Comments'] == 'Inverter'].sort_values(by='Comments')
            st.dataframe(Inverter)
        with tab19:
            Relay = df_f[df_f['Comments'] == 'Relay'].sort_values(by='Comments')
            st.dataframe(Relay)
        with tab20:
            Jumper = df_f[df_f['Comments'] == 'Jumper'].sort_values(by='Comments')
            st.dataframe(Jumper)
        with tab21:
            Panel = df_f[df_f['Comments'] == 'Panel'].sort_values(by='Comments')
            st.dataframe(Panel)
        with tab22:
            Heater = df_f[df_f['Comments'] == 'Heater'].sort_values(by='Comments')
            st.dataframe(Heater)
        with tab23:
            Thermostate = df_f[df_f['Comments'] == 'Thermostate'].sort_values(by='Comments')
            st.dataframe(Thermostate)
        with tab24:
            Thermocouple = df_f[df_f['Comments'] == 'Thermocouple'].sort_values(by='Comments')
            st.dataframe(Thermocouple)

        st.header('Select from these items')

        tab25, tab26 ,tab27, tab28,tab29, tab30 ,tab31, tab32, tab33  = st.tabs(['Ups','Power strip','Power supply','Electricity','Electricity pin',
        'Feedback','Battery','Electronic board','Electronic buzzer'])

        with tab25:
            Ups = df_f[df_f['Comments'] == 'Ups'].sort_values(by='Comments')
            st.dataframe(Ups)
        with tab26:
            Power_strip = df_f[df_f['Comments'] == 'Power strip'].sort_values(by='Comments')
            st.dataframe(Power_strip)
        with tab27:
            Power_supply = df_f[df_f['Comments'] == 'Power supply'].sort_values(by='Comments')
            st.dataframe(Power_supply)
        with tab28:
            Electricity = df_f[df_f['Comments'] == 'Electricity'].sort_values(by='Comments')
            st.dataframe(Electricity)
        with tab29:
            Electricity_pin = df_f[df_f['Comments'] == 'Electricity pin'].sort_values(by='Comments')
            st.dataframe(Electricity_pin)
        with tab30:
            Feedback = df_f[df_f['Comments'] == 'Feedback'].sort_values(by='Comments')
            st.dataframe(Feedback)
        with tab31:
            Battery = df_f[df_f['Comments'] == 'Battery'].sort_values(by='Comments')
            st.dataframe(Battery)
        with tab32:
            Electronic_board = df_f[df_f['Comments'] == 'Electronic board'].sort_values(by='Comments')
            st.dataframe(Electronic_board)
        with tab33:
            Electronic_buzzer = df_f[df_f['Comments'] == 'Electronic buzzer'].sort_values(by='Comments')
            st.dataframe(Electronic_buzzer)
            tab1, tab2 ,tab3, tab4,tab5, tab6 ,tab7, tab8, tab9 ,tab10, tab11 ,tab12  = st.tabs(['Proximity','Sensor','Fiber sensor','Amplifier','Socket',
        'Selector','Button','Switch','Light','Fan','Cable','Fuse'])


    if __name__ == '__main__':

        main()


if page == 'Pneumatic parts': 
    def main():
        st.markdown("""
    <style>
        /* Add your custom CSS styles here */
        .stProgress > div > div > div {
            background-color: #FFD700; /* Change the color of the loading spinner */
            border-radius: 50%; /* Make the loading spinner circular */
        }
    </style>
""", unsafe_allow_html=True)

# Display a placeholder while loading data
        with st.spinner("Data loaded successfully!"):
            # Simulate loading data
            import time
            time.sleep(2)

        st.markdown("""
    <h2 style='text-align: center; font-size: 40px; color: red;'>
        Find your Pneumatic parts
    </h2>
""", unsafe_allow_html=True)
        st.subheader('Select from these items')
      
        tab1, tab2 ,tab3, tab4,tab5, tab6 ,tab7  = st.tabs(['Oil seal','Gasket','Gauge','Solenoid valve','Neumatic hose','Cylinder','Regulator'])

        with tab1:
            Oil_seal = df_f[df_f['Comments'] == 'Oil seal'].sort_values(by='Comments')
            st.dataframe(Oil_seal)
        with tab2:
            Gasket = df_f[df_f['Comments'] == 'Gasket'].sort_values(by='Comments')
            st.dataframe(Gasket)
        with tab3:
            Gauge = df_f[df_f['Comments'] == 'Gauge'].sort_values(by='Comments')
            st.dataframe(Gauge)
        with tab4:
            Solenoid_valve = df_f[df_f['Comments'] == 'Solenoid valve'].sort_values(by='Comments')
            st.dataframe(Solenoid_valve)
        with tab5:
            Neumatic_hose = df_f[df_f['Comments'] == 'Neumatic hose'].sort_values(by='Comments')
            st.dataframe(Neumatic_hose)
        with tab6:
            Cylinder = df_f[df_f['Comments'] == 'Cylinder'].sort_values(by='Comments')
            st.dataframe(Cylinder)
        with tab7:
            Regulator = df_f[df_f['Comments'] == 'Regulator'].sort_values(by='Comments')
            st.dataframe(Regulator)
    if __name__ == '__main__':

        main()


               


if page == 'FORKLIFT': 
    def main():
        st.markdown("""
    <style>
        /* Add your custom CSS styles here */
        .stProgress > div > div > div {
            background-color: #FFD700; /* Change the color of the loading spinner */
            border-radius: 50%; /* Make the loading spinner circular */
        }
    </style>
""", unsafe_allow_html=True)

# Display a placeholder while loading data
        with st.spinner("Data loaded successfully!"):
            # Simulate loading data
            import time
            time.sleep(2)

        st.markdown("""
    <h2 style='text-align: center; font-size: 40px; color: red;'>
        Find your FORKLIFT parts
    </h2>
""", unsafe_allow_html=True)
        st.subheader('Select from these items')
      
        tab1, tab2 ,tab3, tab4,tab5, tab6 ,tab7  = st.tabs(['Forklift wheel','Forklift switch','Forklift coolant','Forklift switch',
        'Forklift control','Forklift carbon','Forklift break'])

        with tab1:
            Forklift_wheel = df_f[df_f['Comments'] == 'Forklift wheel'].sort_values(by='Comments')
            st.dataframe(Forklift_wheel)
        with tab2:
            Forklift_switch = df_f[df_f['Comments'] == 'Forklift switch'].sort_values(by='Comments')
            st.dataframe(Forklift_switch)
        with tab3:
            Forklift_coolant = df_f[df_f['Comments'] == 'Forklift coolant'].sort_values(by='Comments')
            st.dataframe(Forklift_coolant)
        with tab4:
            Forklift_switch = df_f[df_f['Comments'] == 'Forklift switch'].sort_values(by='Comments')
            st.dataframe(Forklift_switch)
        with tab5:
            Forklift_control = df_f[df_f['Comments'] == 'Forklift control'].sort_values(by='Comments')
            st.dataframe(Forklift_control)
        with tab6:
            Forklift_carbon = df_f[df_f['Comments'] == 'Forklift carbon'].sort_values(by='Comments')
            st.dataframe(Forklift_carbon)
        with tab7:
            Forklift_break = df_f[df_f['Comments'] == 'Forklift break'].sort_values(by='Comments')
            st.dataframe(Forklift_break)
    if __name__ == '__main__':

        main()





if page == 'Utility area':
    
    def main():
        
        st.markdown("""
    <style>
        /* Add your custom CSS styles here */
        .stProgress > div > div > div {
            background-color: #FFD700; /* Change the color of the loading spinner */
            border-radius: 50%; /* Make the loading spinner circular */
        }
    </style>
""", unsafe_allow_html=True)

# Display a placeholder while loading data
        with st.spinner("Data loaded successfully!"):
            # Simulate loading data
            import time
            time.sleep(2)

        # Once data is loaded, display a message
      
        st.markdown("""
    <h2 style='text-align: center; font-size: 40px; color: red;'>
        Find your Utility parts
    </h2>
""", unsafe_allow_html=True)
        select_col = st.selectbox('Select page:', ['Water Station','Fire Fighting','Filters', 'AHU'])
        st.subheader('Select from these items')

        if select_col == 'Water Station':
            
            tab1, tab2 ,tab3, tab4,tab5, tab6 ,tab8, tab9 ,tab10, tab12,tab13 = st.tabs(['Conductivity transmitter','Flowmeter controller','Flow module',
            'Flow monitor','conductivity','Stilmas sensor','Valve','test','pump','Uv','Ro'])
            
            with tab1:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Conductivity_transmitter = df_f[df_f['Comments'] == 'Conductivity transmitter'].sort_values(by='Comments')
                    st.dataframe(Conductivity_transmitter)
                with col3:
                    st.subheader('image  for  these  part')
                    image33 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/33.jpg', 'rb').read()
                    st.image(image33, width=150)
                    url = 'https://www.endress.com/en/field-instruments-overview/liquid-analysis-product-overview/conductivity-transmitter-clm223?t.tabId=product-overview'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                    
            with tab2:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Flowmeter_controller = df_f[df_f['Comments'] == 'Flowmeter controller'].sort_values(by='Comments')
                    st.dataframe(Flowmeter_controller)
                with col3:
                    st.subheader('image  for  these  part')
                    image34= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/34.PNG', 'rb').read()
                    st.image(image34, width=150)
                    url = 'https://www.burkert.com/en/type/8035'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                
            with tab3:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Flow_module = df_f[df_f['Comments'] == 'Flow module'].sort_values(by='Comments')
                    st.dataframe(Flow_module)
                with col3:
                    st.subheader('image  for  these  part')
                    image35= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/35.PNG', 'rb').read()
                    st.image(image35, width=150)
                    url = 'https://www.burkert.com/en/type/SE32'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                
            with tab4:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Flow_monitor = df_f[df_f['Comments'] == 'Flow monitor sensor'].sort_values(by='Comments')
                    st.dataframe(Flow_monitor)
                with col3:
                    st.subheader('image  for  these  part')
                    image36= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/36.PNG', 'rb').read()
                    st.image(image36, width=150)
                    url = 'https://www.ifm.com/de/en/product/SI1000'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                
            with tab5:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    conductivity = df_f[df_f['Comments'] == 'Water conductivity'].sort_values(by='Comments')
                    st.dataframe(conductivity)
                with col3:
                    st.subheader('image  for  these  part')
                    image37= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/37.PNG', 'rb').read()
                    st.image(image37, width=150)
                    url = 'https://www.directindustry.com/prod/emerson-automation-solutions-rosemount/product-36718-949557.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                
            with tab6:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    STILMAS_SENSOR = df_f[df_f['Comments'] == 'Stilmas sensor'].sort_values(by='Comments')
                    st.dataframe(STILMAS_SENSOR)
                with col3:
                    st.subheader('image  for  these  part')
                    image38= open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/38.PNG', 'rb').read()
                    st.image(image38, width=150)
                    url = 'https://www.ifm.com/my/en/product/TR7432'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                
            with tab8:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    
                    Valve = df_f[df_f['Comments'] == 'Water valve'].sort_values(by='Comments')
                    st.dataframe(Valve)
                with col3:
                    st.subheader('image  for  these  part')

                    pressure_transmitter, Angle_Valve   = st.tabs(['pressure_transmitter','Angle_Valve '])
                    with pressure_transmitter:
                        image39 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/39.PNG', 'rb').read()
                        st.image(image39, width=150)
                        url = 'https://www.endress.com/en/field-instruments-overview/pressure/pressure-transmitter-cerabar-pmp71b?t.tabId=product-overview'
                        st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                    with Angle_Valve :
                        image40 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/40.PNG', 'rb').read()
                        st.image(image40, width=150)
                        url = 'https://tameson.co.uk/products/al2a-spp-100-b-16-g1inch-ptfe-16bar-nc-angle-seat-valve-stainless-steel-brass'
                        st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                
            with tab9:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    
                    test = df_f[df_f['Comments'] == 'Water test '].sort_values(by='Comments')
                    st.dataframe(test)
                with col3:
                    st.subheader('image  for  these  part')

                    PHOTOMETERS, Colorimetric = st.tabs(['PHOTOMETERS','Colorimetric'])
                    with PHOTOMETERS:
                        image42 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/42.PNG', 'rb').read()
                        st.image(image42, width=150)
                        url = 'https://www.hannaservice.eu/water/environmental/photometers'
                        st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                    with Colorimetric:
                        image41 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/41.PNG', 'rb').read()
                        st.image(image41, width=150)
                        url = 'https://www.hannaservice.eu/total-hardness-colorimetric-reagents-hi93735-0-product'
                        st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                
            with tab10:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    
                    pump = df_f[df_f['Comments'] == 'Water pump'].sort_values(by='Comments')
                    st.dataframe(pump)
                with col3:
                    st.subheader('image  for  these  part')

                    LOBE_PUMP,WHEEL_PUMP = st.tabs(['LOBE PUMP','WHEEL PUMP'])
                    with LOBE_PUMP:
                        image43 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/43.jpg', 'rb').read()
                        st.image(image43, width=150)
                        url = 'https://www.chinastainlesssteelpump.com/Stainless-Steel-rotary-lobe-Pumps/Rotary-Lobe-Pumps-for-Chocolate.html'
                        st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                    with WHEEL_PUMP:
                        image44 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/44.jpg', 'rb').read()
                        st.image(image44, width=150)
                        url = 'https://www.flowpumps.de/product-page/peripheral-pump-pe50brt'
                        st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

            with tab12:
                col1, col2, col3 = st.columns([30,3,13])
            with col1:

                Uv = df_f[df_f['Comments'] == 'Water uv'].sort_values(by='Comments')
                st.dataframe(Uv)
            with col3:
                st.subheader('image  for  these  part')
                image45 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/45.jpeg', 'rb').read()
                st.image(image45, width=150)
                url = 'https://pureaqua.com/viqua-sterilight-uv/'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                
            with tab13:
                col1, col2, col3 = st.columns([30,3,13])
            with col1:

                Ro = df_f[df_f['Comments'] == 'Water ro'].sort_values(by='Comments')
                st.dataframe(Ro)
            with col3:
                st.subheader('image  for  these  part')
                image46 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/46.jpeg', 'rb').read()
                st.image(image46, width=150)
                url = 'https://www.hongtekfiltration.com/RO-membrane-elements/XLP-Series-RO-membrane-elements.html'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                
                
        elif select_col == 'Fire Fighting':
            
            Fire_detector, Fire_valve = st.tabs(['Fire_detector','Fire_valve'])
            with Fire_detector:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:

                    Fire_detector = df_f[df_f['Comments'] == 'Fire detector'].sort_values(by='Comments')
                    st.dataframe(Fire_detector)
                with col3:
                    st.subheader('image  for  these  part')
                    image47 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/47.PNG', 'rb').read()
                    st.image(image47, width=150)
                    url = 'https://www.royal.ps/en/sanitary-ware/products/fire-fighting-system/water-flow-detector'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                

            with Fire_valve:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:

                    Fire_valve = df_f[df_f['Comments'] == 'Fire valve'].sort_values(by='Comments')
                    st.dataframe(Fire_valve)
                with col3:
                    st.subheader('image  for  these  part')
                    image48 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/48.PNG', 'rb').read()
                    st.image(image48, width=150)
                    url = 'https://www.giacomini.com/product/A56'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                

        elif select_col == 'AHU':
            col1, col2, col3 = st.columns([30,3,13])
            with col1:

                AHU_Valve = df_f[df_f['Comments'] == 'Valve ahu'].sort_values(by='Comments')
                st.dataframe(AHU_Valve)
            with col3:
                st.subheader('image  for  these  part')
                image49 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/49.PNG', 'rb').read()
                st.image(image49, width=150)
                url = 'https://www.indiamart.com/proddetail/butterfly-valve-22160377997.html'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

            

        elif select_col == 'Filters':


            tab1, tab2 ,tab3, tab4, tab5, tab6 ,tab7  = st.tabs(['Hepa filter','High filter','Pre filter','Pack filter','Pump filter','Emflon filter','Filters cartage'])

            with tab1:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Hepa_filter = df_f[df_f['Comments'] == 'Hepa filter'].sort_values(by='Comments')
                    st.dataframe(Hepa_filter)
                with col3:
                    st.subheader('image  for  these  part')
                    image50 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/50.PNG', 'rb').read()
                    st.image(image50, width=150)
                    url = 'https://www.indiamart.com/proddetail/hepa-filters-13677374133.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                
            with tab2:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    High_filter = df_f[df_f['Comments'] == 'High filter'].sort_values(by='Comments')
                    st.dataframe(High_filter)
                with col3:
                    st.subheader('image  for  these  part')
                    image51 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/51.PNG', 'rb').read()
                    st.image(image51, width=150)
                    url = 'https://www.indiamart.com/proddetail/hepa-filters-13677374133.html'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                
            with tab3:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Pre_filter = df_f[df_f['Comments'] == 'Pre-filter'].sort_values(by='Comments')
                    st.dataframe(Pre_filter)
                with col3:
                    st.subheader('image  for  these  part')
                    image52 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/52.PNG', 'rb').read()
                    st.image(image52, width=150)
                    url = 'https://dir.indiamart.com/pune/pre-filter.html?enqformpdp=1'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                
            with tab4:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Packfilter = df_f[df_f['Comments'] == 'Packfilter'].sort_values(by='Comments')
                    st.dataframe(Packfilter)
                with col3:
                    st.subheader('image  for  these  part')
                    image53 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/53.PNG', 'rb').read()
                    st.image(image53, width=150)
                    url = 'https://hepafiltersales.com/products/80085-01499-19-7-8x21-1-2x1-air-filter-12-pack'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                
            with tab5:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Pump_filter = df_f[df_f['Comments'] == 'Pump filter'].sort_values(by='Comments')
                    st.dataframe(Pump_filter)
                with col3:
                    st.subheader('image  for  these  part')
                    image55 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/55.PNG', 'rb').read()
                    st.image(image55, width=150)
                    url = 'https://www.buschvacuum.com/in/en/products/spare-parts-and-accessories/spare-parts/inlet-filters/'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                
            with tab6:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Emflon_filter = df_f[df_f['Comments'] == 'Emflon filter'].sort_values(by='Comments')
                    st.dataframe(Emflon_filter)
                with col3:
                    st.subheader('image  for  these  part')
                    image54 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/54.PNG', 'rb').read()
                    st.image(image54, width=150)
                    url = 'https://shop.pall.com/us/en/food-beverage/cannabis/zidMCY2230PFRWH4?CategoryName=filter-cartridges&CatalogID=products'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

                
            with tab7:
                col1, col2, col3 = st.columns([30,3,13])
                with col1:
                    Filters_cartage = df_f[df_f['Comments'] == 'Filters cartage'].sort_values(by='Comments')
                    st.dataframe(Filters_cartage)
                with col3:
                    st.subheader('image  for  these  part')
                    image56 = open('D:/DIPLOMA DATA/DIPLOMA DATA/Spare parts finl/images/56.PNG', 'rb').read()
                    st.image(image56, width=150)
                    url = 'https://shop.pall.com/us/en/food-beverage/zidimmfdh4o'
                    st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')
                    
                
            
    if __name__ == '__main__':

        main()


if page == 'LOTOTO':
    
    def main():
        st.markdown("""
    <style>
        /* Add your custom CSS styles here */
        .stProgress > div > div > div {
            background-color: #FFD700; /* Change the color of the loading spinner */
            border-radius: 50%; /* Make the loading spinner circular */
        }
    </style>
""", unsafe_allow_html=True)

# Display a placeholder while loading data
        with st.spinner("Data loaded successfully!"):
            # Simulate loading data
            import time
            time.sleep(2)
        
        st.markdown("""
    <h2 style='text-align: center; font-size: 40px; color: red;'>
        Find your LOTOTO parts
    </h2>
""", unsafe_allow_html=True)
        st.subheader('Select from these items')

        LOTOTO = df_f[df_f['Comments'] == 'Lototo'].sort_values(by='Comments')
        st.dataframe(LOTOTO)

    if __name__ == '__main__':

        main()
 

if page == 'GLATT': 
    def main():
        st.markdown("""
    <style>
        /* Add your custom CSS styles here */
        .stProgress > div > div > div {
            background-color: #FFD700; /* Change the color of the loading spinner */
            border-radius: 50%; /* Make the loading spinner circular */
        }
    </style>
""", unsafe_allow_html=True)

# Display a placeholder while loading data
        with st.spinner("Data loaded successfully!"):
            # Simulate loading data
            import time
            time.sleep(4)

        st.markdown("""
    <h2 style='text-align: center; font-size: 40px; color: red;'>
        Find your GLATT parts
    </h2>
""", unsafe_allow_html=True)
        st.subheader('Select from these items')
      
        tab1, tab2 ,tab3 = st.tabs(['Glatt nozzle','Glatt  switch','Glatt valve'])

        with tab1:
            Glatt_nozzle = df_f[df_f['Comments'] == 'Glatt nozzle'].sort_values(by='Comments')
            st.dataframe(Glatt_nozzle)
        with tab2:
            Glatt_switch = df_f[df_f['Comments'] == 'Glatt  switch'].sort_values(by='Comments')
            st.dataframe(Glatt_switch)
        with tab3:
            Glatt_valve = df_f[df_f['Comments'] == 'Glatt valve'].sort_values(by='Comments')
            st.dataframe(Glatt_valve)

    if __name__ == '__main__':

        main()


if page == 'FETTE':

    def main():
        st.markdown("""
    <style>
        /* Add your custom CSS styles here */
        .stProgress > div > div > div {
            background-color: #FFD700; /* Change the color of the loading spinner */
            border-radius: 50%; /* Make the loading spinner circular */
        }
    </style>
""", unsafe_allow_html=True)

# Display a placeholder while loading data
        with st.spinner("Data loaded successfully!"):
            # Simulate loading data
            import time
            time.sleep(2)

        st.markdown("""
    <h2 style='text-align: center; font-size: 40px; color: red;'>
        Find your FETTE parts
    </h2>
""", unsafe_allow_html=True)
        st.subheader('Select from these items')
        col1, col2, col3 = st.columns([5,.5, 2])
        with col1:
            FETTE = df_f[df_f['Comments'] == 'Fette'].sort_values(by='Comments')
            st.dataframe(FETTE)

        with col3:
            if st.button('image  for  these  part'):

                image = open('small_c3fd8f0984028bc7dafbe91cf808227543df0eec_450653_0001.jpg', 'rb').read()
                st.image(image, caption='FETTE', width=150)
            
            # Redirect to a web page
                url = 'https://www.abf.store/s/en/bearings/STO12-INA/450653'
                st.components.v1.html(f'<a href="{url}" target="_blank" style="background-color: #FFD700;">Go to Web Page</a>')

    if __name__ == '__main__':

        main()
# Out:
# Overwriting Engineering.py

# %%
# !streamlit run Engineering.py

# %%
# !pipreqs ./
